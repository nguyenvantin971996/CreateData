# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from sklearn.preprocessing import StandardScaler

# %%
class Network(object):

    def __init__(self, sizes):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])
        self.counter = 0

    def feedforward(self, a):
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
        return a

    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]
    
    def score_vector(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))
        total_score=total_score/X.shape[0] # mean-squared error
        return (1/(1+total_score))

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = (self.feedforward(X[i].reshape(-1,1))).reshape(-1)
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

# %%
class NN_ABC_Algo:

    def __init__(self, n_pops, net_size, X, y, X_test, y_test):
        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.X = X[:]
        self.y = y[:]
        self.X_test = X_test[:]
        self.y_test = y_test[:]
        self.accuracy_train = []
        self.accuracy_test = []
        self.limit = self.n_pops
        self.best = Network(self.net_size)
    
    def get_random_point(self, type):
        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc, yc) for net in self.nets]

    def get_all_scores_vector(self,Xc,yc):
        return [net.score_vector(Xc, yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc, yc) for net in self.nets]
    
    def initialization_phase(self):
        for i in range(self.n_pops):
            weight = copy.deepcopy(self.nets[i].weights)
            for x in range(len(weight)):
                for y in range(len(weight[x])):
                    for z in range(len(weight[x][y])):
                        weight[x][y][z]=self.nets[i].weights[x][y].min() + np.random.rand()*(self.nets[i].weights[x][y].max()-self.nets[i].weights[x][y].min())
            self.nets[i].weights = copy.deepcopy(weight)
            biases = copy.deepcopy(self.nets[i].biases)
            for x in range(len(biases)):
                for y in range(len(biases[x])):
                    for z in range(len(biases[x][y])):
                        biases[x][y][z]=self.nets[i].biases[x].min() + np.random.rand()*(self.nets[i].biases[x].max()-self.nets[i].biases[x].min())
            self.nets[i].biases = copy.deepcopy(biases)

    def employeed_phase(self,Xc,yc):
        nets = copy.deepcopy(self.nets)
        for i in range(self.n_pops):
            r = list(range(0,i)) + list(range(i+1,self.n_pops))
            coceg = random.choice(r)
            fi1 = random.uniform(-1,1)
            fi2 = random.uniform(-1,1)
            nn = copy.deepcopy(self.nets[i])
            for t in range(1):
                # get some random points
                layer1, point1 = self.get_random_point('bias')
                # replace genetic (bias) with mother's value
                nn.biases[layer1][point1] = nn.biases[layer1][point1] + fi1*(nn.biases[layer1][point1]-self.nets[coceg].biases[layer1][point1])
                layer2, point2 = self.get_random_point('weight')
                # replace genetic (weights) with mother's value
                nn.weights[layer2][point2] = nn.weights[layer2][point2] + fi2*(nn.weights[layer2][point2]-self.nets[coceg].weights[layer2][point2])
            if(nn.score_vector(Xc,yc)>nets[i].score_vector(Xc,yc)):
                nn.counter = 0
                nets[i] = copy.deepcopy(nn)
            else:
                nets[i].counter += 1
        self.nets = copy.deepcopy(nets)
        
    def onlooked_phase(self,Xc,yc):
        all_scores_vector = self.get_all_scores_vector(Xc,yc)
        sum = np.sum(all_scores_vector)
        probability = all_scores_vector/sum
        nets = copy.deepcopy(self.nets)
        for i in range(self.n_pops):
            index_solution = np.random.choice(list(range(self.n_pops)),p=probability)
            r = list(range(0,index_solution)) + list(range(index_solution+1,self.n_pops))
            coceg = random.choice(r)
            fi1 = random.uniform(-1,1)
            fi2 = random.uniform(-1,1)
            nn = copy.deepcopy(self.nets[index_solution])
            for t in range(1):
                # get some random points
                layer1, point1 = self.get_random_point('bias')
                # replace genetic (bias) with mother's value
                nn.biases[layer1][point1] = nn.biases[layer1][point1] + fi1*(nn.biases[layer1][point1]-self.nets[coceg].biases[layer1][point1])
                layer2, point2 = self.get_random_point('weight')
                # replace genetic (weights) with mother's value
                nn.weights[layer2][point2] = nn.weights[layer2][point2] + fi2*(nn.weights[layer2][point2]-self.nets[coceg].weights[layer2][point2])
            if(nn.score_vector(Xc,yc)>nets[index_solution].score_vector(Xc,yc)):
                nn.counter = 0
                nets[index_solution] = copy.deepcopy(nn)
            else:
                nets[index_solution].counter += 1
        self.nets = copy.deepcopy(nets)

    def scout_phase(self):
        for i in range(self.n_pops):
            if self.nets[i].counter > self.limit:
                weight = copy.deepcopy(self.nets[i].weights)
                for x in range(len(weight)):
                    for y in range(len(weight[x])):
                        for z in range(len(weight[x][y])):
                            weight[x][y][z]=self.nets[i].weights[x][y].min() + np.random.rand()*(self.nets[i].weights[x][y].max()-self.nets[i].weights[x][y].min())
                self.nets[i].weights = copy.deepcopy(weight)
                biases = copy.deepcopy(self.nets[i].biases)
                for x in range(len(biases)):
                    for y in range(len(biases[x])):
                        for z in range(len(biases[x][y])):
                            biases[x][y][z]=self.nets[i].biases[x].min() + np.random.rand()*(self.nets[i].biases[x].max()-self.nets[i].biases[x].min())
                self.nets[i].biases = copy.deepcopy(biases)
                self.nets[i].counter = 0
                
    def sort_nets(self,Xc,yc):
        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])

        # exclude score as it is not needed anymore
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        start_time = time.time()
        self.initialization_phase()
        for t in range(25):
            self.accuracy_train.append(self.best.accuracy(self.X,self.y))
            self.accuracy_test.append(self.best.accuracy(self.X_test,self.y_test))
            for i in range(40):
                j1=i*40
                j2=(1+i)*40
                Xc=self.X[j1:j2,:]
                yc=self.y[j1:j2,:]
                for k in range(25):  
                    self.employeed_phase(Xc,yc)
                    self.onlooked_phase(Xc,yc)
                    self.scout_phase()
                    self.sort_nets(Xc,yc)
                print("Current iteration : {}, batch : {}".format(t+1,i+1))
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.best.score(self.X,self.y))
                print("Current top member's network accuracy: %.2f%%\n" % self.best.accuracy(self.X,self.y))

# %%
df = pd.read_csv("../Data/data_(12-12).csv")

# %%
X = df.iloc[:1600, :12].values
y = df.iloc[:1600, 12:24].values
sc = StandardScaler()
X = sc.fit_transform(X)
X_test = df.iloc[1600:2000, :12].values
y_test = df.iloc[1600:2000, 12:24].values
sc = StandardScaler()
X_test = sc.fit_transform(X_test)

# %%
N_POPS = 100
NET_SIZE = [12,12,12]
nnabc = NN_ABC_Algo(N_POPS, NET_SIZE, X, y, X_test, y_test)
nnabc.evolve()
# Out:
# Current iteration : 1, batch : 1
# Time taken by far : 43.9 seconds
# Current top member's network score: 2.10316
# Current top member's network accuracy: 0.19%
#
# Current iteration : 1, batch : 2
# Time taken by far : 86.3 seconds
# Current top member's network score: 1.86014
# Current top member's network accuracy: 5.56%
#
# Current iteration : 1, batch : 3
# Time taken by far : 127.0 seconds
# Current top member's network score: 1.70815
# Current top member's network accuracy: 21.12%
#
# Current iteration : 1, batch : 4
# Time taken by far : 166.3 seconds
# Current top member's network score: 1.66584
# Current top member's network accuracy: 47.06%
#
# Current iteration : 1, batch : 5
# Time taken by far : 203.9 seconds
# Current top member's network score: 1.66584
# Current top member's network accuracy: 47.06%
#
# Current iteration : 1, batch : 6
# Time taken by far : 245.5 seconds
# Current top member's network score: 1.66584
# Current top member's network accuracy: 47.06%
#
# Current iteration : 1, batch : 7
# Time taken by far : 284.9 seconds
# Current top member's network score: 1.66584
# Current top member's network accuracy: 47.06%
#
# Current iteration : 1, batch : 8
# Time taken by far : 325.0 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 9
# Time taken by far : 365.5 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 10
# Time taken by far : 406.4 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 11
# Time taken by far : 447.4 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
# C:\Users\nguye\AppData\Local\Temp/ipykernel_7972/4068189173.py:20: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# Current iteration : 1, batch : 12
# Time taken by far : 491.2 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 13
# Time taken by far : 531.5 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 14
# Time taken by far : 572.0 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 15
# Time taken by far : 610.6 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 16
# Time taken by far : 650.2 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 17
# Time taken by far : 691.4 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 18
# Time taken by far : 733.4 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 19
# Time taken by far : 774.0 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 20
# Time taken by far : 811.7 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 21
# Time taken by far : 849.9 seconds
# Current top member's network score: 1.57442
# Current top member's network accuracy: 47.94%
#
# Current iteration : 1, batch : 22
# Time taken by far : 889.2 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 23
# Time taken by far : 931.3 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 24
# Time taken by far : 973.8 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 25
# Time taken by far : 1014.3 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 26
# Time taken by far : 1053.1 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 27
# Time taken by far : 1091.4 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 28
# Time taken by far : 1139.8 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 29
# Time taken by far : 1184.2 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 30
# Time taken by far : 1228.2 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 31
# Time taken by far : 1271.4 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 32
# Time taken by far : 1315.1 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 33
# Time taken by far : 1359.1 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 34
# Time taken by far : 1403.6 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 35
# Time taken by far : 1447.9 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 36
# Time taken by far : 1492.3 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 37
# Time taken by far : 1536.3 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 38
# Time taken by far : 1580.8 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 39
# Time taken by far : 1625.3 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 1, batch : 40
# Time taken by far : 1669.9 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 1
# Time taken by far : 1715.1 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 2
# Time taken by far : 1760.2 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 3
# Time taken by far : 1805.0 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 4
# Time taken by far : 1850.2 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 5
# Time taken by far : 1895.5 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 6
# Time taken by far : 1941.5 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 7
# Time taken by far : 1986.5 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 8
# Time taken by far : 2032.4 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 9
# Time taken by far : 2079.8 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 10
# Time taken by far : 2126.6 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 11
# Time taken by far : 2178.7 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 12
# Time taken by far : 2229.6 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 13
# Time taken by far : 2274.2 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 14
# Time taken by far : 2315.3 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 15
# Time taken by far : 2356.3 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 16
# Time taken by far : 2396.7 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 17
# Time taken by far : 2437.7 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 18
# Time taken by far : 2478.5 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 19
# Time taken by far : 2518.9 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 20
# Time taken by far : 2560.5 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 21
# Time taken by far : 2601.5 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 22
# Time taken by far : 2642.3 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 23
# Time taken by far : 2683.4 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 24
# Time taken by far : 2724.1 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 25
# Time taken by far : 2765.1 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 26
# Time taken by far : 2806.2 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 27
# Time taken by far : 2846.9 seconds
# Current top member's network score: 1.46873
# Current top member's network accuracy: 49.69%
#
# Current iteration : 2, batch : 28
# Time taken by far : 2888.5 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 29
# Time taken by far : 2929.8 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 30
# Time taken by far : 2971.6 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 31
# Time taken by far : 3013.5 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 32
# Time taken by far : 3055.2 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 33
# Time taken by far : 3097.1 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 34
# Time taken by far : 3138.9 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 35
# Time taken by far : 3180.0 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 36
# Time taken by far : 3221.8 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 37
# Time taken by far : 3264.7 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 38
# Time taken by far : 3318.1 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 39
# Time taken by far : 3364.6 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 2, batch : 40
# Time taken by far : 3410.0 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 1
# Time taken by far : 3454.1 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 2
# Time taken by far : 3501.9 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 3
# Time taken by far : 3543.7 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 4
# Time taken by far : 3585.3 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 5
# Time taken by far : 3627.3 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 6
# Time taken by far : 3669.1 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 7
# Time taken by far : 3710.7 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 8
# Time taken by far : 3753.3 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 9
# Time taken by far : 3795.5 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 10
# Time taken by far : 3836.9 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 11
# Time taken by far : 3879.1 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 12
# Time taken by far : 3920.7 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 13
# Time taken by far : 3963.2 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 14
# Time taken by far : 4005.3 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 15
# Time taken by far : 4047.2 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 16
# Time taken by far : 4089.4 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 17
# Time taken by far : 4131.4 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 18
# Time taken by far : 4173.1 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 19
# Time taken by far : 4215.1 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 20
# Time taken by far : 4257.3 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 21
# Time taken by far : 4298.9 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 22
# Time taken by far : 4341.0 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 23
# Time taken by far : 4382.5 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 24
# Time taken by far : 4424.7 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 25
# Time taken by far : 4466.6 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 26
# Time taken by far : 4508.7 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 27
# Time taken by far : 4551.1 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 28
# Time taken by far : 4593.3 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 29
# Time taken by far : 4635.5 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 30
# Time taken by far : 4677.8 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 31
# Time taken by far : 4720.2 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 32
# Time taken by far : 4762.6 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 33
# Time taken by far : 4804.6 seconds
# Current top member's network score: 1.41293
# Current top member's network accuracy: 55.25%
#
# Current iteration : 3, batch : 34
# Time taken by far : 4846.8 seconds
# Current top member's network score: 1.38971
# Current top member's network accuracy: 57.06%
#
# Current iteration : 3, batch : 35
# Time taken by far : 4889.2 seconds
# Current top member's network score: 1.38971
# Current top member's network accuracy: 57.06%
#
# Current iteration : 3, batch : 36
# Time taken by far : 4932.2 seconds
# Current top member's network score: 1.39811
# Current top member's network accuracy: 57.38%
#
# Current iteration : 3, batch : 37
# Time taken by far : 4974.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 3, batch : 38
# Time taken by far : 5017.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 3, batch : 39
# Time taken by far : 5060.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 3, batch : 40
# Time taken by far : 5102.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 1
# Time taken by far : 5145.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 2
# Time taken by far : 5187.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 3
# Time taken by far : 5230.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 4
# Time taken by far : 5272.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 5
# Time taken by far : 5315.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 6
# Time taken by far : 5357.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 7
# Time taken by far : 5400.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 8
# Time taken by far : 5442.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 9
# Time taken by far : 5485.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 10
# Time taken by far : 5528.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 11
# Time taken by far : 5570.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 12
# Time taken by far : 5612.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 13
# Time taken by far : 5656.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 14
# Time taken by far : 5698.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 15
# Time taken by far : 5741.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 16
# Time taken by far : 5784.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 17
# Time taken by far : 5826.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 18
# Time taken by far : 5869.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 19
# Time taken by far : 5911.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 20
# Time taken by far : 5953.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 21
# Time taken by far : 5996.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 22
# Time taken by far : 6039.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 23
# Time taken by far : 6082.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 24
# Time taken by far : 6125.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 25
# Time taken by far : 6167.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 26
# Time taken by far : 6210.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 27
# Time taken by far : 6252.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 28
# Time taken by far : 6295.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 29
# Time taken by far : 6338.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 30
# Time taken by far : 6381.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 31
# Time taken by far : 6423.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 32
# Time taken by far : 6466.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 33
# Time taken by far : 6509.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 34
# Time taken by far : 6552.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 35
# Time taken by far : 6595.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 36
# Time taken by far : 6638.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 37
# Time taken by far : 6680.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 38
# Time taken by far : 6723.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 39
# Time taken by far : 6766.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 4, batch : 40
# Time taken by far : 6809.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 1
# Time taken by far : 6852.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 2
# Time taken by far : 6895.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 3
# Time taken by far : 6938.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 4
# Time taken by far : 6981.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 5
# Time taken by far : 7024.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 6
# Time taken by far : 7067.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 7
# Time taken by far : 7110.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 8
# Time taken by far : 7152.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 9
# Time taken by far : 7196.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 10
# Time taken by far : 7239.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 11
# Time taken by far : 7282.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 12
# Time taken by far : 7326.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 13
# Time taken by far : 7370.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 14
# Time taken by far : 7412.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 15
# Time taken by far : 7455.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 16
# Time taken by far : 7498.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 17
# Time taken by far : 7541.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 18
# Time taken by far : 7584.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 19
# Time taken by far : 7626.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 20
# Time taken by far : 7668.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 21
# Time taken by far : 7711.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 22
# Time taken by far : 7754.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 23
# Time taken by far : 7797.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 24
# Time taken by far : 7840.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 25
# Time taken by far : 7884.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 26
# Time taken by far : 7934.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 27
# Time taken by far : 7980.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 28
# Time taken by far : 8020.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 29
# Time taken by far : 8056.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 30
# Time taken by far : 8092.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 31
# Time taken by far : 8129.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 32
# Time taken by far : 8166.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 33
# Time taken by far : 8202.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 34
# Time taken by far : 8239.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 35
# Time taken by far : 8275.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 36
# Time taken by far : 8311.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 37
# Time taken by far : 8347.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 38
# Time taken by far : 8383.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 39
# Time taken by far : 8420.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 5, batch : 40
# Time taken by far : 8456.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 1
# Time taken by far : 8492.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 2
# Time taken by far : 8528.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 3
# Time taken by far : 8564.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 4
# Time taken by far : 8600.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 5
# Time taken by far : 8636.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 6
# Time taken by far : 8673.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 7
# Time taken by far : 8709.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 8
# Time taken by far : 8745.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 9
# Time taken by far : 8781.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 10
# Time taken by far : 8818.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 11
# Time taken by far : 8854.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 12
# Time taken by far : 8890.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 13
# Time taken by far : 8926.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 14
# Time taken by far : 8962.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 15
# Time taken by far : 8998.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 16
# Time taken by far : 9035.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 17
# Time taken by far : 9071.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 18
# Time taken by far : 9108.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 19
# Time taken by far : 9145.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 20
# Time taken by far : 9181.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 21
# Time taken by far : 9217.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 22
# Time taken by far : 9253.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 23
# Time taken by far : 9289.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 24
# Time taken by far : 9325.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 25
# Time taken by far : 9361.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 26
# Time taken by far : 9397.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 27
# Time taken by far : 9434.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 28
# Time taken by far : 9470.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 29
# Time taken by far : 9507.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 30
# Time taken by far : 9545.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 31
# Time taken by far : 9581.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 32
# Time taken by far : 9618.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 33
# Time taken by far : 9654.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 34
# Time taken by far : 9692.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 35
# Time taken by far : 9728.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 36
# Time taken by far : 9766.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 37
# Time taken by far : 9804.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 38
# Time taken by far : 9842.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 39
# Time taken by far : 9880.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 6, batch : 40
# Time taken by far : 9918.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 1
# Time taken by far : 9956.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 2
# Time taken by far : 9997.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 3
# Time taken by far : 10036.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 4
# Time taken by far : 10075.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 5
# Time taken by far : 10111.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 6
# Time taken by far : 10148.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 7
# Time taken by far : 10183.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 8
# Time taken by far : 10220.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 9
# Time taken by far : 10256.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 10
# Time taken by far : 10293.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 11
# Time taken by far : 10329.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 12
# Time taken by far : 10369.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 13
# Time taken by far : 10407.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 14
# Time taken by far : 10446.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 15
# Time taken by far : 10484.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 16
# Time taken by far : 10523.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 17
# Time taken by far : 10561.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 18
# Time taken by far : 10599.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 19
# Time taken by far : 10636.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 20
# Time taken by far : 10676.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 21
# Time taken by far : 10715.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 22
# Time taken by far : 10750.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 23
# Time taken by far : 10782.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 24
# Time taken by far : 10814.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 25
# Time taken by far : 10850.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 26
# Time taken by far : 10884.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 27
# Time taken by far : 10913.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
# Current iteration : 7, batch : 28
# Time taken by far : 10945.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 29
# Time taken by far : 10982.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 30
# Time taken by far : 11016.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 31
# Time taken by far : 11048.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 32
# Time taken by far : 11091.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 33
# Time taken by far : 11124.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 34
# Time taken by far : 11153.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 35
# Time taken by far : 11182.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 36
# Time taken by far : 11212.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 37
# Time taken by far : 11245.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 38
# Time taken by far : 11276.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 39
# Time taken by far : 11308.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 7, batch : 40
# Time taken by far : 11343.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 1
# Time taken by far : 11374.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 2
# Time taken by far : 11406.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 3
# Time taken by far : 11441.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 4
# Time taken by far : 11471.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 5
# Time taken by far : 11500.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 6
# Time taken by far : 11530.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 7
# Time taken by far : 11560.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 8
# Time taken by far : 11589.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 9
# Time taken by far : 11620.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 10
# Time taken by far : 11650.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 11
# Time taken by far : 11679.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 12
# Time taken by far : 11709.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 13
# Time taken by far : 11740.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 14
# Time taken by far : 11769.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 15
# Time taken by far : 11800.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 16
# Time taken by far : 11829.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 17
# Time taken by far : 11859.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 8, batch : 18
# Time taken by far : 11889.3 seconds
# ...
#
# Current iteration : 12, batch : 24
# Time taken by far : 17743.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 25
# Time taken by far : 17780.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 26
# Time taken by far : 17816.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 27
# Time taken by far : 17852.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 28
# Time taken by far : 17887.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 29
# Time taken by far : 17920.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 30
# Time taken by far : 17953.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 31
# Time taken by far : 17985.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
# Current iteration : 12, batch : 32
# Time taken by far : 18018.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 33
# Time taken by far : 18050.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 34
# Time taken by far : 18083.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 35
# Time taken by far : 18116.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 36
# Time taken by far : 18148.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 37
# Time taken by far : 18181.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 38
# Time taken by far : 18214.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 39
# Time taken by far : 18246.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 12, batch : 40
# Time taken by far : 18279.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 1
# Time taken by far : 18312.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 2
# Time taken by far : 18344.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 3
# Time taken by far : 18377.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 4
# Time taken by far : 18410.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 5
# Time taken by far : 18443.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 6
# Time taken by far : 18477.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 7
# Time taken by far : 18511.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 8
# Time taken by far : 18543.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 9
# Time taken by far : 18576.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 10
# Time taken by far : 18608.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 11
# Time taken by far : 18640.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 12
# Time taken by far : 18672.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 13
# Time taken by far : 18704.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 14
# Time taken by far : 18736.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 15
# Time taken by far : 18769.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 16
# Time taken by far : 18801.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 17
# Time taken by far : 18834.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 18
# Time taken by far : 18868.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 19
# Time taken by far : 18901.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 20
# Time taken by far : 18933.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 21
# Time taken by far : 18966.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 22
# Time taken by far : 18998.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 23
# Time taken by far : 19030.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 24
# Time taken by far : 19062.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 25
# Time taken by far : 19095.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 26
# Time taken by far : 19127.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 27
# Time taken by far : 19159.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 28
# Time taken by far : 19193.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 29
# Time taken by far : 19225.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 30
# Time taken by far : 19258.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 31
# Time taken by far : 19288.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 32
# Time taken by far : 19319.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 33
# Time taken by far : 19350.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 34
# Time taken by far : 19382.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 35
# Time taken by far : 19414.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 36
# Time taken by far : 19446.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 37
# Time taken by far : 19477.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 38
# Time taken by far : 19509.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 39
# Time taken by far : 19540.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 13, batch : 40
# Time taken by far : 19572.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 1
# Time taken by far : 19603.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 2
# Time taken by far : 19636.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
# Current iteration : 14, batch : 3
# Time taken by far : 19667.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 4
# Time taken by far : 19699.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 5
# Time taken by far : 19730.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 6
# Time taken by far : 19762.6 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 7
# Time taken by far : 19793.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 8
# Time taken by far : 19825.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 9
# Time taken by far : 19856.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 10
# Time taken by far : 19888.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 11
# Time taken by far : 19920.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 12
# Time taken by far : 19950.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 13
# Time taken by far : 19981.7 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 14
# Time taken by far : 20013.5 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 15
# Time taken by far : 20046.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 16
# Time taken by far : 20080.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 17
# Time taken by far : 20112.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 18
# Time taken by far : 20136.3 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 19
# Time taken by far : 20159.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 20
# Time taken by far : 20182.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 21
# Time taken by far : 20203.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 22
# Time taken by far : 20226.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 23
# Time taken by far : 20247.4 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 24
# Time taken by far : 20269.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 25
# Time taken by far : 20291.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 26
# Time taken by far : 20312.9 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 27
# Time taken by far : 20335.2 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 28
# Time taken by far : 20357.1 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 29
# Time taken by far : 20378.0 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
#
# Current iteration : 14, batch : 30
# Time taken by far : 20398.8 seconds
# Current top member's network score: 1.36282
# Current top member's network accuracy: 57.44%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7972/4105148204.py in <module>
#       2 NET_SIZE = [12,12,12]
#       3 nnabc = NN_ABC_Algo(N_POPS, NET_SIZE, X, y, X_test, y_test)
# ----> 4 nnabc.evolve()
#
# ~\AppData\Local\Temp/ipykernel_7972/16732652.py in evolve(self)
#     141                 yc=self.y[j1:j2,:]
#     142                 for k in range(25):
# --> 143                     self.employeed_phase(Xc,yc)
#     144                     self.onlooked_phase(Xc,yc)
#     145                     self.scout_phase()
#
# ~\AppData\Local\Temp/ipykernel_7972/16732652.py in employeed_phase(self, Xc, yc)
#      65                 # replace genetic (weights) with mother's value
#      66                 nn.weights[layer2][point2] = nn.weights[layer2][point2] + fi2*(nn.weights[layer2][point2]-self.nets[coceg].weights[layer2][point2])
# ---> 67             if(nn.score_vector(Xc,yc)>nets[i].score_vector(Xc,yc)):
#      68                 nn.counter = 0
#      69                 nets[i] = copy.deepcopy(nn)
#
# ~\AppData\Local\Temp/ipykernel_7972/4068189173.py in score_vector(self, X, y)
#      31         total_score=0
#      32         for i in range(X.shape[0]):
# ---> 33             predicted = self.feedforward(X[i].reshape(-1,1))
#      34             actual = y[i].reshape(-1,1)
#      35             total_score += np.sum(np.power(predicted-actual,2))
#
# ~\AppData\Local\Temp/ipykernel_7972/4068189173.py in feedforward(self, a)
#      14     def feedforward(self, a):
#      15         for b, w in zip(self.biases, self.weights):
# ---> 16             a = self.sigmoid(np.dot(w,a)+b)
#      17         return a
#      18
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
nnabc.best.accuracy(X,y)
# Out:
# C:\Users\nguye\AppData\Local\Temp/ipykernel_7972/4068189173.py:20: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# 57.4375

# %%
nnabc.best.accuracy(X_test,y_test)
# Out:
# C:\Users\nguye\AppData\Local\Temp/ipykernel_7972/4068189173.py:20: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# 57.75

# %%
accuracy_train = np.array(nnabc.accuracy_train)
accuracy_test = np.array(nnabc.accuracy_test)

# %%
from matplotlib import pyplot as plt
plt.plot(accuracy_train)
plt.plot(accuracy_test )
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Dependencies
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
# Neural network
model = Sequential()
model.add(Dense(12, input_dim=12, activation="sigmoid"))
model.add(Dense(12, activation="sigmoid"))

# %%
for i in range(len(model.layers)):
    model.layers[i].set_weights([nnabc.best.weights[i].T,nnabc.best.biases[i].reshape(-1)])

# %%
from keras.models import load_model
model.save('model_NN_ABC_12_12_12.h5')  # creates a HDF5 file 'my_model.h5'
del model
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
