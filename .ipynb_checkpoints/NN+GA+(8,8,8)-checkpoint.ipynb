# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from sklearn.preprocessing import StandardScaler

# %%
class Network(object):

    def __init__(self, sizes):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])

    def feedforward(self, a):
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
        return a

    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = (self.feedforward(X[i].reshape(-1,1))).reshape(-1)
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

# %%
class NNGeneticAlgo:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, X, y):
        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.X = X[:]
        self.y = y[:]
        self.best = Network(self.net_size)
    
    def get_random_point(self, type):
        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self):
        return [net.score(self.X, self.y) for net in self.nets]

    def get_all_accuracy(self):
        return [net.accuracy(self.X, self.y) for net in self.nets]

    def crossover(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.crossover_rate:
                father = random.randint(0,self.n_pops-1)
                mother = random.randint(0,self.n_pops-1)
                # make a copy of father 'genetic' weights & biases information
                nn_1 = copy.deepcopy(self.nets[father])
                nn_2 = copy.deepcopy(self.nets[mother])
                # cross-over bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # replace genetic (bias) with mother's value
                    nn_1.biases[layer][point] = self.nets[mother].biases[layer][point]
                    nn_2.biases[layer][point] = self.nets[father].biases[layer][point]

                # cross-over weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # replace genetic (weight) with mother's value
                    nn_1.weights[layer][point] = self.nets[mother].weights[layer][point]
                    nn_2.weights[layer][point] = self.nets[father].weights[layer][point]
                self.nets.append(copy.deepcopy(nn_1))
                self.nets.append(copy.deepcopy(nn_2))
        
    def mutation(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.mutation_rate:
                origin = random.randint(0,self.n_pops-1)
                nn = copy.deepcopy(self.nets[origin])

                # mutate bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # add some random value between -0.5 and 0.5
                    nn.biases[layer][point] += random.uniform(-0.5, 0.5)

                # mutate weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # add some random value between -0.5 and 0.5
                    nn.weights[layer][point[0], point[1]] += random.uniform(-0.5, 0.5)
                self.nets.append(copy.deepcopy(nn))
        
    def selection(self):
        nets_new=[]
        for i in range(self.n_pops):
            k_1 = random.randint(0,len(self.nets)-1)
            k_2 = random.randint(0,len(self.nets)-1)
            if(self.nets[k_1].score(self.X,self.y)<self.nets[k_2].score(self.X,self.y)):
                nets_new.append(self.nets[k_1])
            else:
                nets_new.append(self.nets[k_2])
        self.nets = copy.deepcopy(nets_new)
    
    def sort_nets(self):
        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores()))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])

        # exclude score as it is not needed anymore
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
#         choose best
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        self.crossover()
        self.mutation()
        self.selection()
        self.sort_nets()

# %%
df = pd.read_csv("data_(8-8).csv")

# %%
X = df.iloc[:1000, :8].values
y = df.iloc[:1000, 8:16].values
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
N_POPS = 100
NET_SIZE = [8,8,8]
MUTATION_RATE = 0.1
CROSSOVER_RATE = 0.8

# %%
nnga = NNGeneticAlgo(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, X, y)

# %%
start_time = time.time()

# %%
for i in range(1000):
    if (i+1) % 10 == 0:
        print("Current iteration : {}".format(i+1))
        print("Time taken by far : %.1f seconds" % (time.time() - start_time))
        print("Current top member's network score: %.2f " % nnga.best.score(X,y))
        print("Current top member's network accuracy: %.2f%%\n" % nnga.best.accuracy(X,y))
    nnga.evolve()
# Out:
# Current iteration : 10
# Time taken by far : 64.5 seconds
# Current top member's network score: 1.83
# Current top member's network accuracy: 9.00%
#
# Current iteration : 20
# Time taken by far : 122.4 seconds
# Current top member's network score: 1.83
# Current top member's network accuracy: 9.00%
#
# Current iteration : 30
# Time taken by far : 191.0 seconds
# Current top member's network score: 1.26
# Current top member's network accuracy: 17.10%
#
# Current iteration : 40
# Time taken by far : 260.6 seconds
# Current top member's network score: 1.11
# Current top member's network accuracy: 24.40%
#
# Current iteration : 50
# Time taken by far : 330.6 seconds
# Current top member's network score: 0.99
# Current top member's network accuracy: 36.50%
#
# Current iteration : 60
# Time taken by far : 402.1 seconds
# Current top member's network score: 0.95
# Current top member's network accuracy: 40.30%
#
# Current iteration : 70
# Time taken by far : 473.1 seconds
# Current top member's network score: 0.79
# Current top member's network accuracy: 45.00%
#
# Current iteration : 80
# Time taken by far : 544.2 seconds
# Current top member's network score: 0.74
# Current top member's network accuracy: 52.30%
#
# Current iteration : 90
# Time taken by far : 615.9 seconds
# Current top member's network score: 0.70
# Current top member's network accuracy: 57.90%
#
# Current iteration : 100
# Time taken by far : 687.6 seconds
# Current top member's network score: 0.67
# Current top member's network accuracy: 62.10%
#
# Current iteration : 110
# Time taken by far : 758.3 seconds
# Current top member's network score: 0.66
# Current top member's network accuracy: 63.20%
#
# Current iteration : 120
# Time taken by far : 829.1 seconds
# Current top member's network score: 0.64
# Current top member's network accuracy: 64.20%
#
# Current iteration : 130
# Time taken by far : 899.9 seconds
# Current top member's network score: 0.63
# Current top member's network accuracy: 66.30%
#
# Current iteration : 140
# Time taken by far : 971.4 seconds
# Current top member's network score: 0.63
# Current top member's network accuracy: 66.30%
#
# Current iteration : 150
# Time taken by far : 1042.7 seconds
# Current top member's network score: 0.59
# Current top member's network accuracy: 67.40%
#
# Current iteration : 160
# Time taken by far : 1115.2 seconds
# Current top member's network score: 0.59
# Current top member's network accuracy: 67.70%
#
# Current iteration : 170
# Time taken by far : 1184.9 seconds
# Current top member's network score: 0.57
# Current top member's network accuracy: 71.10%
#
# Current iteration : 180
# Time taken by far : 1255.6 seconds
# Current top member's network score: 0.55
# Current top member's network accuracy: 72.50%
#
# Current iteration : 190
# Time taken by far : 1327.0 seconds
# Current top member's network score: 0.55
# Current top member's network accuracy: 72.50%
#
# Current iteration : 200
# Time taken by far : 1397.3 seconds
# Current top member's network score: 0.55
# Current top member's network accuracy: 72.50%
#
# Current iteration : 210
# Time taken by far : 1468.2 seconds
# Current top member's network score: 0.55
# Current top member's network accuracy: 72.50%
#
# Current iteration : 220
# Time taken by far : 1538.9 seconds
# Current top member's network score: 0.55
# Current top member's network accuracy: 72.50%
#
# Current iteration : 230
# Time taken by far : 1610.1 seconds
# Current top member's network score: 0.53
# Current top member's network accuracy: 74.30%
#
# Current iteration : 240
# Time taken by far : 1681.5 seconds
# Current top member's network score: 0.51
# Current top member's network accuracy: 74.90%
#
# Current iteration : 250
# Time taken by far : 1755.7 seconds
# Current top member's network score: 0.51
# Current top member's network accuracy: 75.10%
#
# Current iteration : 260
# Time taken by far : 1842.0 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 270
# Time taken by far : 1921.8 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 280
# Time taken by far : 2002.0 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 290
# Time taken by far : 2080.8 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 300
# Time taken by far : 2159.6 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 310
# Time taken by far : 2238.6 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 320
# Time taken by far : 2317.9 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 330
# Time taken by far : 2397.7 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 340
# Time taken by far : 2476.3 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 350
# Time taken by far : 2555.7 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 360
# Time taken by far : 2634.3 seconds
# Current top member's network score: 0.50
# Current top member's network accuracy: 76.20%
#
# Current iteration : 370
# Time taken by far : 2714.1 seconds
# Current top member's network score: 0.49
# Current top member's network accuracy: 76.80%
#
# Current iteration : 380
# Time taken by far : 2794.5 seconds
# Current top member's network score: 0.48
# Current top member's network accuracy: 78.20%
#
# Current iteration : 390
# Time taken by far : 2873.5 seconds
# Current top member's network score: 0.48
# Current top member's network accuracy: 78.30%
#
# Current iteration : 400
# Time taken by far : 2952.5 seconds
# Current top member's network score: 0.48
# Current top member's network accuracy: 78.30%
#
# Current iteration : 410
# Time taken by far : 3032.6 seconds
# Current top member's network score: 0.48
# Current top member's network accuracy: 78.30%
#
# Current iteration : 420
# Time taken by far : 3108.8 seconds
# Current top member's network score: 0.47
# Current top member's network accuracy: 78.90%
#
# Current iteration : 430
# Time taken by far : 3179.7 seconds
# Current top member's network score: 0.47
# Current top member's network accuracy: 78.90%
#
# Current iteration : 440
# Time taken by far : 3252.2 seconds
# Current top member's network score: 0.47
# Current top member's network accuracy: 78.90%
#
# Current iteration : 450
# Time taken by far : 3323.6 seconds
# Current top member's network score: 0.47
# Current top member's network accuracy: 78.90%
#
# Current iteration : 460
# Time taken by far : 3394.6 seconds
# Current top member's network score: 0.47
# Current top member's network accuracy: 78.90%
#
# Current iteration : 470
# Time taken by far : 3465.7 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 79.40%
#
# Current iteration : 480
# Time taken by far : 3533.6 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.00%
#
# Current iteration : 490
# Time taken by far : 3592.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.00%
#
# Current iteration : 500
# Time taken by far : 3652.0 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.00%
#
# Current iteration : 510
# Time taken by far : 3710.8 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.50%
#
# Current iteration : 520
# Time taken by far : 3769.5 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 530
# Time taken by far : 3831.6 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 540
# Time taken by far : 3893.3 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 550
# Time taken by far : 3952.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 560
# Time taken by far : 4015.2 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
# Current iteration : 570
# Time taken by far : 4073.7 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 580
# Time taken by far : 4133.5 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 590
# Time taken by far : 4192.5 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 600
# Time taken by far : 4251.3 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 610
# Time taken by far : 4309.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 620
# Time taken by far : 4369.1 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 630
# Time taken by far : 4425.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 640
# Time taken by far : 4483.4 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 650
# Time taken by far : 4540.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 660
# Time taken by far : 4599.4 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 670
# Time taken by far : 4657.5 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 680
# Time taken by far : 4715.1 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 690
# Time taken by far : 4773.4 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 700
# Time taken by far : 4832.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 710
# Time taken by far : 4891.4 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 720
# Time taken by far : 4949.8 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 730
# Time taken by far : 5008.3 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 740
# Time taken by far : 5065.7 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 750
# Time taken by far : 5124.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 760
# Time taken by far : 5183.8 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 770
# Time taken by far : 5241.6 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 780
# Time taken by far : 5300.5 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 790
# Time taken by far : 5359.1 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 800
# Time taken by far : 5416.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 810
# Time taken by far : 5476.0 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 820
# Time taken by far : 5534.7 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 830
# Time taken by far : 5595.4 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 840
# Time taken by far : 5653.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 850
# Time taken by far : 5712.3 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 860
# Time taken by far : 5773.5 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 870
# Time taken by far : 5837.1 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 880
# Time taken by far : 5894.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 890
# Time taken by far : 5952.2 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 900
# Time taken by far : 6008.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 910
# Time taken by far : 6065.7 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 920
# Time taken by far : 6123.2 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 930
# Time taken by far : 6199.5 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 940
# Time taken by far : 6263.8 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 950
# Time taken by far : 6323.1 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 960
# Time taken by far : 6382.3 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 970
# Time taken by far : 6446.1 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 980
# Time taken by far : 6504.8 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 990
# Time taken by far : 6563.3 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%
#
# Current iteration : 1000
# Time taken by far : 6621.9 seconds
# Current top member's network score: 0.44
# Current top member's network accuracy: 80.60%

# %%
nnga.best.accuracy(X,y)
# Out:
# 80.60000000000001

# %%
X[10].reshape(-1,1)
# Out:
# array([[-0.72343826],
#        [-0.3841888 ],
#        [ 1.54662865],
#        [ 0.72263078],
#        [ 1.17945268],
#        [-0.83053637],
#        [ 0.03090244],
#        [-0.82676313]])

# %%
pred = nnga.best.feedforward(X[10].reshape(-1,1)).reshape(-1)

# %%
for j in range(len(pred)):
    pred[j] = round(pred[j])

# %%
pred
# Out:
# array([0., 1., 0., 0., 0., 0., 1., 0.])

# %%
y[10]
# Out:
# array([0, 1, 0, 0, 0, 0, 1, 0], dtype=int64)

# %%
X_test = df.iloc[5000:6000, :8].values
y_test = df.iloc[5000:6000, 8:16].values
sc = StandardScaler()
X_test = sc.fit_transform(X_test)

# %%
acc = nnga.best.accuracy(X_test,y_test)

# %%
acc
# Out:
# 77.8
