# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from sklearn.preprocessing import StandardScaler

# %%
class Network(object):

    def __init__(self, sizes):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])

    def feedforward(self, a):
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
        return a

    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = (self.feedforward(X[i].reshape(-1,1))).reshape(-1)
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

# %%
class NNGeneticAlgo:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, X, y):
        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.X = X[:]
        self.y = y[:]
        self.best = Network(self.net_size)
    
    def get_random_point(self, type):
        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc,yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc,yc) for net in self.nets]

    def crossover(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.crossover_rate:
                father = random.randint(0,self.n_pops-1)
                mother = random.randint(0,self.n_pops-1)
                # make a copy of father 'genetic' weights & biases information
                nn_1 = copy.deepcopy(self.nets[father])
                nn_2 = copy.deepcopy(self.nets[mother])
                # cross-over bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # replace genetic (bias) with mother's value
                    nn_1.biases[layer][point] = self.nets[mother].biases[layer][point]
                    nn_2.biases[layer][point] = self.nets[father].biases[layer][point]

                # cross-over weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # replace genetic (weight) with mother's value
                    nn_1.weights[layer][point] = self.nets[mother].weights[layer][point]
                    nn_2.weights[layer][point] = self.nets[father].weights[layer][point]
                self.nets.append(copy.deepcopy(nn_1))
                self.nets.append(copy.deepcopy(nn_2))
        
    def mutation(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.mutation_rate:
                origin = random.randint(0,self.n_pops-1)
                nn = copy.deepcopy(self.nets[origin])

                # mutate bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # add some random value between -0.5 and 0.5
                    nn.biases[layer][point] += random.uniform(-0.5, 0.5)

                # mutate weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # add some random value between -0.5 and 0.5
                    nn.weights[layer][point[0], point[1]] += random.uniform(-0.5, 0.5)
                self.nets.append(copy.deepcopy(nn))
        
    def selection(self,Xc,yc):
        nets_new=[]
        for i in range(self.n_pops):
            k_1 = random.randint(0,len(self.nets)-1)
            k_2 = random.randint(0,len(self.nets)-1)
            if(self.nets[k_1].score(Xc,yc)<self.nets[k_2].score(Xc,yc)):
                nets_new.append(self.nets[k_1])
            else:
                nets_new.append(self.nets[k_2])
        self.nets = copy.deepcopy(nets_new)
    
    def sort_nets(self,Xc,yc):
        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])

        # exclude score as it is not needed anymore
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        start_time = time.time()
        for t in range(20):
            print("Current iteration : {}".format(t+1))
            for i in range(10):
                j1=i*100
                j2=(1+i)*100
                Xc=self.X[j1:j2,:]
                yc=self.y[j1:j2,:]
                for k in range(20): 
                    self.crossover()
                    self.mutation()
                    self.selection(Xc,yc)
                    self.sort_nets(Xc,yc)
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.best.score(self.X,self.y))
                print("Current top member's network accuracy: %.2f%%\n" % self.best.accuracy(self.X,self.y))

# %%
df = pd.read_csv("data_(8-8).csv")

# %%
X = df.iloc[:1000, :8].values
y = df.iloc[:1000, 8:16].values
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
N_POPS = 100
NET_SIZE = [8,8,8]
MUTATION_RATE = 0.1
CROSSOVER_RATE = 0.8

# %%
nnga = NNGeneticAlgo(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, X, y)

# %%
nnga.evolve()
# Out:
# Current iteration : 1
# Time taken by far : 16.9 seconds
# Current top member's network score: 1.46086
# Current top member's network accuracy: 11.00%
#
# Time taken by far : 32.5 seconds
# Current top member's network score: 1.28665
# Current top member's network accuracy: 23.10%
#
# Time taken by far : 47.9 seconds
# Current top member's network score: 1.02190
# Current top member's network accuracy: 42.80%
#
# Time taken by far : 64.0 seconds
# Current top member's network score: 0.78162
# Current top member's network accuracy: 49.70%
#
# Time taken by far : 80.7 seconds
# Current top member's network score: 0.69090
# Current top member's network accuracy: 54.50%
#
# Time taken by far : 96.7 seconds
# Current top member's network score: 0.66660
# Current top member's network accuracy: 60.50%
#
# Time taken by far : 112.7 seconds
# Current top member's network score: 0.60534
# Current top member's network accuracy: 61.50%
#
# Time taken by far : 128.4 seconds
# Current top member's network score: 0.57000
# Current top member's network accuracy: 66.30%
#
# Time taken by far : 144.4 seconds
# Current top member's network score: 0.55170
# Current top member's network accuracy: 67.50%
#
# Time taken by far : 160.4 seconds
# Current top member's network score: 0.54126
# Current top member's network accuracy: 69.40%
#
# Current iteration : 2
# Time taken by far : 176.0 seconds
# Current top member's network score: 0.51850
# Current top member's network accuracy: 71.30%
#
# Time taken by far : 192.5 seconds
# Current top member's network score: 0.51264
# Current top member's network accuracy: 71.90%
#
# Time taken by far : 209.5 seconds
# Current top member's network score: 0.51264
# Current top member's network accuracy: 71.90%
#
# Time taken by far : 225.9 seconds
# Current top member's network score: 0.47313
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 242.1 seconds
# Current top member's network score: 0.46145
# Current top member's network accuracy: 75.50%
#
# Time taken by far : 258.4 seconds
# Current top member's network score: 0.44255
# Current top member's network accuracy: 76.90%
#
# Time taken by far : 274.1 seconds
# Current top member's network score: 0.43846
# Current top member's network accuracy: 78.10%
#
# Time taken by far : 290.1 seconds
# Current top member's network score: 0.43846
# Current top member's network accuracy: 78.10%
#
# Time taken by far : 306.9 seconds
# Current top member's network score: 0.42810
# Current top member's network accuracy: 78.60%
#
# Time taken by far : 323.5 seconds
# Current top member's network score: 0.42810
# Current top member's network accuracy: 78.60%
#
# Current iteration : 3
# Time taken by far : 339.9 seconds
# Current top member's network score: 0.41355
# Current top member's network accuracy: 79.40%
#
# Time taken by far : 356.2 seconds
# Current top member's network score: 0.41433
# Current top member's network accuracy: 79.60%
#
# Time taken by far : 372.5 seconds
# Current top member's network score: 0.41433
# Current top member's network accuracy: 79.60%
#
# Time taken by far : 389.0 seconds
# Current top member's network score: 0.41433
# Current top member's network accuracy: 79.60%
#
# Time taken by far : 405.1 seconds
# Current top member's network score: 0.41433
# Current top member's network accuracy: 79.60%
#
# Time taken by far : 421.7 seconds
# Current top member's network score: 0.41433
# Current top member's network accuracy: 79.60%
#
# Time taken by far : 437.4 seconds
# Current top member's network score: 0.39819
# Current top member's network accuracy: 80.40%
#
# Time taken by far : 453.8 seconds
# Current top member's network score: 0.39819
# Current top member's network accuracy: 80.40%
#
# Time taken by far : 470.4 seconds
# Current top member's network score: 0.38797
# Current top member's network accuracy: 80.80%
#
# Time taken by far : 486.6 seconds
# Current top member's network score: 0.38251
# Current top member's network accuracy: 81.00%
#
# Current iteration : 4
# Time taken by far : 503.0 seconds
# Current top member's network score: 0.36663
# Current top member's network accuracy: 81.50%
#
# Time taken by far : 519.5 seconds
# Current top member's network score: 0.36663
# Current top member's network accuracy: 81.50%
#
# Time taken by far : 535.9 seconds
# Current top member's network score: 0.36663
# Current top member's network accuracy: 81.50%
#
# Time taken by far : 552.1 seconds
# Current top member's network score: 0.36663
# Current top member's network accuracy: 81.50%
#
# Time taken by far : 567.6 seconds
# Current top member's network score: 0.36663
# Current top member's network accuracy: 81.50%
#
# Time taken by far : 583.7 seconds
# Current top member's network score: 0.35837
# Current top member's network accuracy: 81.70%
#
# Time taken by far : 600.1 seconds
# Current top member's network score: 0.35837
# Current top member's network accuracy: 81.70%
#
# Time taken by far : 616.6 seconds
# Current top member's network score: 0.36244
# Current top member's network accuracy: 81.90%
#
# Time taken by far : 631.7 seconds
# Current top member's network score: 0.35450
# Current top member's network accuracy: 82.70%
#
# Time taken by far : 648.2 seconds
# Current top member's network score: 0.35450
# Current top member's network accuracy: 82.70%
#
# Current iteration : 5
# Time taken by far : 663.7 seconds
# Current top member's network score: 0.35066
# Current top member's network accuracy: 82.80%
#
# Time taken by far : 680.8 seconds
# Current top member's network score: 0.35259
# Current top member's network accuracy: 83.20%
#
# Time taken by far : 697.1 seconds
# Current top member's network score: 0.35259
# Current top member's network accuracy: 83.20%
#
# Time taken by far : 712.9 seconds
# Current top member's network score: 0.35259
# Current top member's network accuracy: 83.20%
#
# Time taken by far : 729.2 seconds
# Current top member's network score: 0.35259
# Current top member's network accuracy: 83.20%
#
# Time taken by far : 745.4 seconds
# Current top member's network score: 0.33338
# Current top member's network accuracy: 83.50%
#
# Time taken by far : 761.7 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 778.0 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 794.6 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 811.3 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Current iteration : 6
# Time taken by far : 827.3 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 843.7 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 859.8 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 876.4 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 892.3 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 908.7 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 925.7 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 942.6 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 958.6 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Time taken by far : 974.9 seconds
# Current top member's network score: 0.32897
# Current top member's network accuracy: 84.30%
#
# Current iteration : 7
# Time taken by far : 990.8 seconds
# Current top member's network score: 0.31768
# Current top member's network accuracy: 84.50%
#
# Time taken by far : 1006.9 seconds
# Current top member's network score: 0.31768
# Current top member's network accuracy: 84.50%
#
# Time taken by far : 1022.5 seconds
# Current top member's network score: 0.31768
# Current top member's network accuracy: 84.50%
#
# Time taken by far : 1038.3 seconds
# Current top member's network score: 0.31729
# Current top member's network accuracy: 85.00%
# Time taken by far : 1054.3 seconds
# Current top member's network score: 0.31729
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 1071.1 seconds
# Current top member's network score: 0.31729
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 1087.2 seconds
# Current top member's network score: 0.30707
# Current top member's network accuracy: 85.90%
#
# Time taken by far : 1103.4 seconds
# Current top member's network score: 0.30707
# Current top member's network accuracy: 85.90%
#
# Time taken by far : 1119.3 seconds
# Current top member's network score: 0.30707
# Current top member's network accuracy: 85.90%
#
# Time taken by far : 1136.7 seconds
# Current top member's network score: 0.30707
# Current top member's network accuracy: 85.90%
#
# Current iteration : 8
# Time taken by far : 1153.0 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1169.2 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1185.1 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1201.0 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1216.9 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1232.5 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1248.6 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1265.0 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1281.2 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 1296.6 seconds
# Current top member's network score: 0.30524
# Current top member's network accuracy: 86.00%
#
# Current iteration : 9
# Time taken by far : 1312.7 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1329.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1345.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1361.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1377.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1393.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1409.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1425.7 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1442.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1459.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 10
# Time taken by far : 1475.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1491.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1507.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1523.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1540.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1556.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1572.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1592.7 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1608.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1625.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 11
# Time taken by far : 1640.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1665.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1686.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1704.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1723.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1741.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1759.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1777.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1796.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1814.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 12
# Time taken by far : 1831.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1849.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1868.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1886.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1904.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1922.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1939.9 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1957.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1975.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 1993.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 13
# Time taken by far : 2011.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2029.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2047.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2065.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2083.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2101.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2119.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2137.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
# Time taken by far : 2155.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2173.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 14
# Time taken by far : 2191.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2209.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2227.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2245.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2263.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2281.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2299.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2317.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2334.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2352.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 15
# Time taken by far : 2370.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2389.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2406.7 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2424.9 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2442.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2460.9 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2478.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2496.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2514.9 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2532.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 16
# Time taken by far : 2550.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2568.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2587.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2605.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2623.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2641.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2659.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2677.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2695.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2713.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 17
# Time taken by far : 2731.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2749.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2767.4 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2785.6 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2803.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2821.0 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2838.7 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2857.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2875.3 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2893.9 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Current iteration : 18
# Time taken by far : 2912.1 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2930.2 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2947.9 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2963.5 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2979.8 seconds
# Current top member's network score: 0.29519
# Current top member's network accuracy: 87.30%
#
# Time taken by far : 2995.4 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 87.40%
#
# Time taken by far : 3011.4 seconds
# Current top member's network score: 0.25908
# Current top member's network accuracy: 87.70%
#
# Time taken by far : 3028.0 seconds
# Current top member's network score: 0.25140
# Current top member's network accuracy: 88.30%
#
# Time taken by far : 3044.6 seconds
# Current top member's network score: 0.25140
# Current top member's network accuracy: 88.30%
#
# Time taken by far : 3061.3 seconds
# Current top member's network score: 0.25140
# Current top member's network accuracy: 88.30%
#
# Current iteration : 19
# Time taken by far : 3077.6 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3093.7 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3110.7 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3126.7 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3142.9 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3159.9 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3176.5 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3192.2 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3208.2 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3224.6 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Current iteration : 20
# Time taken by far : 3241.1 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3257.3 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
# Time taken by far : 3273.1 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3288.9 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3306.3 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3321.9 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3337.6 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3353.2 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3369.2 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%
#
# Time taken by far : 3385.4 seconds
# Current top member's network score: 0.25053
# Current top member's network accuracy: 88.50%

# %%
nnga.best.accuracy(X,y)
# Out:
# 88.5

# %%
X[10].reshape(-1,1)
# Out:
# array([[-0.72343826],
#        [-0.3841888 ],
#        [ 1.54662865],
#        [ 0.72263078],
#        [ 1.17945268],
#        [-0.83053637],
#        [ 0.03090244],
#        [-0.82676313]])

# %%
pred = nnga.best.feedforward(X[10].reshape(-1,1)).reshape(-1)

# %%
for j in range(len(pred)):
    pred[j] = round(pred[j])

# %%
pred
# Out:
# array([0., 1., 0., 0., 0., 0., 1., 0.])

# %%
y[10]
# Out:
# array([0, 1, 0, 0, 0, 0, 1, 0], dtype=int64)

# %%
X_test = df.iloc[5000:6000, :8].values
y_test = df.iloc[5000:6000, 8:16].values
sc = StandardScaler()
X_test = sc.fit_transform(X_test)

# %%
acc = nnga.best.accuracy(X_test,y_test)

# %%
acc
# Out:
# 84.6
