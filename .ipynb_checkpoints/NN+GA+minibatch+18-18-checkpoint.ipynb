# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from sklearn.preprocessing import StandardScaler

# %%
class Network(object):

    def __init__(self, sizes):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])

    def feedforward(self, a):
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
        return a

    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = (self.feedforward(X[i].reshape(-1,1))).reshape(-1)
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

# %%
class NNGeneticAlgo:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, X, y):
        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.X = X[:]
        self.y = y[:]
    
    def get_random_point(self, type):
        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc,yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc,yc) for net in self.nets]

    def crossover(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.crossover_rate:
                father = random.randint(0,self.n_pops-1)
                mother = random.randint(0,self.n_pops-1)
                # make a copy of father 'genetic' weights & biases information
                nn_1 = copy.deepcopy(self.nets[father])
                nn_2 = copy.deepcopy(self.nets[mother])
                # cross-over bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # replace genetic (bias) with mother's value
                    nn_1.biases[layer][point] = self.nets[mother].biases[layer][point]
                    nn_2.biases[layer][point] = self.nets[father].biases[layer][point]

                # cross-over weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # replace genetic (weight) with mother's value
                    nn_1.weights[layer][point] = self.nets[mother].weights[layer][point]
                    nn_2.weights[layer][point] = self.nets[father].weights[layer][point]
                self.nets[father] = copy.deepcopy(nn_1)
                self.nets[mother] = copy.deepcopy(nn_2)
        
    def mutation(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.mutation_rate:
                origin = random.randint(0,self.n_pops-1)
                nn = copy.deepcopy(self.nets[origin])

                # mutate bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # add some random value between -0.5 and 0.5
                    nn.biases[layer][point] += random.uniform(-0.5, 0.5)

                # mutate weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # add some random value between -0.5 and 0.5
                    nn.weights[layer][point[0], point[1]] += random.uniform(-0.5, 0.5)
                self.nets[origin] = copy.deepcopy(nn)
        
    def selection(self,Xc,yc):
        nets_new=[]
        for i in range(self.n_pops):
            k_1 = random.randint(0,self.n_pops-1)
            k_2 = random.randint(0,self.n_pops-1)
            if(self.nets[k_1].score(Xc,yc)<self.nets[k_2].score(Xc,yc)):
                nets_new.append(self.nets[k_1])
            else:
                nets_new.append(self.nets[k_2])
        self.nets = copy.deepcopy(nets_new)
    
    def sort_nets(self,Xc,yc):
        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])

        # exclude score as it is not needed anymore
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)

    def evolve(self):
        start_time = time.time()
        for t in range(50):
            print("Current iteration : {}".format(t+1))
            for i in range(20):
                j1=i*50
                j2=(1+i)*50
                Xc=self.X[j1:j2,:]
                yc=self.y[j1:j2,:]
                for k in range(100): 
                    self.crossover()
                    self.mutation()
                    self.selection(Xc,yc)
                    self.sort_nets(Xc,yc)
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.nets[0].score(Xc,yc))
                print("Current top member's network accuracy: %.2f%%\n" % self.nets[0].accuracy(Xc,yc))

# %%
df = pd.read_csv("data_(18-18).csv")

# %%
X = df.iloc[:1000, :18].values
y = df.iloc[:1000, 18:36].values
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
N_POPS = 100
NET_SIZE = [18,18,18]
MUTATION_RATE = 0.1
CROSSOVER_RATE = 0.7

# %%
nnga = NNGeneticAlgo(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, X, y)

# %%
nnga.evolve()
# Out:
# Current iteration : 1
# Time taken by far : 6.9 seconds
# Current top member's network score: 3.26818
# Current top member's network accuracy: 0.00%
#
# Time taken by far : 14.0 seconds
# Current top member's network score: 2.74633
# Current top member's network accuracy: 0.00%
#
# Time taken by far : 20.5 seconds
# Current top member's network score: 2.56406
# Current top member's network accuracy: 0.00%
#
# Time taken by far : 26.9 seconds
# Current top member's network score: 2.47928
# Current top member's network accuracy: 0.00%
#
# Time taken by far : 33.3 seconds
# Current top member's network score: 2.46676
# Current top member's network accuracy: 0.00%
#
# Time taken by far : 39.7 seconds
# Current top member's network score: 2.29603
# Current top member's network accuracy: 2.00%
#
# Time taken by far : 46.9 seconds
# Current top member's network score: 2.17912
# Current top member's network accuracy: 5.00%
#
# Time taken by far : 53.3 seconds
# Current top member's network score: 2.00234
# Current top member's network accuracy: 8.00%
#
# Time taken by far : 59.7 seconds
# Current top member's network score: 2.10420
# Current top member's network accuracy: 3.00%
#
# Time taken by far : 66.2 seconds
# Current top member's network score: 1.86667
# Current top member's network accuracy: 8.00%
#
# Current iteration : 2
# Time taken by far : 72.7 seconds
# Current top member's network score: 1.74403
# Current top member's network accuracy: 1.00%
#
# Time taken by far : 79.8 seconds
# Current top member's network score: 1.62412
# Current top member's network accuracy: 6.00%
#
# Time taken by far : 86.2 seconds
# Current top member's network score: 1.83893
# Current top member's network accuracy: 11.00%
#
# Time taken by far : 92.5 seconds
# Current top member's network score: 1.67647
# Current top member's network accuracy: 14.00%
#
# Time taken by far : 98.9 seconds
# Current top member's network score: 1.80135
# Current top member's network accuracy: 20.00%
#
# Time taken by far : 105.3 seconds
# Current top member's network score: 1.65496
# Current top member's network accuracy: 7.00%
#
# Time taken by far : 112.4 seconds
# Current top member's network score: 1.49097
# Current top member's network accuracy: 24.00%
#
# Time taken by far : 118.7 seconds
# Current top member's network score: 1.50344
# Current top member's network accuracy: 27.00%
#
# Time taken by far : 125.1 seconds
# Current top member's network score: 1.59334
# Current top member's network accuracy: 17.00%
#
# Time taken by far : 131.5 seconds
# Current top member's network score: 1.39464
# Current top member's network accuracy: 35.00%
#
# Current iteration : 3
# Time taken by far : 137.8 seconds
# Current top member's network score: 1.26874
# Current top member's network accuracy: 24.00%
#
# Time taken by far : 145.1 seconds
# Current top member's network score: 1.26371
# Current top member's network accuracy: 30.00%
#
# Time taken by far : 151.4 seconds
# Current top member's network score: 1.60098
# Current top member's network accuracy: 23.00%
#
# Time taken by far : 157.8 seconds
# Current top member's network score: 1.35560
# Current top member's network accuracy: 28.00%
#
# Time taken by far : 164.1 seconds
# Current top member's network score: 1.63743
# Current top member's network accuracy: 24.00%
#
# Time taken by far : 170.5 seconds
# Current top member's network score: 1.52609
# Current top member's network accuracy: 22.00%
#
# Time taken by far : 177.3 seconds
# Current top member's network score: 1.35805
# Current top member's network accuracy: 32.00%
#
# Time taken by far : 184.0 seconds
# Current top member's network score: 1.35406
# Current top member's network accuracy: 29.00%
#
# Time taken by far : 190.3 seconds
# Current top member's network score: 1.42185
# Current top member's network accuracy: 28.00%
#
# Time taken by far : 196.6 seconds
# Current top member's network score: 1.29750
# Current top member's network accuracy: 33.00%
#
# Current iteration : 4
# Time taken by far : 202.9 seconds
# Current top member's network score: 1.12216
# Current top member's network accuracy: 33.00%
#
# Time taken by far : 209.9 seconds
# Current top member's network score: 1.16740
# Current top member's network accuracy: 38.00%
#
# Time taken by far : 216.3 seconds
# Current top member's network score: 1.51751
# Current top member's network accuracy: 28.00%
#
# Time taken by far : 222.6 seconds
# Current top member's network score: 1.27663
# Current top member's network accuracy: 33.00%
#
# Time taken by far : 228.9 seconds
# Current top member's network score: 1.58483
# Current top member's network accuracy: 26.00%
#
# Time taken by far : 235.2 seconds
# Current top member's network score: 1.43057
# Current top member's network accuracy: 20.00%
#
# Time taken by far : 241.9 seconds
# Current top member's network score: 1.31147
# Current top member's network accuracy: 35.00%
#
# Time taken by far : 248.7 seconds
# Current top member's network score: 1.31913
# Current top member's network accuracy: 33.00%
#
# Time taken by far : 255.0 seconds
# Current top member's network score: 1.37728
# Current top member's network accuracy: 28.00%
#
# Time taken by far : 261.3 seconds
# Current top member's network score: 1.27270
# Current top member's network accuracy: 42.00%
#
# Current iteration : 5
# Time taken by far : 267.6 seconds
# Current top member's network score: 1.07784
# Current top member's network accuracy: 40.00%
#
# Time taken by far : 274.6 seconds
# Current top member's network score: 1.12395
# Current top member's network accuracy: 39.00%
#
# Time taken by far : 281.2 seconds
# Current top member's network score: 1.47465
# Current top member's network accuracy: 31.00%
#
# Time taken by far : 287.5 seconds
# Current top member's network score: 1.21997
# Current top member's network accuracy: 35.00%
#
# Time taken by far : 293.8 seconds
# Current top member's network score: 1.53663
# Current top member's network accuracy: 30.00%
#
# Time taken by far : 300.3 seconds
# Current top member's network score: 1.34685
# Current top member's network accuracy: 29.00%
#
# Time taken by far : 306.8 seconds
# Current top member's network score: 1.24875
# Current top member's network accuracy: 39.00%
#
# Time taken by far : 313.6 seconds
# Current top member's network score: 1.25810
# Current top member's network accuracy: 38.00%
#
# Time taken by far : 319.9 seconds
# Current top member's network score: 1.31930
# Current top member's network accuracy: 34.00%
#
# Time taken by far : 326.3 seconds
# Current top member's network score: 1.21176
# Current top member's network accuracy: 44.00%
#
# Current iteration : 6
# Time taken by far : 332.6 seconds
# Current top member's network score: 1.00739
# Current top member's network accuracy: 42.00%
#
# Time taken by far : 339.4 seconds
# Current top member's network score: 1.06926
# Current top member's network accuracy: 42.00%
#
# Time taken by far : 346.4 seconds
# Current top member's network score: 1.44293
# Current top member's network accuracy: 31.00%
#
# Time taken by far : 352.8 seconds
# Current top member's network score: 1.17809
# Current top member's network accuracy: 36.00%
#
# Time taken by far : 359.1 seconds
# Current top member's network score: 1.51212
# Current top member's network accuracy: 33.00%
#
# Time taken by far : 365.4 seconds
# Current top member's network score: 1.30859
# Current top member's network accuracy: 35.00%
#
# Time taken by far : 372.4 seconds
# Current top member's network score: 1.19019
# Current top member's network accuracy: 37.00%
#
# Time taken by far : 380.0 seconds
# Current top member's network score: 1.24628
# Current top member's network accuracy: 40.00%
#
# Time taken by far : 386.5 seconds
# Current top member's network score: 1.31002
# Current top member's network accuracy: 31.00%
#
# Time taken by far : 393.0 seconds
# Current top member's network score: 1.18011
# Current top member's network accuracy: 46.00%
#
# Current iteration : 7
# Time taken by far : 399.5 seconds
# Current top member's network score: 0.99801
# Current top member's network accuracy: 43.00%
#
# Time taken by far : 406.8 seconds
# Current top member's network score: 1.05746
# Current top member's network accuracy: 42.00%
#
# Time taken by far : 413.4 seconds
# Current top member's network score: 1.40868
# Current top member's network accuracy: 33.00%
#
# Time taken by far : 420.0 seconds
# Current top member's network score: 1.16596
# Current top member's network accuracy: 36.00%
#
# Time taken by far : 426.4 seconds
# Current top member's network score: 1.46204
# Current top member's network accuracy: 34.00%
# Time taken by far : 433.0 seconds
# Current top member's network score: 1.28415
# Current top member's network accuracy: 32.00%
#
# Time taken by far : 439.6 seconds
# Current top member's network score: 1.17618
# Current top member's network accuracy: 40.00%
#
# Time taken by far : 446.4 seconds
# Current top member's network score: 1.20089
# Current top member's network accuracy: 42.00%
#
# Time taken by far : 452.8 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 31.00%
#
# Time taken by far : 459.3 seconds
# Current top member's network score: 1.14721
# Current top member's network accuracy: 45.00%
#
# Current iteration : 8
# Time taken by far : 465.7 seconds
# Current top member's network score: 0.96115
# Current top member's network accuracy: 48.00%
#
# Time taken by far : 472.9 seconds
# Current top member's network score: 1.02769
# Current top member's network accuracy: 40.00%
#
# Time taken by far : 479.6 seconds
# Current top member's network score: 1.38665
# Current top member's network accuracy: 37.00%
#
# Time taken by far : 486.1 seconds
# Current top member's network score: 1.15034
# Current top member's network accuracy: 39.00%
#
# Time taken by far : 492.8 seconds
# Current top member's network score: 1.45716
# Current top member's network accuracy: 33.00%
#
# Time taken by far : 499.2 seconds
# Current top member's network score: 1.23765
# Current top member's network accuracy: 38.00%
#
# Time taken by far : 505.8 seconds
# Current top member's network score: 1.17193
# Current top member's network accuracy: 42.00%
#
# Time taken by far : 512.8 seconds
# Current top member's network score: 1.16725
# Current top member's network accuracy: 43.00%
#
# Time taken by far : 519.2 seconds
# Current top member's network score: 1.24224
# Current top member's network accuracy: 37.00%
#
# Time taken by far : 525.6 seconds
# Current top member's network score: 1.12249
# Current top member's network accuracy: 46.00%
#
# Current iteration : 9
# Time taken by far : 532.1 seconds
# Current top member's network score: 0.93727
# Current top member's network accuracy: 46.00%
#
# Time taken by far : 539.4 seconds
# Current top member's network score: 1.00429
# Current top member's network accuracy: 42.00%
#
# Time taken by far : 546.1 seconds
# Current top member's network score: 1.36727
# Current top member's network accuracy: 35.00%
#
# Time taken by far : 552.5 seconds
# Current top member's network score: 1.14779
# Current top member's network accuracy: 39.00%
#
# Time taken by far : 559.1 seconds
# Current top member's network score: 1.43390
# Current top member's network accuracy: 36.00%
#
# Time taken by far : 565.6 seconds
# Current top member's network score: 1.21855
# Current top member's network accuracy: 35.00%
#
# Time taken by far : 572.5 seconds
# Current top member's network score: 1.14019
# Current top member's network accuracy: 43.00%
#
# Time taken by far : 579.5 seconds
# Current top member's network score: 1.16063
# Current top member's network accuracy: 46.00%
#
# Time taken by far : 586.1 seconds
# Current top member's network score: 1.22307
# Current top member's network accuracy: 34.00%
#
# Time taken by far : 592.5 seconds
# Current top member's network score: 1.09667
# Current top member's network accuracy: 47.00%
#
# Current iteration : 10
# Time taken by far : 599.3 seconds
# Current top member's network score: 0.91353
# Current top member's network accuracy: 45.00%
#
# Time taken by far : 606.5 seconds
# Current top member's network score: 0.99387
# Current top member's network accuracy: 45.00%
#
# Time taken by far : 613.2 seconds
# Current top member's network score: 1.33129
# Current top member's network accuracy: 39.00%
#
# Time taken by far : 619.7 seconds
# Current top member's network score: 1.13672
# Current top member's network accuracy: 36.00%
#
# Time taken by far : 626.3 seconds
# Current top member's network score: 1.39562
# Current top member's network accuracy: 34.00%
#
# Time taken by far : 633.0 seconds
# Current top member's network score: 1.20465
# Current top member's network accuracy: 33.00%
#
# Time taken by far : 640.2 seconds
# Current top member's network score: 1.10397
# Current top member's network accuracy: 44.00%
#
# Time taken by far : 647.4 seconds
# Current top member's network score: 1.11829
# Current top member's network accuracy: 45.00%
#
# Time taken by far : 655.2 seconds
# Current top member's network score: 1.21986
# Current top member's network accuracy: 35.00%

# %%
nnga.nets[0].accuracy(X,y)

# %%
X[10].reshape(-1,1)

# %%
pred = nnga.nets[0].feedforward(X[10].reshape(-1,1)).reshape(-1)

# %%
for j in range(len(pred)):
    pred[j] = round(pred[j])

# %%
pred

# %%
y[10]

# %%
X_test = df.iloc[5000:6000, :18].values
y_test = df.iloc[5000:6000, 18:36].values
sc = StandardScaler()
X_test = sc.fit_transform(X_test)

# %%
acc = nnga.nets[0].accuracy(X_test,y_test)

# %%
acc
