# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from sklearn.preprocessing import StandardScaler

# %%
class Network(object):

    def __init__(self, sizes):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])
        self.counter = 0

    def feedforward(self, a):
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
        return a

    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]
    
    def score_vector(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))
        total_score=total_score/X.shape[0] # mean-squared error
        return (1/(1+total_score))

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = (self.feedforward(X[i].reshape(-1,1))).reshape(-1)
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

# %%
class NN_ABC_Algo:

    def __init__(self, n_pops, net_size, X, y):
        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.X = X[:]
        self.y = y[:]
        self.limit = self.n_pops
        self.best = Network(self.net_size)
    
    def get_random_point(self, type):
        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc, yc) for net in self.nets]

    def get_all_scores_vector(self,Xc,yc):
        return [net.score_vector(Xc, yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc, yc) for net in self.nets]
    def initialization_phase(self):
        for i in range(self.n_pops):
            weight = copy.deepcopy(self.nets[i].weights)
            for x in range(len(weight)):
                for y in range(len(weight[x])):
                    for z in range(len(weight[x][y])):
                        weight[x][y][z]=self.nets[i].weights[x][y].min() + np.random.rand()*(self.nets[i].weights[x][y].max()-self.nets[i].weights[x][y].min())
            self.nets[i].weights = copy.deepcopy(weight)
            biases = copy.deepcopy(self.nets[i].biases)
            for x in range(len(biases)):
                for y in range(len(biases[x])):
                    for z in range(len(biases[x][y])):
                        biases[x][y][z]=self.nets[i].biases[x].min() + np.random.rand()*(self.nets[i].biases[x].max()-self.nets[i].biases[x].min())
            self.nets[i].biases = copy.deepcopy(biases)

    def employeed_phase(self,Xc,yc):
        nets = copy.deepcopy(self.nets)
        for i in range(self.n_pops):
            r = list(range(0,i)) + list(range(i+1,self.n_pops))
            coceg = random.choice(r)
            fi1 = random.uniform(-1,1)
            fi2 = random.uniform(-1,1)
            nn = copy.deepcopy(self.nets[i])
            for t in range(1):
                # get some random points
                layer1, point1 = self.get_random_point('bias')
                # replace genetic (bias) with mother's value
                nn.biases[layer1][point1] = nn.biases[layer1][point1] + fi1*(nn.biases[layer1][point1]-self.nets[coceg].biases[layer1][point1])
                layer2, point2 = self.get_random_point('weight')
                # replace genetic (weights) with mother's value
                nn.weights[layer2][point2] = nn.weights[layer2][point2] + fi2*(nn.weights[layer2][point2]-self.nets[coceg].weights[layer2][point2])
            if(nn.score_vector(Xc,yc)>nets[i].score_vector(Xc,yc)):
                nn.counter = 0
                nets[i] = copy.deepcopy(nn)
            else:
                nets[i].counter += 1
        self.nets = copy.deepcopy(nets)
        
    def onlooked_phase(self,Xc,yc):
        all_scores_vector = self.get_all_scores_vector(Xc,yc)
        sum = np.sum(all_scores_vector)
        probability = all_scores_vector/sum
        nets = copy.deepcopy(self.nets)
        for i in range(self.n_pops):
            index_solution = np.random.choice(list(range(self.n_pops)),p=probability)
            r = list(range(0,index_solution)) + list(range(index_solution+1,self.n_pops))
            coceg = random.choice(r)
            fi1 = random.uniform(-1,1)
            fi2 = random.uniform(-1,1)
            nn = copy.deepcopy(self.nets[index_solution])
            for t in range(1):
                # get some random points
                layer1, point1 = self.get_random_point('bias')
                # replace genetic (bias) with mother's value
                nn.biases[layer1][point1] = nn.biases[layer1][point1] + fi1*(nn.biases[layer1][point1]-self.nets[coceg].biases[layer1][point1])
                layer2, point2 = self.get_random_point('weight')
                # replace genetic (weights) with mother's value
                nn.weights[layer2][point2] = nn.weights[layer2][point2] + fi2*(nn.weights[layer2][point2]-self.nets[coceg].weights[layer2][point2])
            if(nn.score_vector(Xc,yc)>nets[index_solution].score_vector(Xc,yc)):
                nn.counter = 0
                nets[index_solution] = copy.deepcopy(nn)
            else:
                nets[index_solution].counter += 1
        self.nets = copy.deepcopy(nets)

    def scout_phase(self):
        for i in range(self.n_pops):
            if self.nets[i].counter > self.limit:
                weight = copy.deepcopy(self.nets[i].weights)
                for x in range(len(weight)):
                    for y in range(len(weight[x])):
                        for z in range(len(weight[x][y])):
                            weight[x][y][z]=self.nets[i].weights[x][y].min() + np.random.rand()*(self.nets[i].weights[x][y].max()-self.nets[i].weights[x][y].min())
                self.nets[i].weights = copy.deepcopy(weight)
                biases = copy.deepcopy(self.nets[i].biases)
                for x in range(len(biases)):
                    for y in range(len(biases[x])):
                        for z in range(len(biases[x][y])):
                            biases[x][y][z]=self.nets[i].biases[x].min() + np.random.rand()*(self.nets[i].biases[x].max()-self.nets[i].biases[x].min())
                self.nets[i].biases = copy.deepcopy(biases)
                self.nets[i].counter = 0
                
    def sort_nets(self,Xc,yc):
        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])

        # exclude score as it is not needed anymore
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        start_time = time.time()
        self.initialization_phase()
        for t in range(20):
            print("Current iteration : {}".format(t+1))
            for i in range(10):
                j1=i*100
                j2=(1+i)*100
                Xc=self.X[j1:j2,:]
                yc=self.y[j1:j2,:]
                for k in range(20):  
                    self.employeed_phase(Xc,yc)
                    self.onlooked_phase(Xc,yc)
                    self.scout_phase()
                    self.sort_nets(Xc,yc)
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.best.score(self.X,self.y))
                print("Current top member's network accuracy: %.2f%%\n" % self.best.accuracy(self.X,self.y))

# %%
df = pd.read_csv("data_(8-8).csv")

# %%
X = df.iloc[:1000, :8].values
y = df.iloc[:1000, 8:16].values
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
N_POPS = 100
NET_SIZE = [8,8,8]

# %%
nnabc = NN_ABC_Algo(N_POPS, NET_SIZE, X, y)
nnabc.evolve()
# Out:
# Current iteration : 1
# Time taken by far : 36.9 seconds
# Current top member's network score: 1.49463
# Current top member's network accuracy: 0.00%
#
# Time taken by far : 73.8 seconds
# Current top member's network score: 1.39241
# Current top member's network accuracy: 14.00%
#
# Time taken by far : 109.0 seconds
# Current top member's network score: 1.34891
# Current top member's network accuracy: 3.00%
#
# Time taken by far : 145.6 seconds
# Current top member's network score: 1.28703
# Current top member's network accuracy: 1.00%
#
# Time taken by far : 182.4 seconds
# Current top member's network score: 1.16454
# Current top member's network accuracy: 31.00%
#
# Time taken by far : 219.0 seconds
# Current top member's network score: 1.07451
# Current top member's network accuracy: 25.00%
#
# Time taken by far : 255.1 seconds
# Current top member's network score: 1.16460
# Current top member's network accuracy: 23.00%
#
# Time taken by far : 290.6 seconds
# Current top member's network score: 1.06945
# Current top member's network accuracy: 17.00%
#
# Time taken by far : 327.7 seconds
# Current top member's network score: 1.08543
# Current top member's network accuracy: 6.00%
#
# Time taken by far : 369.2 seconds
# Current top member's network score: 0.94103
# Current top member's network accuracy: 32.00%
#
# Current iteration : 2
# Time taken by far : 412.1 seconds
# Current top member's network score: 1.08004
# Current top member's network accuracy: 27.00%
#
# Time taken by far : 454.5 seconds
# Current top member's network score: 0.98086
# Current top member's network accuracy: 30.00%
#
# Time taken by far : 497.6 seconds
# Current top member's network score: 0.99822
# Current top member's network accuracy: 28.00%
#
# Time taken by far : 540.5 seconds
# Current top member's network score: 0.97813
# Current top member's network accuracy: 35.00%
#
# Time taken by far : 583.0 seconds
# Current top member's network score: 0.81100
# Current top member's network accuracy: 51.00%
# C:\Users\nguye\AppData\Local\Temp/ipykernel_7212/79852835.py:20: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# Time taken by far : 626.1 seconds
# Current top member's network score: 0.81119
# Current top member's network accuracy: 46.00%
#
# Time taken by far : 669.3 seconds
# Current top member's network score: 0.78256
# Current top member's network accuracy: 60.00%
#
# Time taken by far : 711.8 seconds
# Current top member's network score: 0.70576
# Current top member's network accuracy: 57.00%
#
# Time taken by far : 754.6 seconds
# Current top member's network score: 0.80831
# Current top member's network accuracy: 49.00%
#
# Time taken by far : 797.7 seconds
# Current top member's network score: 0.75249
# Current top member's network accuracy: 51.00%
#
# Current iteration : 3
# Time taken by far : 840.9 seconds
# Current top member's network score: 0.72492
# Current top member's network accuracy: 52.00%
#
# Time taken by far : 884.7 seconds
# Current top member's network score: 0.82442
# Current top member's network accuracy: 48.00%
#
# Time taken by far : 928.5 seconds
# Current top member's network score: 0.79584
# Current top member's network accuracy: 46.00%
#
# Time taken by far : 971.1 seconds
# Current top member's network score: 0.79489
# Current top member's network accuracy: 51.00%
#
# Time taken by far : 1017.0 seconds
# Current top member's network score: 0.69332
# Current top member's network accuracy: 55.00%
#
# Time taken by far : 1061.0 seconds
# Current top member's network score: 0.74096
# Current top member's network accuracy: 59.00%
#
# Time taken by far : 1103.8 seconds
# Current top member's network score: 0.74684
# Current top member's network accuracy: 53.00%
#
# Time taken by far : 1147.3 seconds
# Current top member's network score: 0.58154
# Current top member's network accuracy: 64.00%
#
# Time taken by far : 1190.9 seconds
# Current top member's network score: 0.66011
# Current top member's network accuracy: 60.00%
#
# Time taken by far : 1234.0 seconds
# Current top member's network score: 0.61362
# Current top member's network accuracy: 56.00%
#
# Current iteration : 4
# Time taken by far : 1278.2 seconds
# Current top member's network score: 0.65630
# Current top member's network accuracy: 61.00%
#
# Time taken by far : 1322.2 seconds
# Current top member's network score: 0.65205
# Current top member's network accuracy: 68.00%
#
# Time taken by far : 1365.9 seconds
# Current top member's network score: 0.67620
# Current top member's network accuracy: 64.00%
#
# Time taken by far : 1410.0 seconds
# Current top member's network score: 0.69416
# Current top member's network accuracy: 43.00%
#
# Time taken by far : 1454.4 seconds
# Current top member's network score: 0.57741
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 1497.8 seconds
# Current top member's network score: 0.55304
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 1542.1 seconds
# Current top member's network score: 0.64123
# Current top member's network accuracy: 62.00%
#
# Time taken by far : 1586.5 seconds
# Current top member's network score: 0.50155
# Current top member's network accuracy: 71.00%
#
# Time taken by far : 1630.1 seconds
# Current top member's network score: 0.62716
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 1674.8 seconds
# Current top member's network score: 0.55640
# Current top member's network accuracy: 72.00%
#
# Current iteration : 5
# Time taken by far : 1719.6 seconds
# Current top member's network score: 0.61252
# Current top member's network accuracy: 71.00%
#
# Time taken by far : 1764.1 seconds
# Current top member's network score: 0.62885
# Current top member's network accuracy: 68.00%
#
# Time taken by far : 1809.3 seconds
# Current top member's network score: 0.65624
# Current top member's network accuracy: 54.00%
#
# Time taken by far : 1859.3 seconds
# Current top member's network score: 0.58992
# Current top member's network accuracy: 70.00%
#
# Time taken by far : 1902.4 seconds
# Current top member's network score: 0.48902
# Current top member's network accuracy: 78.00%
#
# Time taken by far : 1941.6 seconds
# Current top member's network score: 0.46133
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 1982.2 seconds
# Current top member's network score: 0.61599
# Current top member's network accuracy: 68.00%
#
# Time taken by far : 2021.3 seconds
# Current top member's network score: 0.43314
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 2059.5 seconds
# Current top member's network score: 0.58278
# Current top member's network accuracy: 56.00%
#
# Time taken by far : 2097.5 seconds
# Current top member's network score: 0.49795
# Current top member's network accuracy: 71.00%
#
# Current iteration : 6
# Time taken by far : 2133.3 seconds
# Current top member's network score: 0.58428
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 2169.5 seconds
# Current top member's network score: 0.48933
# Current top member's network accuracy: 70.00%
#
# Time taken by far : 2208.2 seconds
# Current top member's network score: 0.59054
# Current top member's network accuracy: 71.00%
#
# Time taken by far : 2244.5 seconds
# Current top member's network score: 0.52997
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 2280.0 seconds
# Current top member's network score: 0.47250
# Current top member's network accuracy: 74.00%
#
# Time taken by far : 2316.4 seconds
# Current top member's network score: 0.41666
# Current top member's network accuracy: 76.00%
#
# Time taken by far : 2351.2 seconds
# Current top member's network score: 0.51331
# Current top member's network accuracy: 74.00%
#
# Time taken by far : 2386.6 seconds
# Current top member's network score: 0.43025
# Current top member's network accuracy: 76.00%
#
# Time taken by far : 2421.8 seconds
# Current top member's network score: 0.53850
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 2457.9 seconds
# Current top member's network score: 0.41365
# Current top member's network accuracy: 81.00%
#
# Current iteration : 7
# Time taken by far : 2493.4 seconds
# Current top member's network score: 0.49984
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 2529.7 seconds
# Current top member's network score: 0.52113
# Current top member's network accuracy: 76.00%
#
# Time taken by far : 2565.9 seconds
# Current top member's network score: 0.55046
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 2602.3 seconds
# Current top member's network score: 0.52675
# Current top member's network accuracy: 69.00%
#
# Time taken by far : 2637.9 seconds
# Current top member's network score: 0.42412
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 2673.5 seconds
# Current top member's network score: 0.42287
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 2710.0 seconds
# Current top member's network score: 0.44242
# Current top member's network accuracy: 74.00%
#
# Time taken by far : 2748.0 seconds
# Current top member's network score: 0.40655
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 2784.0 seconds
# Current top member's network score: 0.48941
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 2819.3 seconds
# Current top member's network score: 0.42441
# Current top member's network accuracy: 82.00%
#
# Current iteration : 8
# Time taken by far : 2856.1 seconds
# Current top member's network score: 0.47530
# Current top member's network accuracy: 74.00%
#
# Time taken by far : 2891.2 seconds
# Current top member's network score: 0.50200
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 2927.5 seconds
# Current top member's network score: 0.52655
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 2963.6 seconds
# Current top member's network score: 0.49280
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 3000.0 seconds
# Current top member's network score: 0.41702
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 3037.1 seconds
# Current top member's network score: 0.45407
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 3074.4 seconds
# Current top member's network score: 0.55156
# Current top member's network accuracy: 78.00%
#
# Time taken by far : 3110.7 seconds
# Current top member's network score: 0.45949
# Current top member's network accuracy: 71.00%
#
# Time taken by far : 3146.6 seconds
# Current top member's network score: 0.50276
# Current top member's network accuracy: 73.00%
# Time taken by far : 3183.0 seconds
# Current top member's network score: 0.42152
# Current top member's network accuracy: 79.00%
#
# Current iteration : 9
# Time taken by far : 3220.9 seconds
# Current top member's network score: 0.49321
# Current top member's network accuracy: 70.00%
#
# Time taken by far : 3257.3 seconds
# Current top member's network score: 0.47683
# Current top member's network accuracy: 78.00%
#
# Time taken by far : 3293.8 seconds
# Current top member's network score: 0.58641
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 3331.5 seconds
# Current top member's network score: 0.46350
# Current top member's network accuracy: 81.00%
#
# Time taken by far : 3369.6 seconds
# Current top member's network score: 0.35819
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 3408.8 seconds
# Current top member's network score: 0.45720
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 3451.6 seconds
# Current top member's network score: 0.47064
# Current top member's network accuracy: 69.00%
#
# Time taken by far : 3489.9 seconds
# Current top member's network score: 0.44163
# Current top member's network accuracy: 78.00%
#
# Time taken by far : 3530.4 seconds
# Current top member's network score: 0.44023
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 3570.0 seconds
# Current top member's network score: 0.35049
# Current top member's network accuracy: 76.00%
#
# Current iteration : 10
# Time taken by far : 3607.7 seconds
# Current top member's network score: 0.45506
# Current top member's network accuracy: 76.00%
#
# Time taken by far : 3645.5 seconds
# Current top member's network score: 0.46744
# Current top member's network accuracy: 74.00%
#
# Time taken by far : 3684.4 seconds
# Current top member's network score: 0.51606
# Current top member's network accuracy: 71.00%
#
# Time taken by far : 3722.9 seconds
# Current top member's network score: 0.46585
# Current top member's network accuracy: 68.00%
#
# Time taken by far : 3762.0 seconds
# Current top member's network score: 0.36972
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 3801.2 seconds
# Current top member's network score: 0.36015
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 3839.4 seconds
# Current top member's network score: 0.46646
# Current top member's network accuracy: 76.00%
#
# Time taken by far : 3878.4 seconds
# Current top member's network score: 0.42118
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 3919.2 seconds
# Current top member's network score: 0.46481
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 3963.1 seconds
# Current top member's network score: 0.31259
# Current top member's network accuracy: 76.00%
#
# Current iteration : 11
# Time taken by far : 4004.2 seconds
# Current top member's network score: 0.40834
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 4044.6 seconds
# Current top member's network score: 0.46726
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 4084.5 seconds
# Current top member's network score: 0.57271
# Current top member's network accuracy: 68.00%
#
# Time taken by far : 4127.8 seconds
# Current top member's network score: 0.46194
# Current top member's network accuracy: 74.00%
#
# Time taken by far : 4167.0 seconds
# Current top member's network score: 0.39037
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 4208.4 seconds
# Current top member's network score: 0.38410
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 4250.8 seconds
# Current top member's network score: 0.42911
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 4291.7 seconds
# Current top member's network score: 0.42636
# Current top member's network accuracy: 78.00%
#
# Time taken by far : 4330.7 seconds
# Current top member's network score: 0.42075
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 4370.9 seconds
# Current top member's network score: 0.26040
# Current top member's network accuracy: 86.00%
#
# Current iteration : 12
# Time taken by far : 4410.5 seconds
# Current top member's network score: 0.40085
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 4449.9 seconds
# Current top member's network score: 0.39303
# Current top member's network accuracy: 81.00%
#
# Time taken by far : 4490.0 seconds
# Current top member's network score: 0.51312
# Current top member's network accuracy: 76.00%
#
# Time taken by far : 4530.4 seconds
# Current top member's network score: 0.42675
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 4570.8 seconds
# Current top member's network score: 0.38086
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 4610.9 seconds
# Current top member's network score: 0.31004
# Current top member's network accuracy: 87.00%
#
# Time taken by far : 4650.9 seconds
# Current top member's network score: 0.43287
# Current top member's network accuracy: 76.00%
#
# Time taken by far : 4692.0 seconds
# Current top member's network score: 0.42820
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 4732.8 seconds
# Current top member's network score: 0.32859
# Current top member's network accuracy: 88.00%
#
# Time taken by far : 4773.5 seconds
# Current top member's network score: 0.29910
# Current top member's network accuracy: 79.00%
#
# Current iteration : 13
# Time taken by far : 4812.8 seconds
# Current top member's network score: 0.43562
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 4854.2 seconds
# Current top member's network score: 0.40826
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 4894.0 seconds
# Current top member's network score: 0.53907
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 4934.0 seconds
# Current top member's network score: 0.39089
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 4973.4 seconds
# Current top member's network score: 0.39508
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 5013.1 seconds
# Current top member's network score: 0.37605
# Current top member's network accuracy: 81.00%
#
# Time taken by far : 5051.9 seconds
# Current top member's network score: 0.42106
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 5091.7 seconds
# Current top member's network score: 0.41821
# Current top member's network accuracy: 74.00%
#
# Time taken by far : 5131.4 seconds
# Current top member's network score: 0.46329
# Current top member's network accuracy: 74.00%
#
# Time taken by far : 5175.4 seconds
# Current top member's network score: 0.37529
# Current top member's network accuracy: 82.00%
#
# Current iteration : 14
# Time taken by far : 5220.4 seconds
# Current top member's network score: 0.45633
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 5266.9 seconds
# Current top member's network score: 0.42179
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 5314.7 seconds
# Current top member's network score: 0.58078
# Current top member's network accuracy: 78.00%
#
# Time taken by far : 5353.8 seconds
# Current top member's network score: 0.40351
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 5390.8 seconds
# Current top member's network score: 0.38391
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 5432.2 seconds
# Current top member's network score: 0.37578
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 5471.5 seconds
# Current top member's network score: 0.41849
# Current top member's network accuracy: 87.00%
#
# Time taken by far : 5511.2 seconds
# Current top member's network score: 0.41328
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 5554.6 seconds
# Current top member's network score: 0.43411
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 5591.8 seconds
# Current top member's network score: 0.32093
# Current top member's network accuracy: 80.00%
#
# Current iteration : 15
# Time taken by far : 5638.6 seconds
# Current top member's network score: 0.43817
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 5684.0 seconds
# Current top member's network score: 0.45993
# Current top member's network accuracy: 69.00%
#
# Time taken by far : 5736.9 seconds
# Current top member's network score: 0.54556
# Current top member's network accuracy: 76.00%
# Time taken by far : 5788.8 seconds
# Current top member's network score: 0.46727
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 5845.8 seconds
# Current top member's network score: 0.38908
# Current top member's network accuracy: 76.00%
#
# Time taken by far : 5898.1 seconds
# Current top member's network score: 0.31634
# Current top member's network accuracy: 89.00%
#
# Time taken by far : 5950.2 seconds
# Current top member's network score: 0.45970
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 5998.2 seconds
# Current top member's network score: 0.34838
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 6044.1 seconds
# Current top member's network score: 0.44214
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 6088.6 seconds
# Current top member's network score: 0.30837
# Current top member's network accuracy: 77.00%
#
# Current iteration : 16
# Time taken by far : 6134.4 seconds
# Current top member's network score: 0.45458
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 6184.3 seconds
# Current top member's network score: 0.44906
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 6231.7 seconds
# Current top member's network score: 0.51110
# Current top member's network accuracy: 67.00%
#
# Time taken by far : 6277.5 seconds
# Current top member's network score: 0.46955
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 6322.7 seconds
# Current top member's network score: 0.40132
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 6367.5 seconds
# Current top member's network score: 0.35057
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 6413.3 seconds
# Current top member's network score: 0.46258
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 6459.3 seconds
# Current top member's network score: 0.37610
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 6504.4 seconds
# Current top member's network score: 0.46263
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 6550.5 seconds
# Current top member's network score: 0.29919
# Current top member's network accuracy: 89.00%
#
# Current iteration : 17
# Time taken by far : 6595.7 seconds
# Current top member's network score: 0.42565
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 6640.7 seconds
# Current top member's network score: 0.40119
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 6686.0 seconds
# Current top member's network score: 0.58026
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 6730.7 seconds
# Current top member's network score: 0.45543
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 6775.4 seconds
# Current top member's network score: 0.34306
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 6820.7 seconds
# Current top member's network score: 0.33075
# Current top member's network accuracy: 88.00%
#
# Time taken by far : 6867.0 seconds
# Current top member's network score: 0.45040
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 6911.6 seconds
# Current top member's network score: 0.44589
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 6956.4 seconds
# Current top member's network score: 0.43997
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 7002.0 seconds
# Current top member's network score: 0.35837
# Current top member's network accuracy: 79.00%
#
# Current iteration : 18
# Time taken by far : 7047.1 seconds
# Current top member's network score: 0.49118
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 7092.4 seconds
# Current top member's network score: 0.45941
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 7138.5 seconds
# Current top member's network score: 0.56527
# Current top member's network accuracy: 78.00%
#
# Time taken by far : 7185.0 seconds
# Current top member's network score: 0.43654
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 7230.4 seconds
# Current top member's network score: 0.33129
# Current top member's network accuracy: 89.00%
#
# Time taken by far : 7272.7 seconds
# Current top member's network score: 0.39536
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 7313.9 seconds
# Current top member's network score: 0.45035
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 7353.9 seconds
# Current top member's network score: 0.46437
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 7396.0 seconds
# Current top member's network score: 0.45454
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 7437.2 seconds
# Current top member's network score: 0.32691
# Current top member's network accuracy: 89.00%
#
# Current iteration : 19
# Time taken by far : 7480.2 seconds
# Current top member's network score: 0.51743
# Current top member's network accuracy: 81.00%
#
# Time taken by far : 7521.5 seconds
# Current top member's network score: 0.46114
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 7563.9 seconds
# Current top member's network score: 0.58366
# Current top member's network accuracy: 67.00%
#
# Time taken by far : 7606.8 seconds
# Current top member's network score: 0.40948
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 7653.2 seconds
# Current top member's network score: 0.32998
# Current top member's network accuracy: 90.00%
#
# Time taken by far : 7697.3 seconds
# Current top member's network score: 0.39545
# Current top member's network accuracy: 81.00%
#
# Time taken by far : 7749.4 seconds
# Current top member's network score: 0.46542
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 7800.8 seconds
# Current top member's network score: 0.31990
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 7847.1 seconds
# Current top member's network score: 0.43366
# Current top member's network accuracy: 81.00%
#
# Time taken by far : 7892.2 seconds
# Current top member's network score: 0.37733
# Current top member's network accuracy: 87.00%
#
# Current iteration : 20
# Time taken by far : 7938.1 seconds
# Current top member's network score: 0.51809
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 7987.4 seconds
# Current top member's network score: 0.40856
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 8038.0 seconds
# Current top member's network score: 0.58287
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 8087.6 seconds
# Current top member's network score: 0.38420
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 8135.8 seconds
# Current top member's network score: 0.28655
# Current top member's network accuracy: 89.00%
#
# Time taken by far : 8186.5 seconds
# Current top member's network score: 0.38601
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 8239.2 seconds
# Current top member's network score: 0.48068
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 8288.9 seconds
# Current top member's network score: 0.34538
# Current top member's network accuracy: 89.00%
#
# Time taken by far : 8339.5 seconds
# Current top member's network score: 0.46317
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 8389.3 seconds
# Current top member's network score: 0.33267
# Current top member's network accuracy: 84.00%
#
# Current iteration : 21
# Time taken by far : 8443.2 seconds
# Current top member's network score: 0.49872
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 8492.8 seconds
# Current top member's network score: 0.45945
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 8540.5 seconds
# Current top member's network score: 0.57184
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 8593.8 seconds
# Current top member's network score: 0.46774
# Current top member's network accuracy: 70.00%
#
# Time taken by far : 8646.3 seconds
# Current top member's network score: 0.36803
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 8696.0 seconds
# Current top member's network score: 0.33510
# Current top member's network accuracy: 88.00%
#
# Time taken by far : 8747.1 seconds
# Current top member's network score: 0.45850
# Current top member's network accuracy: 82.00%
# Time taken by far : 8797.9 seconds
# Current top member's network score: 0.40360
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 8848.7 seconds
# Current top member's network score: 0.48803
# Current top member's network accuracy: 81.00%
#
# Time taken by far : 8896.8 seconds
# Current top member's network score: 0.31187
# Current top member's network accuracy: 82.00%
#
# Current iteration : 22
# Time taken by far : 8945.2 seconds
# Current top member's network score: 0.45598
# Current top member's network accuracy: 78.00%
#
# Time taken by far : 8994.8 seconds
# Current top member's network score: 0.44406
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 9046.1 seconds
# Current top member's network score: 0.58992
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 9092.7 seconds
# Current top member's network score: 0.45696
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 9132.0 seconds
# Current top member's network score: 0.36714
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 9171.7 seconds
# Current top member's network score: 0.36089
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 9210.2 seconds
# Current top member's network score: 0.44554
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 9249.1 seconds
# Current top member's network score: 0.43932
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 9288.6 seconds
# Current top member's network score: 0.45877
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 9326.5 seconds
# Current top member's network score: 0.29787
# Current top member's network accuracy: 89.00%
#
# Current iteration : 23
# Time taken by far : 9367.3 seconds
# Current top member's network score: 0.42258
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 9407.9 seconds
# Current top member's network score: 0.39947
# Current top member's network accuracy: 86.00%
#
# Time taken by far : 9447.8 seconds
# Current top member's network score: 0.45319
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 9488.5 seconds
# Current top member's network score: 0.48188
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 9530.6 seconds
# Current top member's network score: 0.43037
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 9569.4 seconds
# Current top member's network score: 0.40709
# Current top member's network accuracy: 72.00%
#
# Time taken by far : 9607.0 seconds
# Current top member's network score: 0.47211
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 9645.6 seconds
# Current top member's network score: 0.37498
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 9686.6 seconds
# Current top member's network score: 0.42001
# Current top member's network accuracy: 80.00%
#
# Time taken by far : 9727.2 seconds
# Current top member's network score: 0.39599
# Current top member's network accuracy: 83.00%
#
# Current iteration : 24
# Time taken by far : 9766.4 seconds
# Current top member's network score: 0.46586
# Current top member's network accuracy: 73.00%
#
# Time taken by far : 9806.5 seconds
# Current top member's network score: 0.40843
# Current top member's network accuracy: 87.00%
#
# Time taken by far : 9846.1 seconds
# Current top member's network score: 0.57917
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 9887.9 seconds
# Current top member's network score: 0.43697
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 9926.3 seconds
# Current top member's network score: 0.45870
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 9967.5 seconds
# Current top member's network score: 0.33730
# Current top member's network accuracy: 89.00%
#
# Time taken by far : 10009.7 seconds
# Current top member's network score: 0.44154
# Current top member's network accuracy: 81.00%
#
# Time taken by far : 10051.8 seconds
# Current top member's network score: 0.36487
# Current top member's network accuracy: 84.00%
#
# Time taken by far : 10097.3 seconds
# Current top member's network score: 0.44485
# Current top member's network accuracy: 82.00%
#
# Time taken by far : 10139.1 seconds
# Current top member's network score: 0.37665
# Current top member's network accuracy: 89.00%
#
# Current iteration : 25
# Time taken by far : 10180.7 seconds
# Current top member's network score: 0.50838
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 10220.9 seconds
# Current top member's network score: 0.36168
# Current top member's network accuracy: 87.00%
#
# Time taken by far : 10261.4 seconds
# Current top member's network score: 0.55874
# Current top member's network accuracy: 75.00%
#
# Time taken by far : 10302.6 seconds
# Current top member's network score: 0.47435
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 10341.4 seconds
# Current top member's network score: 0.39606
# Current top member's network accuracy: 87.00%
#
# Time taken by far : 10380.5 seconds
# Current top member's network score: 0.42343
# Current top member's network accuracy: 83.00%
#
# Time taken by far : 10419.5 seconds
# Current top member's network score: 0.45081
# Current top member's network accuracy: 77.00%
#
# Time taken by far : 10458.4 seconds
# Current top member's network score: 0.36510
# Current top member's network accuracy: 85.00%
#
# Time taken by far : 10498.2 seconds
# Current top member's network score: 0.43409
# Current top member's network accuracy: 79.00%
#
# Time taken by far : 10538.3 seconds
# Current top member's network score: 0.34374
# Current top member's network accuracy: 89.00%

# %%
nnabc.best.accuracy(X,y)
# Out:
# C:\Users\nguye\AppData\Local\Temp/ipykernel_7212/79852835.py:20: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))
# 79.5

# %%
X[10].reshape(-1,1)
# Out:
# array([[-0.72343826],
#        [-0.3841888 ],
#        [ 1.54662865],
#        [ 0.72263078],
#        [ 1.17945268],
#        [-0.83053637],
#        [ 0.03090244],
#        [-0.82676313]])

# %%
pred = nnabc.best.feedforward(X[10].reshape(-1,1)).reshape(-1)
# Out:
# C:\Users\nguye\AppData\Local\Temp/ipykernel_7212/79852835.py:20: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))

# %%
for j in range(len(pred)):
    pred[j] = round(pred[j])

# %%
pred
# Out:
# array([0., 1., 0., 0., 0., 0., 1., 0.])

# %%
y[10]
# Out:
# array([0, 1, 0, 0, 0, 0, 1, 0], dtype=int64)

# %%
X_test = df.iloc[5000:6000, :8].values
y_test = df.iloc[5000:6000, 8:16].values
sc = StandardScaler()
X_test = sc.fit_transform(X_test)

# %%
acc = nnabc.best.accuracy(X_test,y_test)
# Out:
# C:\Users\nguye\AppData\Local\Temp/ipykernel_7212/79852835.py:20: RuntimeWarning: overflow encountered in exp
#   return 1.0/(1.0+np.exp(-z))

# %%
acc
# Out:
# 78.10000000000001
