# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt

# %%
class Network(object):

    def __init__(self, sizes):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])

    def feedforward(self, a):
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
        return a

    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = (self.feedforward(X[i].reshape(-1,1))).reshape(-1)
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

# %%
class NNGeneticAlgo:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, X, y, X_test, y_test):
        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.X = X[:]
        self.y = y[:]
        self.X_test = X_test[:]
        self.y_test = y_test[:]
        self.accuracy_train = []
        self.accuracy_test = []
        self.best = Network(self.net_size)
            
    def get_random_point(self, type):
        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc,yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc,yc) for net in self.nets]

    def crossover(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.crossover_rate:
                father = random.randint(0,self.n_pops-1)
                mother = random.randint(0,self.n_pops-1)
                # make a copy of father 'genetic' weights & biases information
                nn_1 = copy.deepcopy(self.nets[father])
                nn_2 = copy.deepcopy(self.nets[mother])
                # cross-over bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # replace genetic (bias) with mother's value
                    nn_1.biases[layer][point] = self.nets[mother].biases[layer][point]
                    nn_2.biases[layer][point] = self.nets[father].biases[layer][point]

                # cross-over weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # replace genetic (weight) with mother's value
                    nn_1.weights[layer][point] = self.nets[mother].weights[layer][point]
                    nn_2.weights[layer][point] = self.nets[father].weights[layer][point]
                self.nets.append(copy.deepcopy(nn_1))
                self.nets.append(copy.deepcopy(nn_2))
        
    def mutation(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.mutation_rate:
                origin = random.randint(0,self.n_pops-1)
                nn = copy.deepcopy(self.nets[origin])

                # mutate bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # add some random value between -0.5 and 0.5
                    nn.biases[layer][point] += random.uniform(-0.5, 0.5)

                # mutate weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # add some random value between -0.5 and 0.5
                    nn.weights[layer][point[0], point[1]] += random.uniform(-0.5, 0.5)
                self.nets.append(copy.deepcopy(nn))
        
    def selection(self,Xc,yc):
        nets_new=[]
        for i in range(self.n_pops):
            k_1 = random.randint(0,len(self.nets)-1)
            k_2 = random.randint(0,len(self.nets)-1)
            if(self.nets[k_1].score(Xc,yc)<self.nets[k_2].score(Xc,yc)):
                nets_new.append(self.nets[k_1])
            else:
                nets_new.append(self.nets[k_2])
        self.nets = copy.deepcopy(nets_new)
    
    def sort_nets(self,Xc,yc):
        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])

        # exclude score as it is not needed anymore
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        start_time = time.time()
        for t in range(25):
            self.accuracy_train.append(self.best.accuracy(self.X,self.y))
            self.accuracy_test.append(self.best.accuracy(self.X_test,self.y_test))
            for i in range(20):
                j1=i*40
                j2=(1+i)*40
                Xc=self.X[j1:j2,:]
                yc=self.y[j1:j2,:]
                for k in range(25): 
                    self.crossover()
                    self.mutation()
                    self.selection(Xc,yc)
                    self.sort_nets(Xc,yc)
                print("Current iteration : {}, batch : {}".format(t+1,i+1))
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.best.score(self.X,self.y))
                print("Current top member's network accuracy: %.2f%%\n" % self.best.accuracy(self.X,self.y))

# %%
df = pd.read_csv("../Data/data_(8-8).csv")

# %%
X = df.iloc[:800, :8].values
y = df.iloc[:800, 8:16].values
sc = StandardScaler()
X = sc.fit_transform(X)
X_test = df.iloc[800:1000, :8].values
y_test = df.iloc[800:1000, 8:16].values
sc = StandardScaler()
X_test = sc.fit_transform(X_test)

# %%
N_POPS = 100
NET_SIZE = [8,8,8]
MUTATION_RATE = 0.1
CROSSOVER_RATE = 0.8
nnga = NNGeneticAlgo(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, X, y, X_test, y_test)
nnga.evolve()
# Out:
# Current iteration : 1, batch : 1
# Time taken by far : 12.2 seconds
# Current top member's network score: 1.26197
# Current top member's network accuracy: 24.00%
#
# Current iteration : 1, batch : 2
# Time taken by far : 23.9 seconds
# Current top member's network score: 0.95990
# Current top member's network accuracy: 32.62%
#
# Current iteration : 1, batch : 3
# Time taken by far : 35.4 seconds
# Current top member's network score: 0.93791
# Current top member's network accuracy: 38.75%
#
# Current iteration : 1, batch : 4
# Time taken by far : 46.3 seconds
# Current top member's network score: 0.82600
# Current top member's network accuracy: 44.00%
#
# Current iteration : 1, batch : 5
# Time taken by far : 58.5 seconds
# Current top member's network score: 0.75714
# Current top member's network accuracy: 51.88%
#
# Current iteration : 1, batch : 6
# Time taken by far : 71.8 seconds
# Current top member's network score: 0.70703
# Current top member's network accuracy: 56.75%
#
# Current iteration : 1, batch : 7
# Time taken by far : 82.6 seconds
# Current top member's network score: 0.68139
# Current top member's network accuracy: 59.50%
#
# Current iteration : 1, batch : 8
# Time taken by far : 93.8 seconds
# Current top member's network score: 0.62154
# Current top member's network accuracy: 65.38%
#
# Current iteration : 1, batch : 9
# Time taken by far : 104.5 seconds
# Current top member's network score: 0.59016
# Current top member's network accuracy: 66.88%
#
# Current iteration : 1, batch : 10
# Time taken by far : 118.1 seconds
# Current top member's network score: 0.56780
# Current top member's network accuracy: 68.62%
#
# Current iteration : 1, batch : 11
# Time taken by far : 129.4 seconds
# Current top member's network score: 0.53850
# Current top member's network accuracy: 71.12%
#
# Current iteration : 1, batch : 12
# Time taken by far : 141.4 seconds
# Current top member's network score: 0.52332
# Current top member's network accuracy: 71.62%
#
# Current iteration : 1, batch : 13
# Time taken by far : 152.1 seconds
# Current top member's network score: 0.53607
# Current top member's network accuracy: 71.88%
#
# Current iteration : 1, batch : 14
# Time taken by far : 162.7 seconds
# Current top member's network score: 0.49210
# Current top member's network accuracy: 74.62%
#
# Current iteration : 1, batch : 15
# Time taken by far : 173.8 seconds
# Current top member's network score: 0.48243
# Current top member's network accuracy: 74.75%
#
# Current iteration : 1, batch : 16
# Time taken by far : 185.7 seconds
# Current top member's network score: 0.45454
# Current top member's network accuracy: 76.75%
#
# Current iteration : 1, batch : 17
# Time taken by far : 197.1 seconds
# Current top member's network score: 0.45454
# Current top member's network accuracy: 76.75%
#
# Current iteration : 1, batch : 18
# Time taken by far : 208.1 seconds
# Current top member's network score: 0.44289
# Current top member's network accuracy: 77.75%
#
# Current iteration : 1, batch : 19
# Time taken by far : 219.8 seconds
# Current top member's network score: 0.44289
# Current top member's network accuracy: 77.75%
#
# Current iteration : 1, batch : 20
# Time taken by far : 231.3 seconds
# Current top member's network score: 0.43484
# Current top member's network accuracy: 79.00%
#
# Current iteration : 2, batch : 1
# Time taken by far : 242.0 seconds
# Current top member's network score: 0.42580
# Current top member's network accuracy: 80.12%
#
# Current iteration : 2, batch : 2
# Time taken by far : 253.7 seconds
# Current top member's network score: 0.42580
# Current top member's network accuracy: 80.12%
#
# Current iteration : 2, batch : 3
# Time taken by far : 264.8 seconds
# Current top member's network score: 0.42580
# Current top member's network accuracy: 80.12%
#
# Current iteration : 2, batch : 4
# Time taken by far : 275.9 seconds
# Current top member's network score: 0.42580
# Current top member's network accuracy: 80.12%
#
# Current iteration : 2, batch : 5
# Time taken by far : 286.9 seconds
# Current top member's network score: 0.42580
# Current top member's network accuracy: 80.12%
#
# Current iteration : 2, batch : 6
# Time taken by far : 298.3 seconds
# Current top member's network score: 0.41251
# Current top member's network accuracy: 80.38%
#
# Current iteration : 2, batch : 7
# Time taken by far : 309.3 seconds
# Current top member's network score: 0.41993
# Current top member's network accuracy: 80.62%
#
# Current iteration : 2, batch : 8
# Time taken by far : 321.2 seconds
# Current top member's network score: 0.41993
# Current top member's network accuracy: 80.62%
#
# Current iteration : 2, batch : 9
# Time taken by far : 331.6 seconds
# Current top member's network score: 0.38630
# Current top member's network accuracy: 81.12%
#
# Current iteration : 2, batch : 10
# Time taken by far : 342.7 seconds
# Current top member's network score: 0.39692
# Current top member's network accuracy: 81.62%
#
# Current iteration : 2, batch : 11
# Time taken by far : 354.0 seconds
# Current top member's network score: 0.39692
# Current top member's network accuracy: 81.62%
#
# Current iteration : 2, batch : 12
# Time taken by far : 365.7 seconds
# Current top member's network score: 0.39692
# Current top member's network accuracy: 81.62%
#
# Current iteration : 2, batch : 13
# Time taken by far : 377.7 seconds
# Current top member's network score: 0.39692
# Current top member's network accuracy: 81.62%
#
# Current iteration : 2, batch : 14
# Time taken by far : 389.2 seconds
# Current top member's network score: 0.39692
# Current top member's network accuracy: 81.62%
#
# Current iteration : 2, batch : 15
# Time taken by far : 400.4 seconds
# Current top member's network score: 0.39692
# Current top member's network accuracy: 81.62%
#
# Current iteration : 2, batch : 16
# Time taken by far : 412.3 seconds
# Current top member's network score: 0.37659
# Current top member's network accuracy: 83.88%
#
# Current iteration : 2, batch : 17
# Time taken by far : 423.9 seconds
# Current top member's network score: 0.37659
# Current top member's network accuracy: 83.88%
#
# Current iteration : 2, batch : 18
# Time taken by far : 434.9 seconds
# Current top member's network score: 0.37659
# Current top member's network accuracy: 83.88%
#
# Current iteration : 2, batch : 19
# Time taken by far : 445.4 seconds
# Current top member's network score: 0.37659
# Current top member's network accuracy: 83.88%
#
# Current iteration : 2, batch : 20
# Time taken by far : 456.2 seconds
# Current top member's network score: 0.37659
# Current top member's network accuracy: 83.88%
#
# Current iteration : 3, batch : 1
# Time taken by far : 466.9 seconds
# Current top member's network score: 0.34222
# Current top member's network accuracy: 84.00%
#
# Current iteration : 3, batch : 2
# Time taken by far : 477.4 seconds
# Current top member's network score: 0.34222
# Current top member's network accuracy: 84.00%
#
# Current iteration : 3, batch : 3
# Time taken by far : 488.6 seconds
# Current top member's network score: 0.34222
# Current top member's network accuracy: 84.00%
#
# Current iteration : 3, batch : 4
# Time taken by far : 499.3 seconds
# Current top member's network score: 0.34222
# Current top member's network accuracy: 84.00%
#
# Current iteration : 3, batch : 5
# Time taken by far : 510.3 seconds
# Current top member's network score: 0.34222
# Current top member's network accuracy: 84.00%
#
# Current iteration : 3, batch : 6
# Time taken by far : 521.1 seconds
# Current top member's network score: 0.35313
# Current top member's network accuracy: 84.75%
#
# Current iteration : 3, batch : 7
# Time taken by far : 532.4 seconds
# Current top member's network score: 0.35313
# Current top member's network accuracy: 84.75%
#
# Current iteration : 3, batch : 8
# Time taken by far : 543.3 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 9
# Time taken by far : 554.4 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 10
# Time taken by far : 566.1 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 11
# Time taken by far : 577.0 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 12
# Time taken by far : 588.0 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
# Current iteration : 3, batch : 13
# Time taken by far : 598.5 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 14
# Time taken by far : 609.2 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 15
# Time taken by far : 622.6 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 16
# Time taken by far : 634.4 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 17
# Time taken by far : 645.7 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 18
# Time taken by far : 657.0 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 19
# Time taken by far : 668.2 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 3, batch : 20
# Time taken by far : 679.6 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 1
# Time taken by far : 690.8 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 2
# Time taken by far : 701.5 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 3
# Time taken by far : 713.0 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 4
# Time taken by far : 724.1 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 5
# Time taken by far : 735.2 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 6
# Time taken by far : 745.5 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 7
# Time taken by far : 757.2 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 8
# Time taken by far : 768.3 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 9
# Time taken by far : 779.9 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 10
# Time taken by far : 791.8 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 11
# Time taken by far : 803.0 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 12
# Time taken by far : 814.3 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 13
# Time taken by far : 827.5 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 14
# Time taken by far : 838.9 seconds
# Current top member's network score: 0.32463
# Current top member's network accuracy: 85.88%
#
# Current iteration : 4, batch : 15
# Time taken by far : 850.9 seconds
# Current top member's network score: 0.30549
# Current top member's network accuracy: 86.12%
#
# Current iteration : 4, batch : 16
# Time taken by far : 862.2 seconds
# Current top member's network score: 0.30375
# Current top member's network accuracy: 86.75%
#
# Current iteration : 4, batch : 17
# Time taken by far : 873.7 seconds
# Current top member's network score: 0.30375
# Current top member's network accuracy: 86.75%
#
# Current iteration : 4, batch : 18
# Time taken by far : 884.8 seconds
# Current top member's network score: 0.30375
# Current top member's network accuracy: 86.75%
#
# Current iteration : 4, batch : 19
# Time taken by far : 896.2 seconds
# Current top member's network score: 0.30375
# Current top member's network accuracy: 86.75%
#
# Current iteration : 4, batch : 20
# Time taken by far : 907.9 seconds
# Current top member's network score: 0.30375
# Current top member's network accuracy: 86.75%
#
# Current iteration : 5, batch : 1
# Time taken by far : 919.8 seconds
# Current top member's network score: 0.30375
# Current top member's network accuracy: 86.75%
#
# Current iteration : 5, batch : 2
# Time taken by far : 931.2 seconds
# Current top member's network score: 0.30375
# Current top member's network accuracy: 86.75%
#
# Current iteration : 5, batch : 3
# Time taken by far : 942.4 seconds
# Current top member's network score: 0.29090
# Current top member's network accuracy: 86.88%
#
# Current iteration : 5, batch : 4
# Time taken by far : 954.1 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 5
# Time taken by far : 965.2 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 6
# Time taken by far : 976.8 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 7
# Time taken by far : 988.6 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 8
# Time taken by far : 1000.0 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 9
# Time taken by far : 1011.0 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 10
# Time taken by far : 1021.5 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 11
# Time taken by far : 1032.5 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 12
# Time taken by far : 1043.8 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 13
# Time taken by far : 1054.9 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 14
# Time taken by far : 1065.7 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 15
# Time taken by far : 1077.9 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 16
# Time taken by far : 1091.9 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 17
# Time taken by far : 1106.7 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 18
# Time taken by far : 1123.5 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 19
# Time taken by far : 1142.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 5, batch : 20
# Time taken by far : 1163.9 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 1
# Time taken by far : 1185.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 2
# Time taken by far : 1205.8 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 3
# Time taken by far : 1227.9 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 4
# Time taken by far : 1249.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
# Current iteration : 6, batch : 5
# Time taken by far : 1270.1 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 6
# Time taken by far : 1290.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 7
# Time taken by far : 1310.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 8
# Time taken by far : 1329.0 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 9
# Time taken by far : 1347.9 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 10
# Time taken by far : 1368.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 11
# Time taken by far : 1390.0 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 12
# Time taken by far : 1409.7 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 13
# Time taken by far : 1429.8 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 14
# Time taken by far : 1451.2 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 15
# Time taken by far : 1470.5 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 16
# Time taken by far : 1490.9 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 17
# Time taken by far : 1511.2 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 18
# Time taken by far : 1531.6 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 19
# Time taken by far : 1552.0 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 6, batch : 20
# Time taken by far : 1572.9 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 1
# Time taken by far : 1593.8 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 2
# Time taken by far : 1616.1 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 3
# Time taken by far : 1637.2 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 4
# Time taken by far : 1658.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 5
# Time taken by far : 1678.3 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 6
# Time taken by far : 1698.7 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 7
# Time taken by far : 1719.6 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 8
# Time taken by far : 1739.0 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 9
# Time taken by far : 1758.5 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 10
# Time taken by far : 1778.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 11
# Time taken by far : 1798.3 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 12
# Time taken by far : 1817.8 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 13
# Time taken by far : 1839.8 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 14
# Time taken by far : 1861.2 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 15
# Time taken by far : 1882.1 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 16
# Time taken by far : 1903.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 17
# Time taken by far : 1922.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 18
# Time taken by far : 1941.5 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 19
# Time taken by far : 1960.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 7, batch : 20
# Time taken by far : 1980.0 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 8, batch : 1
# Time taken by far : 1999.4 seconds
# Current top member's network score: 0.30229
# Current top member's network accuracy: 87.12%
#
# Current iteration : 8, batch : 2
# Time taken by far : 2018.5 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 3
# Time taken by far : 2039.6 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 4
# Time taken by far : 2061.2 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 5
# Time taken by far : 2081.9 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 6
# Time taken by far : 2103.2 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 7
# Time taken by far : 2124.5 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 8
# Time taken by far : 2145.9 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 9
# Time taken by far : 2165.7 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 10
# Time taken by far : 2185.3 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 11
# Time taken by far : 2204.5 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 12
# Time taken by far : 2223.8 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 13
# Time taken by far : 2243.2 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 14
# Time taken by far : 2267.7 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 15
# Time taken by far : 2291.9 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
#
# Current iteration : 8, batch : 16
# Time taken by far : 2314.0 seconds
# Current top member's network score: 0.26926
# Current top member's network accuracy: 87.50%
# Current iteration : 8, batch : 17
# Time taken by far : 2335.6 seconds
# Current top member's network score: 0.28430
# Current top member's network accuracy: 87.75%
#
# Current iteration : 8, batch : 18
# Time taken by far : 2357.2 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 8, batch : 19
# Time taken by far : 2379.3 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 8, batch : 20
# Time taken by far : 2400.9 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 1
# Time taken by far : 2422.5 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 2
# Time taken by far : 2444.5 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 3
# Time taken by far : 2466.0 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 4
# Time taken by far : 2487.4 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 5
# Time taken by far : 2509.2 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 6
# Time taken by far : 2531.2 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 7
# Time taken by far : 2553.0 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 8
# Time taken by far : 2574.9 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 9
# Time taken by far : 2596.5 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 10
# Time taken by far : 2618.1 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 11
# Time taken by far : 2640.0 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 12
# Time taken by far : 2661.5 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 13
# Time taken by far : 2682.8 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 14
# Time taken by far : 2704.6 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 15
# Time taken by far : 2726.2 seconds
# Current top member's network score: 0.26414
# Current top member's network accuracy: 88.25%
#
# Current iteration : 9, batch : 16
# Time taken by far : 2747.6 seconds
# Current top member's network score: 0.26210
# Current top member's network accuracy: 88.88%
#
# Current iteration : 9, batch : 17
# Time taken by far : 2769.4 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 9, batch : 18
# Time taken by far : 2790.6 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 9, batch : 19
# Time taken by far : 2812.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 9, batch : 20
# Time taken by far : 2834.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 1
# Time taken by far : 2855.7 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 2
# Time taken by far : 2877.3 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 3
# Time taken by far : 2899.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 4
# Time taken by far : 2920.4 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 5
# Time taken by far : 2942.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 6
# Time taken by far : 2963.8 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 7
# Time taken by far : 2985.3 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 8
# Time taken by far : 3006.8 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 9
# Time taken by far : 3028.6 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 10
# Time taken by far : 3050.4 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 11
# Time taken by far : 3071.9 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 12
# Time taken by far : 3093.6 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 13
# Time taken by far : 3115.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 14
# Time taken by far : 3136.8 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 15
# Time taken by far : 3159.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 16
# Time taken by far : 3180.9 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 17
# Time taken by far : 3203.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 18
# Time taken by far : 3225.9 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 19
# Time taken by far : 3248.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 10, batch : 20
# Time taken by far : 3270.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 1
# Time taken by far : 3294.3 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 2
# Time taken by far : 3320.4 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 3
# Time taken by far : 3343.9 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 4
# Time taken by far : 3368.4 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 5
# Time taken by far : 3389.8 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 6
# Time taken by far : 3410.8 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 7
# Time taken by far : 3431.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
# Current iteration : 11, batch : 8
# Time taken by far : 3450.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 9
# Time taken by far : 3469.8 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 10
# Time taken by far : 3489.5 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 11
# Time taken by far : 3508.9 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 12
# Time taken by far : 3528.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 13
# Time taken by far : 3547.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 14
# Time taken by far : 3566.9 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 15
# Time taken by far : 3586.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 16
# Time taken by far : 3605.5 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 17
# Time taken by far : 3624.9 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 18
# Time taken by far : 3644.0 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 19
# Time taken by far : 3663.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 11, batch : 20
# Time taken by far : 3682.5 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 1
# Time taken by far : 3702.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 2
# Time taken by far : 3721.3 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 3
# Time taken by far : 3740.5 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 4
# Time taken by far : 3759.7 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 5
# Time taken by far : 3779.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 6
# Time taken by far : 3798.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 7
# Time taken by far : 3818.0 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 8
# Time taken by far : 3837.0 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 9
# Time taken by far : 3855.9 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 10
# Time taken by far : 3875.0 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 11
# Time taken by far : 3894.4 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 12
# Time taken by far : 3913.7 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 13
# Time taken by far : 3932.6 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 14
# Time taken by far : 3952.0 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 15
# Time taken by far : 3971.1 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 16
# Time taken by far : 3990.2 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 17
# Time taken by far : 4009.4 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 18
# Time taken by far : 4028.8 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 19
# Time taken by far : 4047.7 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 12, batch : 20
# Time taken by far : 4067.0 seconds
# Current top member's network score: 0.26766
# Current top member's network accuracy: 89.00%
#
# Current iteration : 13, batch : 1
# Time taken by far : 4086.7 seconds
# Current top member's network score: 0.25523
# Current top member's network accuracy: 89.25%
#
# Current iteration : 13, batch : 2
# Time taken by far : 4106.0 seconds
# Current top member's network score: 0.25523
# Current top member's network accuracy: 89.25%
#
# Current iteration : 13, batch : 3
# Time taken by far : 4124.9 seconds
# Current top member's network score: 0.25523
# Current top member's network accuracy: 89.25%
#
# Current iteration : 13, batch : 4
# Time taken by far : 4144.3 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 5
# Time taken by far : 4163.6 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 6
# Time taken by far : 4183.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 7
# Time taken by far : 4202.5 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 8
# Time taken by far : 4222.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 9
# Time taken by far : 4241.1 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 10
# Time taken by far : 4260.5 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 11
# Time taken by far : 4280.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 12
# Time taken by far : 4299.1 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 13
# Time taken by far : 4318.1 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 14
# Time taken by far : 4337.2 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 15
# Time taken by far : 4356.5 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 16
# Time taken by far : 4375.8 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 17
# Time taken by far : 4395.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 18
# Time taken by far : 4416.1 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
# Current iteration : 13, batch : 19
# Time taken by far : 4443.3 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 13, batch : 20
# Time taken by far : 4465.9 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 1
# Time taken by far : 4489.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 2
# Time taken by far : 4508.8 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 3
# Time taken by far : 4528.5 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 4
# Time taken by far : 4550.2 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 5
# Time taken by far : 4571.6 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 6
# Time taken by far : 4591.3 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 7
# Time taken by far : 4616.1 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 8
# Time taken by far : 4636.6 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 9
# Time taken by far : 4656.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 10
# Time taken by far : 4675.8 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 11
# Time taken by far : 4694.8 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 12
# Time taken by far : 4714.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 13
# Time taken by far : 4733.3 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 14
# Time taken by far : 4752.7 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 15
# Time taken by far : 4772.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 16
# Time taken by far : 4791.1 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 17
# Time taken by far : 4810.6 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 18
# Time taken by far : 4829.7 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 19
# Time taken by far : 4849.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 14, batch : 20
# Time taken by far : 4868.6 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 1
# Time taken by far : 4888.1 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 2
# Time taken by far : 4907.4 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 3
# Time taken by far : 4926.6 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 4
# Time taken by far : 4946.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 5
# Time taken by far : 4965.1 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 6
# Time taken by far : 4984.2 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 7
# Time taken by far : 5003.7 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 8
# Time taken by far : 5023.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 9
# Time taken by far : 5042.5 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 10
# Time taken by far : 5061.8 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 11
# Time taken by far : 5081.5 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 12
# Time taken by far : 5100.9 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 13
# Time taken by far : 5120.0 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 14
# Time taken by far : 5139.4 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 15
# Time taken by far : 5158.5 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 16
# Time taken by far : 5177.7 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 17
# Time taken by far : 5196.9 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 18
# Time taken by far : 5216.5 seconds
# Current top member's network score: 0.25533
# Current top member's network accuracy: 89.50%
#
# Current iteration : 15, batch : 19
# Time taken by far : 5235.5 seconds
# Current top member's network score: 0.25533
# ...
#
# Current iteration : 21, batch : 2
# Time taken by far : 7221.3 seconds
# Current top member's network score: 0.22408
# Current top member's network accuracy: 90.88%
#
# Current iteration : 21, batch : 3
# Time taken by far : 7240.2 seconds
# Current top member's network score: 0.22408
# Current top member's network accuracy: 90.88%
#
# Current iteration : 21, batch : 4
# Time taken by far : 7259.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 5
# Time taken by far : 7278.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 6
# Time taken by far : 7298.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 7
# Time taken by far : 7317.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 8
# Time taken by far : 7336.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 9
# Time taken by far : 7355.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 10
# Time taken by far : 7374.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 11
# Time taken by far : 7394.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
# Current iteration : 21, batch : 12
# Time taken by far : 7413.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 13
# Time taken by far : 7432.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 14
# Time taken by far : 7452.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 15
# Time taken by far : 7471.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 16
# Time taken by far : 7490.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 17
# Time taken by far : 7509.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 18
# Time taken by far : 7529.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 19
# Time taken by far : 7548.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 21, batch : 20
# Time taken by far : 7567.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 1
# Time taken by far : 7587.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 2
# Time taken by far : 7606.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 3
# Time taken by far : 7625.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 4
# Time taken by far : 7645.0 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 5
# Time taken by far : 7664.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 6
# Time taken by far : 7683.9 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 7
# Time taken by far : 7703.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 8
# Time taken by far : 7722.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 9
# Time taken by far : 7741.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 10
# Time taken by far : 7760.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 11
# Time taken by far : 7780.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 12
# Time taken by far : 7799.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 13
# Time taken by far : 7818.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 14
# Time taken by far : 7837.9 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 15
# Time taken by far : 7857.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 16
# Time taken by far : 7876.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 17
# Time taken by far : 7895.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 18
# Time taken by far : 7915.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 19
# Time taken by far : 7934.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 22, batch : 20
# Time taken by far : 7953.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 1
# Time taken by far : 7972.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 2
# Time taken by far : 7992.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 3
# Time taken by far : 8011.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 4
# Time taken by far : 8030.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 5
# Time taken by far : 8050.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 6
# Time taken by far : 8069.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 7
# Time taken by far : 8088.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 8
# Time taken by far : 8107.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 9
# Time taken by far : 8126.9 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 10
# Time taken by far : 8146.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 11
# Time taken by far : 8165.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 12
# Time taken by far : 8184.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 13
# Time taken by far : 8203.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 14
# Time taken by far : 8222.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 15
# Time taken by far : 8241.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 16
# Time taken by far : 8261.0 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 17
# Time taken by far : 8280.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 18
# Time taken by far : 8299.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 19
# Time taken by far : 8319.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 23, batch : 20
# Time taken by far : 8338.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 1
# Time taken by far : 8357.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 2
# Time taken by far : 8377.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
# Current iteration : 24, batch : 3
# Time taken by far : 8396.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 4
# Time taken by far : 8415.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 5
# Time taken by far : 8435.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 6
# Time taken by far : 8454.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 7
# Time taken by far : 8474.0 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 8
# Time taken by far : 8494.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 9
# Time taken by far : 8513.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 10
# Time taken by far : 8532.3 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 11
# Time taken by far : 8551.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 12
# Time taken by far : 8569.9 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 13
# Time taken by far : 8589.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 14
# Time taken by far : 8608.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 15
# Time taken by far : 8627.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 16
# Time taken by far : 8646.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 17
# Time taken by far : 8665.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 18
# Time taken by far : 8684.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 19
# Time taken by far : 8703.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 24, batch : 20
# Time taken by far : 8722.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 1
# Time taken by far : 8741.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 2
# Time taken by far : 8760.4 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 3
# Time taken by far : 8779.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 4
# Time taken by far : 8798.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 5
# Time taken by far : 8817.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 6
# Time taken by far : 8836.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 7
# Time taken by far : 8855.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 8
# Time taken by far : 8874.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 9
# Time taken by far : 8893.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 10
# Time taken by far : 8913.2 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 11
# Time taken by far : 8932.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 12
# Time taken by far : 8951.0 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 13
# Time taken by far : 8970.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 14
# Time taken by far : 8989.5 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 15
# Time taken by far : 9008.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 16
# Time taken by far : 9028.7 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 17
# Time taken by far : 9051.1 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 18
# Time taken by far : 9072.9 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 19
# Time taken by far : 9094.6 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%
#
# Current iteration : 25, batch : 20
# Time taken by far : 9114.8 seconds
# Current top member's network score: 0.24013
# Current top member's network accuracy: 91.00%

# %%
nnga.best.accuracy(X,y)
# Out:
# 91.0

# %%
nnga.best.accuracy(X_test,y_test)
# Out:
# 86.0

# %%
accuracy_train = np.array(nnga.accuracy_train)
accuracy_test = np.array(nnga.accuracy_test)

# %%
plt.plot(accuracy_train)
plt.plot(accuracy_test )
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Dependencies
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
# Neural network
model = Sequential()
model.add(Dense(8, input_dim=8, activation="sigmoid"))
model.add(Dense(8, activation="sigmoid"))

# %%
for i in range(len(model.layers)):
    model.layers[i].set_weights([nnga.best.weights[i].T,nnga.best.biases[i].reshape(-1)])

# %%
from keras.models import load_model
model.save('model_NN_GA_8_8_8.h5')  # creates a HDF5 file 'my_model.h5'
del model
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
