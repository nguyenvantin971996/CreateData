# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
import copy
import time
from sklearn.preprocessing import StandardScaler
import random
from rnn_utils import *

# %%
class GRU_CUSTOM(object):

    def __init__(self, sizes, steps):
        self.num_layers = len(sizes)
        self.sizes = sizes
        
        self.h0 = np.zeros((sizes[1],1))
        
        self.wz = np.random.randn(sizes[1],sizes[0])
        self.bz = np.random.randn(sizes[1], 1)
        self.uz = np.random.randn(sizes[1],sizes[1])
        
        self.wr = np.random.randn(sizes[1],sizes[0])
        self.br = np.random.randn(sizes[1], 1)
        self.ur = np.random.randn(sizes[1],sizes[1])
        
        self.wh = np.random.randn(sizes[1],sizes[0])
        self.bwh = np.random.randn(sizes[1], 1)
        self.uh = np.random.randn(sizes[1],sizes[1])
        self.buh = np.random.randn(sizes[1], 1)
        
        self.wy = np.random.randn(sizes[2], sizes[1])
        self.by = np.random.randn(sizes[2], 1)     
        
        self.steps = steps

    def feedforward(self, x):
        h_next = self.h0
        for i in range(self.steps):
            zt = sigmoid(np.dot(self.wz, x[i].reshape(-1,1)) + np.dot(self.uz, h_next) + self.bz)
            rt = sigmoid(np.dot(self.wr, x[i].reshape(-1,1)) + np.dot(self.ur, h_next) + self.br)
            nt = np.tanh(np.dot(self.wh, x[i].reshape(-1,1)) + self.bwh + rt*(np.dot(self.uh, h_next) + self.buh))
            h_next = (1-zt)*nt + zt*h_next
        result = sigmoid(np.dot(self.wy, h_next) + self.by).reshape(-1)
        return result 

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i])
            actual = y[i]
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = self.feedforward(X[i])
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

# %%
class GRU_GA:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, X, y, X_test, y_test, steps):
        self.n_pops = n_pops
        self.steps = steps
        self.net_size = net_size
        self.nets = [GRU_CUSTOM(self.net_size,self.steps) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.X = X[:]
        self.y = y[:]
        self.X_test = X_test[:]
        self.y_test = y_test[:]
        self.accuracy_train = []
        self.accuracy_test = []
        self.best = GRU_CUSTOM(self.net_size,self.steps)
    
    def get_random_point(self, type):
        nn = self.nets[0]
        point_index = 0
        if type == 'wz':
            row = random.randint(0,nn.wz.shape[0]-1)
            col = random.randint(0,nn.wz.shape[1]-1)
            point_index = (row, col)
        elif type == 'bz':
            row = random.randint(0,nn.bz.shape[0]-1)
            col = random.randint(0,nn.bz.shape[1]-1)
            point_index = (row, col)
        elif type == 'uz':
            row = random.randint(0,nn.uz.shape[0]-1)
            col = random.randint(0,nn.uz.shape[1]-1)
            point_index = (row, col)
            
        if type == 'wr':
            row = random.randint(0,nn.wr.shape[0]-1)
            col = random.randint(0,nn.wr.shape[1]-1)
            point_index = (row, col)
        elif type == 'br':
            row = random.randint(0,nn.br.shape[0]-1)
            col = random.randint(0,nn.br.shape[1]-1)
            point_index = (row, col)
        elif type == 'ur':
            row = random.randint(0,nn.ur.shape[0]-1)
            col = random.randint(0,nn.ur.shape[1]-1)
            point_index = (row, col)
            
        if type == 'wh':
            row = random.randint(0,nn.wh.shape[0]-1)
            col = random.randint(0,nn.wh.shape[1]-1)
            point_index = (row, col)
        elif type == 'bwh':
            row = random.randint(0,nn.bwh.shape[0]-1)
            col = random.randint(0,nn.bwh.shape[1]-1)
            point_index = (row, col)
        elif type == 'uh':
            row = random.randint(0,nn.uh.shape[0]-1)
            col = random.randint(0,nn.uh.shape[1]-1)
            point_index = (row, col)
        elif type == 'buh':
            row = random.randint(0,nn.buh.shape[0]-1)
            col = random.randint(0,nn.buh.shape[1]-1)
            point_index = (row, col)
            
        elif type == 'wy':
            row = random.randint(0,nn.wy.shape[0]-1)
            col = random.randint(0,nn.wy.shape[1]-1)
            point_index = (row, col)
        elif type == 'by':
            row = random.randint(0,nn.by.shape[0]-1)
            col = random.randint(0,nn.by.shape[1]-1)
            point_index = (row, col)
        return point_index

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc,yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc,yc) for net in self.nets]

    def crossover(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.crossover_rate:
                father = random.randint(0,self.n_pops-1)
                mother = random.randint(0,self.n_pops-1)
                nn_1 = copy.deepcopy(self.nets[father])
                nn_2 = copy.deepcopy(self.nets[mother])
                
                k_1 = random.randint(int(0.5*self.nets[0].wz.size),self.nets[0].wz.size)
                for _ in range(k_1):
                    point = self.get_random_point('wz')
                    nn_1.wz[point] = self.nets[mother].wz[point]
                    nn_2.wz[point] = self.nets[father].wz[point]
                    
                k_2 = random.randint(int(0.5*self.nets[0].bz.size),self.nets[0].bz.size)
                for _ in range(k_2):
                    point = self.get_random_point('bz')
                    nn_1.bz[point] = self.nets[mother].bz[point]
                    nn_2.bz[point] = self.nets[father].bz[point]
                    
                k_3 = random.randint(int(0.5*self.nets[0].uz.size),self.nets[0].uz.size)
                for _ in range(k_3):
                    point = self.get_random_point('uz')
                    nn_1.uz[point] = self.nets[mother].uz[point]
                    nn_2.uz[point] = self.nets[father].uz[point]
                    
                k_5 = random.randint(int(0.5*self.nets[0].wr.size),self.nets[0].wr.size)
                for _ in range(k_5):
                    point = self.get_random_point('wr')
                    nn_1.wr[point] = self.nets[mother].wr[point]
                    nn_2.wr[point] = self.nets[father].wr[point]
                
                k_6 = random.randint(int(0.5*self.nets[0].br.size),self.nets[0].br.size)
                for _ in range(k_6):
                    point = self.get_random_point('br')
                    nn_1.br[point] = self.nets[mother].br[point]
                    nn_2.br[point] = self.nets[father].br[point]
                
                k_7 = random.randint(int(0.5*self.nets[0].ur.size),self.nets[0].ur.size)
                for _ in range(k_7):
                    point = self.get_random_point('ur')
                    nn_1.ur[point] = self.nets[mother].ur[point]
                    nn_2.ur[point] = self.nets[father].ur[point]
                
                k_9 = random.randint(int(0.5*self.nets[0].wh.size),self.nets[0].wh.size)
                for _ in range(k_9):
                    point = self.get_random_point('wh')
                    nn_1.wh[point] = self.nets[mother].wh[point]
                    nn_2.wh[point] = self.nets[father].wh[point]
                
                k_10 = random.randint(int(0.5*self.nets[0].bwh.size),self.nets[0].bwh.size)
                for _ in range(k_10):
                    point = self.get_random_point('bwh')
                    nn_1.bwh[point] = self.nets[mother].bwh[point]
                    nn_2.bwh[point] = self.nets[father].bwh[point]
                    
                k_11 = random.randint(int(0.5*self.nets[0].uh.size),self.nets[0].uh.size)
                for _ in range(k_11):
                    point = self.get_random_point('uh')
                    nn_1.uh[point] = self.nets[mother].uh[point]
                    nn_2.uh[point] = self.nets[father].uh[point]
                
                k_12 = random.randint(int(0.5*self.nets[0].buh.size),self.nets[0].buh.size)
                for _ in range(k_12):
                    point = self.get_random_point('buh')
                    nn_1.buh[point] = self.nets[mother].buh[point]
                    nn_2.buh[point] = self.nets[father].buh[point]
                
                k_13 = random.randint(int(0.5*self.nets[0].wy.size),self.nets[0].wy.size)
                for _ in range(k_13):
                    point = self.get_random_point('wy')
                    nn_1.wy[point] = self.nets[mother].wy[point]
                    nn_2.wy[point] = self.nets[father].wy[point]
                
                k_14 = random.randint(int(0.5*self.nets[0].by.size),self.nets[0].by.size)
                for _ in range(k_14):
                    point = self.get_random_point('by')
                    nn_1.by[point] = self.nets[mother].by[point]
                    nn_2.by[point] = self.nets[father].by[point]
                
                self.nets.append(copy.deepcopy(nn_1))
                self.nets.append(copy.deepcopy(nn_2))
        
    def mutation(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.mutation_rate:
                origin = random.randint(0,self.n_pops-1)
                nn = copy.deepcopy(self.nets[origin])

                k_1 = random.randint(int(0.5*self.nets[0].wz.size),self.nets[0].wz.size)
                for _ in range(k_1):
                    point = self.get_random_point('wz')
                    nn.wz[point] += random.uniform(-0.5, 0.5)

                k_2 = random.randint(int(0.5*self.nets[0].bz.size),self.nets[0].bz.size)
                for _ in range(k_2):
                    point = self.get_random_point('bz')
                    nn.bz[point] += random.uniform(-0.5, 0.5)
                    
                k_3 = random.randint(int(0.5*self.nets[0].uz.size),self.nets[0].uz.size)
                for _ in range(k_3):
                    point = self.get_random_point('uz')
                    nn.uz[point] += random.uniform(-0.5, 0.5)
                    
                k_5 = random.randint(int(0.5*self.nets[0].wr.size),self.nets[0].wr.size)
                for _ in range(k_5):
                    point = self.get_random_point('wr')
                    nn.wr[point] += random.uniform(-0.5, 0.5)
                
                k_6 = random.randint(int(0.5*self.nets[0].br.size),self.nets[0].br.size)
                for _ in range(k_6):
                    point = self.get_random_point('br')
                    nn.br[point] += random.uniform(-0.5, 0.5)

                k_7 = random.randint(int(0.5*self.nets[0].ur.size),self.nets[0].ur.size)
                for _ in range(k_7):
                    point = self.get_random_point('ur')
                    nn.ur[point] += random.uniform(-0.5, 0.5)
                
                k_9 = random.randint(int(0.5*self.nets[0].wh.size),self.nets[0].wh.size)
                for _ in range(k_9):
                    point = self.get_random_point('wh')
                    nn.wh[point] += random.uniform(-0.5, 0.5)
                
                k_10 = random.randint(int(0.5*self.nets[0].bwh.size),self.nets[0].bwh.size)
                for _ in range(k_10):
                    point = self.get_random_point('bwh')
                    nn.bwh[point] += random.uniform(-0.5, 0.5)

                k_11 = random.randint(int(0.5*self.nets[0].uh.size),self.nets[0].uh.size)
                for _ in range(k_11):
                    point = self.get_random_point('uh')
                    nn.uh[point] += random.uniform(-0.5, 0.5)
                    
                k_12 = random.randint(int(0.5*self.nets[0].buh.size),self.nets[0].buh.size)
                for _ in range(k_12):
                    point = self.get_random_point('buh')
                    nn.buh[point] += random.uniform(-0.5, 0.5)
                    
                k_13 = random.randint(int(0.5*self.nets[0].wy.size),self.nets[0].wy.size)
                for _ in range(k_13):
                    point = self.get_random_point('wy')
                    nn.wy[point] += random.uniform(-0.5, 0.5)
                    
                k_14 = random.randint(int(0.5*self.nets[0].by.size),self.nets[0].by.size)
                for _ in range(k_14):
                    point = self.get_random_point('by')
                    nn.by[point] += random.uniform(-0.5, 0.5)
                self.nets.append(copy.deepcopy(nn))
        
    def selection(self,Xc,yc):
        nets_new=[]
        for i in range(self.n_pops):
            k_1 = random.randint(0,len(self.nets)-1)
            k_2 = random.randint(0,len(self.nets)-1)
            if(self.nets[k_1].score(Xc,yc)<self.nets[k_2].score(Xc,yc)):
                nets_new.append(self.nets[k_1])
            else:
                nets_new.append(self.nets[k_2])
        self.nets = copy.deepcopy(nets_new)
    
    def sort_nets(self,Xc,yc):
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))
        score_list.sort(key=lambda x: x[1])
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        start_time = time.time()
        for t in range(25):
            self.accuracy_train.append(self.best.accuracy(self.X,self.y))
            self.accuracy_test.append(self.best.accuracy(self.X_test,self.y_test))
            for i in range(20):
                j1=i*40
                j2=(1+i)*40
                Xc=self.X[j1:j2,:,:]
                yc=self.y[j1:j2,:]
                for k in range(25): 
                    self.crossover()
                    self.mutation()
                    self.selection(Xc,yc)
                    self.sort_nets(Xc,yc)
                print("Current iteration : {}, batch : {}".format(t+1,i+1))
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.best.score(self.X,self.y))
                print("Current top member's network accuracy: %.2f%%\n" % self.best.accuracy(self.X,self.y))

# %%
df = pd.read_csv("../Data/data_(8-8).csv")
sc = StandardScaler()

# %%
X = df.iloc[:800, :8].values
y = df.iloc[:800, 8:16].values
X = sc.fit_transform(X)
X_test = df.iloc[800:1000, :8].values
y_test = df.iloc[800:1000, 8:16].values
X_test = sc.fit_transform(X_test)

# %%
X1= np.reshape(X, (X.shape[0], X.shape[1], 1))
y1= np.reshape(y, (y.shape[0], y.shape[1]))

# %%
X2= np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y2= np.reshape(y_test, (y_test.shape[0], y_test.shape[1]))

# %%
N_POPS = 100
steps = X.shape[1]
NET_SIZE = [1,24,8]
MUTATION_RATE = 0.1
CROSSOVER_RATE = 0.8
gru_ga = GRU_GA(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, X1, y1, X2, y2, steps)
gru_ga.evolve()
# Out:
# Current iteration : 1, batch : 1
# Time taken by far : 79.9 seconds
# Current top member's network score: 1.95200
# Current top member's network accuracy: 13.00%
#
# Current iteration : 1, batch : 2
# Time taken by far : 161.2 seconds
# Current top member's network score: 1.95200
# Current top member's network accuracy: 13.00%
#
# Current iteration : 1, batch : 3
# Time taken by far : 238.6 seconds
# Current top member's network score: 1.71808
# Current top member's network accuracy: 18.00%
#
# Current iteration : 1, batch : 4
# Time taken by far : 314.4 seconds
# Current top member's network score: 1.71808
# Current top member's network accuracy: 18.00%
#
# Current iteration : 1, batch : 5
# Time taken by far : 390.3 seconds
# Current top member's network score: 1.39879
# Current top member's network accuracy: 22.12%
#
# Current iteration : 1, batch : 6
# Time taken by far : 466.9 seconds
# Current top member's network score: 1.26643
# Current top member's network accuracy: 23.62%
#
# Current iteration : 1, batch : 7
# Time taken by far : 542.9 seconds
# Current top member's network score: 1.22443
# Current top member's network accuracy: 28.75%
#
# Current iteration : 1, batch : 8
# Time taken by far : 618.8 seconds
# Current top member's network score: 1.22443
# Current top member's network accuracy: 28.75%
#
# Current iteration : 1, batch : 9
# Time taken by far : 695.3 seconds
# Current top member's network score: 1.21350
# Current top member's network accuracy: 30.88%
#
# Current iteration : 1, batch : 10
# Time taken by far : 771.6 seconds
# Current top member's network score: 1.21350
# Current top member's network accuracy: 30.88%
#
# Current iteration : 1, batch : 11
# Time taken by far : 847.4 seconds
# Current top member's network score: 1.21350
# Current top member's network accuracy: 30.88%
#
# Current iteration : 1, batch : 12
# Time taken by far : 923.6 seconds
# Current top member's network score: 1.21350
# Current top member's network accuracy: 30.88%
#
# Current iteration : 1, batch : 13
# Time taken by far : 999.8 seconds
# Current top member's network score: 1.12784
# Current top member's network accuracy: 33.00%
#
# Current iteration : 1, batch : 14
# Time taken by far : 1075.5 seconds
# Current top member's network score: 1.11863
# Current top member's network accuracy: 33.62%
#
# Current iteration : 1, batch : 15
# Time taken by far : 1151.4 seconds
# Current top member's network score: 1.11863
# Current top member's network accuracy: 33.62%
#
# Current iteration : 1, batch : 16
# Time taken by far : 1228.2 seconds
# Current top member's network score: 1.11863
# Current top member's network accuracy: 33.62%
#
# Current iteration : 1, batch : 17
# Time taken by far : 1303.5 seconds
# Current top member's network score: 1.06415
# Current top member's network accuracy: 34.88%
#
# Current iteration : 1, batch : 18
# Time taken by far : 1380.4 seconds
# Current top member's network score: 1.07494
# Current top member's network accuracy: 36.25%
#
# Current iteration : 1, batch : 19
# Time taken by far : 1456.3 seconds
# Current top member's network score: 1.07494
# Current top member's network accuracy: 36.25%
#
# Current iteration : 1, batch : 20
# Time taken by far : 1533.6 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 1
# Time taken by far : 1610.9 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 2
# Time taken by far : 1690.3 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 3
# Time taken by far : 1769.2 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 4
# Time taken by far : 1848.6 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 5
# Time taken by far : 1926.1 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 6
# Time taken by far : 2007.2 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 7
# Time taken by far : 2087.7 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 8
# Time taken by far : 2163.8 seconds
# Current top member's network score: 1.07159
# Current top member's network accuracy: 38.25%
#
# Current iteration : 2, batch : 9
# Time taken by far : 2241.5 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 10
# Time taken by far : 2323.9 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 11
# Time taken by far : 2402.2 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 12
# Time taken by far : 2483.6 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 13
# Time taken by far : 2562.9 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 14
# Time taken by far : 2643.1 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 15
# Time taken by far : 2721.5 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 16
# Time taken by far : 2799.9 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 17
# Time taken by far : 2881.4 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 18
# Time taken by far : 2959.2 seconds
# Current top member's network score: 1.04771
# Current top member's network accuracy: 38.62%
#
# Current iteration : 2, batch : 19
# Time taken by far : 3038.8 seconds
# Current top member's network score: 1.02328
# Current top member's network accuracy: 39.75%
#
# Current iteration : 2, batch : 20
# Time taken by far : 3117.3 seconds
# Current top member's network score: 1.02328
# Current top member's network accuracy: 39.75%
#
# Current iteration : 3, batch : 1
# Time taken by far : 3197.0 seconds
# Current top member's network score: 1.02328
# Current top member's network accuracy: 39.75%
#
# Current iteration : 3, batch : 2
# Time taken by far : 3275.3 seconds
# Current top member's network score: 0.98715
# Current top member's network accuracy: 41.50%
#
# Current iteration : 3, batch : 3
# Time taken by far : 3354.6 seconds
# Current top member's network score: 0.98715
# Current top member's network accuracy: 41.50%
#
# Current iteration : 3, batch : 4
# Time taken by far : 3430.4 seconds
# Current top member's network score: 0.98715
# Current top member's network accuracy: 41.50%
#
# Current iteration : 3, batch : 5
# Time taken by far : 3509.5 seconds
# Current top member's network score: 0.98715
# Current top member's network accuracy: 41.50%
#
# Current iteration : 3, batch : 6
# Time taken by far : 3587.3 seconds
# Current top member's network score: 0.98715
# Current top member's network accuracy: 41.50%
#
# Current iteration : 3, batch : 7
# Time taken by far : 3667.7 seconds
# Current top member's network score: 0.98715
# Current top member's network accuracy: 41.50%
#
# Current iteration : 3, batch : 8
# Time taken by far : 3745.1 seconds
# Current top member's network score: 0.98715
# Current top member's network accuracy: 41.50%
#
# Current iteration : 3, batch : 9
# Time taken by far : 3822.4 seconds
# Current top member's network score: 1.05140
# Current top member's network accuracy: 45.38%
#
# Current iteration : 3, batch : 10
# Time taken by far : 3899.9 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 11
# Time taken by far : 3977.8 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 12
# Time taken by far : 4055.5 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 13
# Time taken by far : 4131.4 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 14
# Time taken by far : 4207.2 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 15
# Time taken by far : 4284.7 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 16
# Time taken by far : 4361.3 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 17
# Time taken by far : 4438.8 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 18
# Time taken by far : 4517.8 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 19
# Time taken by far : 4598.2 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 3, batch : 20
# Time taken by far : 4677.4 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 1
# Time taken by far : 4752.9 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 2
# Time taken by far : 4834.1 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 3
# Time taken by far : 4911.8 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 4
# Time taken by far : 4989.7 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 5
# Time taken by far : 5070.7 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 6
# Time taken by far : 5151.4 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 7
# Time taken by far : 5233.7 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 8
# Time taken by far : 5328.0 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 9
# Time taken by far : 5426.8 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 10
# Time taken by far : 5526.0 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 11
# Time taken by far : 5623.1 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 12
# Time taken by far : 5723.2 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 13
# Time taken by far : 5834.9 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 14
# Time taken by far : 5951.7 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 15
# Time taken by far : 6083.7 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 16
# Time taken by far : 6217.5 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 17
# Time taken by far : 6343.3 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 18
# Time taken by far : 6446.5 seconds
# Current top member's network score: 0.96599
# Current top member's network accuracy: 47.75%
#
# Current iteration : 4, batch : 19
# Time taken by far : 6541.0 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 4, batch : 20
# Time taken by far : 6645.2 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 5, batch : 1
# Time taken by far : 6742.1 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 5, batch : 2
# Time taken by far : 6837.5 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 5, batch : 3
# Time taken by far : 6933.7 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 5, batch : 4
# Time taken by far : 7028.2 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 5, batch : 5
# Time taken by far : 7122.5 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 5, batch : 6
# Time taken by far : 7219.1 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 5, batch : 7
# Time taken by far : 7313.4 seconds
# Current top member's network score: 0.95872
# Current top member's network accuracy: 47.88%
#
# Current iteration : 5, batch : 8
# Time taken by far : 7409.8 seconds
# Current top member's network score: 0.88695
# Current top member's network accuracy: 48.50%
#
# Current iteration : 5, batch : 9
# Time taken by far : 7504.9 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 10
# Time taken by far : 7599.9 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 11
# Time taken by far : 7695.7 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 12
# Time taken by far : 7788.8 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 13
# Time taken by far : 7882.6 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 14
# Time taken by far : 7977.9 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 15
# Time taken by far : 8073.4 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 16
# Time taken by far : 8166.4 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 17
# Time taken by far : 8261.5 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 18
# Time taken by far : 8355.6 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 19
# Time taken by far : 8452.3 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 5, batch : 20
# Time taken by far : 8546.7 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 1
# Time taken by far : 8642.6 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 2
# Time taken by far : 8737.9 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 3
# Time taken by far : 8832.2 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
# Current iteration : 6, batch : 4
# Time taken by far : 8927.0 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 5
# Time taken by far : 9023.7 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 6
# Time taken by far : 9119.4 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 7
# Time taken by far : 9214.1 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 8
# Time taken by far : 9309.0 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 9
# Time taken by far : 9405.3 seconds
# Current top member's network score: 0.86453
# Current top member's network accuracy: 50.75%
#
# Current iteration : 6, batch : 10
# Time taken by far : 9500.6 seconds
# Current top member's network score: 0.88014
# Current top member's network accuracy: 51.38%
#
# Current iteration : 6, batch : 11
# Time taken by far : 9597.1 seconds
# Current top member's network score: 0.88014
# Current top member's network accuracy: 51.38%
#
# Current iteration : 6, batch : 12
# Time taken by far : 9704.3 seconds
# Current top member's network score: 0.88163
# Current top member's network accuracy: 52.25%
#
# Current iteration : 6, batch : 13
# Time taken by far : 9803.3 seconds
# Current top member's network score: 0.87832
# Current top member's network accuracy: 53.00%
#
# Current iteration : 6, batch : 14
# Time taken by far : 9899.0 seconds
# Current top member's network score: 0.87832
# Current top member's network accuracy: 53.00%
#
# Current iteration : 6, batch : 15
# Time taken by far : 9995.3 seconds
# Current top member's network score: 0.85339
# Current top member's network accuracy: 53.50%
#
# Current iteration : 6, batch : 16
# Time taken by far : 10089.9 seconds
# Current top member's network score: 0.84061
# Current top member's network accuracy: 55.50%
#
# Current iteration : 6, batch : 17
# Time taken by far : 10186.5 seconds
# Current top member's network score: 0.84061
# Current top member's network accuracy: 55.50%
#
# Current iteration : 6, batch : 18
# Time taken by far : 10280.8 seconds
# Current top member's network score: 0.84061
# Current top member's network accuracy: 55.50%
#
# Current iteration : 6, batch : 19
# Time taken by far : 10374.5 seconds
# Current top member's network score: 0.84061
# Current top member's network accuracy: 55.50%
#
# Current iteration : 6, batch : 20
# Time taken by far : 10469.3 seconds
# Current top member's network score: 0.84061
# Current top member's network accuracy: 55.50%
#
# Current iteration : 7, batch : 1
# Time taken by far : 10564.6 seconds
# Current top member's network score: 0.85074
# Current top member's network accuracy: 56.38%
#
# Current iteration : 7, batch : 2
# Time taken by far : 10660.0 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 3
# Time taken by far : 10753.7 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 4
# Time taken by far : 10850.5 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 5
# Time taken by far : 10950.6 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 6
# Time taken by far : 11051.7 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 7
# Time taken by far : 11152.3 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 8
# Time taken by far : 11253.9 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 9
# Time taken by far : 11356.1 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 10
# Time taken by far : 11470.0 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 11
# Time taken by far : 11575.0 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 12
# Time taken by far : 11675.8 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 13
# Time taken by far : 11784.3 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 14
# Time taken by far : 11892.2 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 15
# Time taken by far : 11986.7 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 16
# Time taken by far : 12080.9 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 17
# Time taken by far : 12176.3 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 18
# Time taken by far : 12270.5 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 19
# Time taken by far : 12366.5 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 7, batch : 20
# Time taken by far : 12461.0 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 1
# Time taken by far : 12557.3 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 2
# Time taken by far : 12651.7 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 3
# Time taken by far : 12748.0 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 4
# Time taken by far : 12843.8 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 5
# Time taken by far : 12937.6 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 6
# Time taken by far : 13032.6 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 7
# Time taken by far : 13129.3 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 8
# Time taken by far : 13225.7 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 9
# Time taken by far : 13318.9 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 10
# Time taken by far : 13412.5 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 11
# Time taken by far : 13506.7 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 12
# Time taken by far : 13603.7 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 13
# Time taken by far : 13699.3 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 14
# Time taken by far : 13793.2 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
# Current iteration : 8, batch : 15
# Time taken by far : 13889.1 seconds
# Current top member's network score: 0.83089
# Current top member's network accuracy: 56.62%
#
# Current iteration : 8, batch : 16
# Time taken by far : 13983.6 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 8, batch : 17
# Time taken by far : 14080.6 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 8, batch : 18
# Time taken by far : 14174.8 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 8, batch : 19
# Time taken by far : 14269.4 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 8, batch : 20
# Time taken by far : 14363.9 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 9, batch : 1
# Time taken by far : 14458.2 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 9, batch : 2
# Time taken by far : 14552.7 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 9, batch : 3
# Time taken by far : 14645.5 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 9, batch : 4
# Time taken by far : 14739.6 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 9, batch : 5
# Time taken by far : 14834.6 seconds
# Current top member's network score: 0.83026
# Current top member's network accuracy: 57.12%
#
# Current iteration : 9, batch : 6
# Time taken by far : 14928.1 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 7
# Time taken by far : 15024.1 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 8
# Time taken by far : 15118.5 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 9
# Time taken by far : 15212.0 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 10
# Time taken by far : 15307.2 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 11
# Time taken by far : 15401.5 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 12
# Time taken by far : 15497.3 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 13
# Time taken by far : 15575.9 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 14
# Time taken by far : 15653.1 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 15
# Time taken by far : 15730.9 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 16
# Time taken by far : 15807.9 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 17
# Time taken by far : 15886.1 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 18
# Time taken by far : 15965.1 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 19
# Time taken by far : 16053.5 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 9, batch : 20
# Time taken by far : 16146.2 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 1
# Time taken by far : 16228.7 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 2
# Time taken by far : 16304.9 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 3
# Time taken by far : 16382.8 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 4
# Time taken by far : 16474.9 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 5
# Time taken by far : 16572.3 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 6
# Time taken by far : 16650.7 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 7
# Time taken by far : 16729.1 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 8
# Time taken by far : 16806.4 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 9
# Time taken by far : 16885.7 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 10
# Time taken by far : 16965.7 seconds
# Current top member's network score: 0.80201
# Current top member's network accuracy: 58.13%
#
# Current iteration : 10, batch : 11
# Time taken by far : 17050.3 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 12
# Time taken by far : 17129.8 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 13
# Time taken by far : 17207.1 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 14
# Time taken by far : 17286.8 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 15
# Time taken by far : 17370.4 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 16
# Time taken by far : 17459.7 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 17
# Time taken by far : 17545.2 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 18
# Time taken by far : 17624.7 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 19
# Time taken by far : 17707.3 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 10, batch : 20
# Time taken by far : 17794.5 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 1
# Time taken by far : 17897.5 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 2
# Time taken by far : 17977.5 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 3
# Time taken by far : 18057.6 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 4
# Time taken by far : 18137.8 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 5
# Time taken by far : 18218.0 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 6
# Time taken by far : 18296.8 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 7
# Time taken by far : 18375.4 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 8
# Time taken by far : 18460.1 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 9
# Time taken by far : 18539.9 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 10
# Time taken by far : 18620.8 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 11
# Time taken by far : 18700.3 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 12
# Time taken by far : 18778.6 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 13
# Time taken by far : 18855.6 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 14
# Time taken by far : 18932.9 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 15
# Time taken by far : 19011.5 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 16
# Time taken by far : 19089.7 seconds
# Current top member's network score: 0.79377
# Current top member's network accuracy: 59.38%
#
# Current iteration : 11, batch : 17
# Time taken by far : 19166.7 seconds
# Current top member's network score: 0.79204
# Current top member's network accuracy: 59.62%
#
# Current iteration : 11, batch : 18
# Time taken by far : 19244.0 seconds
# Current top member's network score: 0.79204
# Current top member's network accuracy: 59.62%
#
# Current iteration : 11, batch : 19
# Time taken by far : 19321.1 seconds
# Current top member's network score: 0.79204
# Current top member's network accuracy: 59.62%
#
# Current iteration : 11, batch : 20
# Time taken by far : 19398.4 seconds
# Current top member's network score: 0.79204
# Current top member's network accuracy: 59.62%
#
# Current iteration : 12, batch : 1
# Time taken by far : 19476.0 seconds
# Current top member's network score: 0.79204
# Current top member's network accuracy: 59.62%
#
# Current iteration : 12, batch : 2
# Time taken by far : 19553.7 seconds
# Current top member's network score: 0.79204
# Current top member's network accuracy: 59.62%
#
# Current iteration : 12, batch : 3
# Time taken by far : 19631.2 seconds
# Current top member's network score: 0.79204
# Current top member's network accuracy: 59.62%
#
# Current iteration : 12, batch : 4
# Time taken by far : 19708.5 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 5
# Time taken by far : 19786.1 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 6
# Time taken by far : 19863.4 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 7
# Time taken by far : 19940.5 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 8
# Time taken by far : 20017.6 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 9
# Time taken by far : 20094.6 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 10
# Time taken by far : 20171.7 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 11
# Time taken by far : 20248.6 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 12
# Time taken by far : 20326.1 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 13
# Time taken by far : 20404.3 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 14
# Time taken by far : 20481.8 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 15
# Time taken by far : 20559.0 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 16
# Time taken by far : 20636.4 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 17
# Time taken by far : 20713.7 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 18
# Time taken by far : 20791.4 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 19
# Time taken by far : 20869.5 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 12, batch : 20
# Time taken by far : 20946.8 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 1
# Time taken by far : 21024.3 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 2
# Time taken by far : 21101.5 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 3
# Time taken by far : 21178.2 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 4
# Time taken by far : 21255.2 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 5
# Time taken by far : 21333.2 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 6
# Time taken by far : 21410.6 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 7
# Time taken by far : 21487.8 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 8
# Time taken by far : 21565.1 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 9
# Time taken by far : 21642.0 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 10
# Time taken by far : 21719.0 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 11
# Time taken by far : 21797.0 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 12
# Time taken by far : 21873.9 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 13
# Time taken by far : 21958.7 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 14
# Time taken by far : 22036.1 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 15
# Time taken by far : 22113.7 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 16
# Time taken by far : 22191.9 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 17
# Time taken by far : 22269.6 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 18
# Time taken by far : 22346.8 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 19
# Time taken by far : 22424.0 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 13, batch : 20
# Time taken by far : 22501.2 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 14, batch : 1
# Time taken by far : 22580.2 seconds
# Current top member's network score: 0.79106
# Current top member's network accuracy: 60.50%
#
# Current iteration : 14, batch : 2
# Time taken by far : 22657.3 seconds
# Current top member's network score: 0.76255
# Current top member's network accuracy: 61.88%
#
# Current iteration : 14, batch : 3
# Time taken by far : 22734.3 seconds
# Current top member's network score: 0.76255
# Current top member's network accuracy: 61.88%
#
# Current iteration : 14, batch : 4
# Time taken by far : 22811.7 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 5
# Time taken by far : 22888.7 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 6
# Time taken by far : 22965.6 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 7
# Time taken by far : 23043.3 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 8
# Time taken by far : 23121.4 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 9
# Time taken by far : 23198.9 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 10
# Time taken by far : 23276.6 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 11
# Time taken by far : 23353.9 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 12
# Time taken by far : 23439.4 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 13
# Time taken by far : 23525.2 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 14
# Time taken by far : 23611.9 seconds
# Current top member's network score: 0.74264
# Current top member's network accuracy: 62.25%
#
# Current iteration : 14, batch : 15
# Time taken by far : 23702.3 seconds
# Current top member's network score: 0.76049
# Current top member's network accuracy: 62.50%
#
# Current iteration : 14, batch : 16
# Time taken by far : 23787.3 seconds
# Current top member's network score: 0.76049
# Current top member's network accuracy: 62.50%
#
# Current iteration : 14, batch : 17
# Time taken by far : 23870.5 seconds
# Current top member's network score: 0.76049
# Current top member's network accuracy: 62.50%
#
# Current iteration : 14, batch : 18
# Time taken by far : 23963.6 seconds
# Current top member's network score: 0.76049
# Current top member's network accuracy: 62.50%
#
# Current iteration : 14, batch : 19
# Time taken by far : 24047.7 seconds
# Current top member's network score: 0.76049
# Current top member's network accuracy: 62.50%
#
# Current iteration : 14, batch : 20
# Time taken by far : 24134.1 seconds
# Current top member's network score: 0.76049
# Current top member's network accuracy: 62.50%
#
# Current iteration : 15, batch : 1
# Time taken by far : 24218.7 seconds
# Current top member's network score: 0.76049
# Current top member's network accuracy: 62.50%
#
# Current iteration : 15, batch : 2
# Time taken by far : 24302.1 seconds
# Current top member's network score: 0.76049
# Current top member's network accuracy: 62.50%
#
# Current iteration : 15, batch : 3
# Time taken by far : 24420.4 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 4
# Time taken by far : 24532.9 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 5
# Time taken by far : 24629.7 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 6
# Time taken by far : 24726.9 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 7
# Time taken by far : 24824.4 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 8
# Time taken by far : 24918.4 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 9
# Time taken by far : 25022.0 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 10
# Time taken by far : 25117.4 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 11
# Time taken by far : 25214.8 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 12
# Time taken by far : 25310.0 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 13
# Time taken by far : 25404.8 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 14
# Time taken by far : 25501.0 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 15
# Time taken by far : 25597.8 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 16
# Time taken by far : 25693.4 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 17
# Time taken by far : 25812.5 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 15, batch : 18
# ...
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 3
# Time taken by far : 34245.7 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 4
# Time taken by far : 34321.1 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 5
# Time taken by far : 34396.5 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 6
# Time taken by far : 34472.1 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 7
# Time taken by far : 34547.6 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 8
# Time taken by far : 34623.0 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 9
# Time taken by far : 34698.5 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 10
# Time taken by far : 34774.9 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 11
# Time taken by far : 34850.6 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 12
# Time taken by far : 34925.8 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 13
# Time taken by far : 35001.4 seconds
# Current top member's network score: 0.76140
# Current top member's network accuracy: 63.12%
#
# Current iteration : 21, batch : 14
# Time taken by far : 35076.8 seconds
# Current top member's network score: 0.78497
# Current top member's network accuracy: 63.38%
#
# Current iteration : 21, batch : 15
# Time taken by far : 35152.9 seconds
# Current top member's network score: 0.78497
# Current top member's network accuracy: 63.38%
#
# Current iteration : 21, batch : 16
# Time taken by far : 35228.5 seconds
# Current top member's network score: 0.78497
# Current top member's network accuracy: 63.38%
#
# Current iteration : 21, batch : 17
# Time taken by far : 35304.5 seconds
# Current top member's network score: 0.78497
# Current top member's network accuracy: 63.38%
#
# Current iteration : 21, batch : 18
# Time taken by far : 35380.1 seconds
# Current top member's network score: 0.78497
# Current top member's network accuracy: 63.38%
#
# Current iteration : 21, batch : 19
# Time taken by far : 35455.6 seconds
# Current top member's network score: 0.78497
# Current top member's network accuracy: 63.38%
#
# Current iteration : 21, batch : 20
# Time taken by far : 35530.7 seconds
# Current top member's network score: 0.78497
# Current top member's network accuracy: 63.38%
#
# Current iteration : 22, batch : 1
# Time taken by far : 35606.2 seconds
# Current top member's network score: 0.78497
# Current top member's network accuracy: 63.38%
#
# Current iteration : 22, batch : 2
# Time taken by far : 35681.8 seconds
# Current top member's network score: 0.73215
# Current top member's network accuracy: 63.50%
#
# Current iteration : 22, batch : 3
# Time taken by far : 35757.9 seconds
# Current top member's network score: 0.73215
# Current top member's network accuracy: 63.50%
#
# Current iteration : 22, batch : 4
# Time taken by far : 35833.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 5
# Time taken by far : 35908.6 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 6
# Time taken by far : 35984.3 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 7
# Time taken by far : 36059.7 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 8
# Time taken by far : 36134.7 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 9
# Time taken by far : 36210.2 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 10
# Time taken by far : 36286.6 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 11
# Time taken by far : 36363.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 12
# Time taken by far : 36439.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 13
# Time taken by far : 36515.0 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 14
# Time taken by far : 36590.2 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 15
# Time taken by far : 36665.7 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 16
# Time taken by far : 36741.2 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 17
# Time taken by far : 36817.6 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 18
# Time taken by far : 36893.1 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 19
# Time taken by far : 36968.9 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 22, batch : 20
# Time taken by far : 37043.9 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 1
# Time taken by far : 37119.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 2
# Time taken by far : 37195.1 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 3
# Time taken by far : 37270.7 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 4
# Time taken by far : 37346.6 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 5
# Time taken by far : 37421.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 6
# Time taken by far : 37497.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 7
# Time taken by far : 37572.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 8
# Time taken by far : 37648.3 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 9
# Time taken by far : 37723.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 10
# Time taken by far : 37799.3 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 11
# Time taken by far : 37875.5 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 12
# Time taken by far : 37951.1 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 13
# Time taken by far : 38026.2 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 14
# Time taken by far : 38101.2 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 15
# Time taken by far : 38176.7 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 16
# Time taken by far : 38252.1 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 17
# Time taken by far : 38327.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 18
# Time taken by far : 38403.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 19
# Time taken by far : 38479.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 23, batch : 20
# Time taken by far : 38554.7 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 1
# Time taken by far : 38630.5 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 2
# Time taken by far : 38706.5 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 3
# Time taken by far : 38782.1 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 4
# Time taken by far : 38857.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 5
# Time taken by far : 38933.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 6
# Time taken by far : 39009.1 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 7
# Time taken by far : 39084.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 8
# Time taken by far : 39159.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 9
# Time taken by far : 39235.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 10
# Time taken by far : 39310.9 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 11
# Time taken by far : 39387.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 12
# Time taken by far : 39462.6 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 13
# Time taken by far : 39538.3 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 14
# Time taken by far : 39613.7 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 15
# Time taken by far : 39689.3 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 16
# Time taken by far : 45289.9 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 17
# Time taken by far : 45366.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 18
# Time taken by far : 45441.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 19
# Time taken by far : 45517.1 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 24, batch : 20
# Time taken by far : 45592.9 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 1
# Time taken by far : 45668.2 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 2
# Time taken by far : 45743.6 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 3
# Time taken by far : 45818.6 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 4
# Time taken by far : 45893.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 5
# Time taken by far : 45968.9 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 6
# Time taken by far : 46044.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 7
# Time taken by far : 46119.7 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 8
# Time taken by far : 46195.0 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 9
# Time taken by far : 46270.5 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 10
# Time taken by far : 46346.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 11
# Time taken by far : 46422.1 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 12
# Time taken by far : 46497.9 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 13
# Time taken by far : 46575.2 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 14
# Time taken by far : 46650.8 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 15
# Time taken by far : 46774.3 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 16
# Time taken by far : 46901.5 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 17
# Time taken by far : 47005.3 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 18
# Time taken by far : 47102.6 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 19
# Time taken by far : 47191.5 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%
#
# Current iteration : 25, batch : 20
# Time taken by far : 47283.4 seconds
# Current top member's network score: 0.72547
# Current top member's network accuracy: 64.12%

# %%
gru_ga.best.accuracy(X1,y1)
# Out:
# 64.125

# %%
gru_ga.best.accuracy(X2,y2)
# Out:
# 57.49999999999999

# %%
accuracy_train = np.array(gru_ga.accuracy_train)
accuracy_test = np.array(gru_ga.accuracy_test)

# %%
plt.plot(accuracy_train)
plt.plot(accuracy_test )
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
