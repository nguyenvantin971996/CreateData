# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
import copy
import time
from sklearn.preprocessing import StandardScaler
import random

# %%
class Simple_RNN(object):

    def __init__(self, sizes, steps):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.wx = np.random.randn(sizes[0], sizes[1])
        self.wh = np.random.randn(sizes[1], sizes[1])
        self.bh = np.random.randn(sizes[1], 1)
        self.wy = np.random.randn(sizes[1], sizes[2])
        self.by = np.random.randn(sizes[2], 1)
        self.h0 = np.zeros(sizes[1])
        self.steps = steps

    def feedforward(self, x):
        h_temp=np.tanh(np.dot(self.wx.T,x[0]) + self.h0 + self.bh.reshape(-1))
        for i in range(self.steps-1):
            h_temp = np.tanh(np.dot( self.wx.T,x[i+1]) + np.dot(self.wh.T,h_temp) + self.bh.reshape(-1))
        result = self.sigmoid(np.dot(self.wy.T,h_temp) + self.by.reshape(-1))
        return result 
    
    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i])
            actual = y[i]
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = self.feedforward(X[i])
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

# %%
class Simple_RNN_GA:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, X, y, X_test, y_test, steps):
        self.n_pops = n_pops
        self.steps = steps
        self.net_size = net_size
        self.nets = [Simple_RNN(self.net_size,self.steps) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.X = X[:]
        self.y = y[:]
        self.X_test = X_test[:]
        self.y_test = y_test[:]
        self.accuracy_train = []
        self.accuracy_test = []
        self.best = Simple_RNN(self.net_size,self.steps)
    
    def get_random_point(self, type):
        nn = self.nets[0]
        point_index = 0
        if type == 'wx':
            row = random.randint(0,nn.wx.shape[0]-1)
            col = random.randint(0,nn.wx.shape[1]-1)
            point_index = (row, col)
        elif type == 'wh':
            row = random.randint(0,nn.wh.shape[0]-1)
            col = random.randint(0,nn.wh.shape[1]-1)
            point_index = (row, col)
        elif type == 'bh':
            row = random.randint(0,nn.bh.shape[0]-1)
            col = random.randint(0,nn.bh.shape[1]-1)
            point_index = (row, col)
        elif type == 'wy':
            row = random.randint(0,nn.wy.shape[0]-1)
            col = random.randint(0,nn.wy.shape[1]-1)
            point_index = (row, col)
        elif type == 'by':
            row = random.randint(0,nn.by.shape[0]-1)
            col = random.randint(0,nn.by.shape[1]-1)
            point_index = (row, col)
        return point_index

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc,yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc,yc) for net in self.nets]

    def crossover(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.crossover_rate:
                father = random.randint(0,self.n_pops-1)
                mother = random.randint(0,self.n_pops-1)
                nn_1 = copy.deepcopy(self.nets[father])
                nn_2 = copy.deepcopy(self.nets[mother])
                
                k_1 = random.randint(int(0.5*self.nets[0].wx.size),self.nets[0].wx.size)
                for _ in range(k_1):
                    point = self.get_random_point('wx')
                    nn_1.wx[point] = self.nets[mother].wx[point]
                    nn_2.wx[point] = self.nets[father].wx[point]
                    
                k_2 = random.randint(int(0.5*self.nets[0].wh.size),self.nets[0].wh.size)
                for _ in range(k_2):
                    point = self.get_random_point('wh')
                    nn_1.wh[point] = self.nets[mother].wh[point]
                    nn_2.wh[point] = self.nets[father].wh[point]
                    
                k_3 = random.randint(int(0.5*self.nets[0].bh.size),self.nets[0].bh.size)
                for _ in range(k_3):
                    point = self.get_random_point('bh')
                    nn_1.bh[point] = self.nets[mother].bh[point]
                    nn_2.bh[point] = self.nets[father].bh[point]
                    
                k_4 = random.randint(int(0.5*self.nets[0].wy.size),self.nets[0].wy.size)
                for _ in range(k_4):
                    point = self.get_random_point('wy')
                    nn_1.wy[point] = self.nets[mother].wy[point]
                    nn_2.wy[point] = self.nets[father].wy[point]
                    
                k_5 = random.randint(int(0.5*self.nets[0].by.size),self.nets[0].by.size)
                for _ in range(k_5):
                    point = self.get_random_point('by')
                    nn_1.by[point] = self.nets[mother].by[point]
                    nn_2.by[point] = self.nets[father].by[point]
                    
                self.nets.append(copy.deepcopy(nn_1))
                self.nets.append(copy.deepcopy(nn_2))
        
    def mutation(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.mutation_rate:
                origin = random.randint(0,self.n_pops-1)
                nn = copy.deepcopy(self.nets[origin])

                k_1 = random.randint(int(0.5*self.nets[0].wx.size),self.nets[0].wx.size)
                for _ in range(k_1):
                    point = self.get_random_point('wx')
                    nn.wx[point] += random.uniform(-0.5, 0.5)

                k_2 = random.randint(int(0.5*self.nets[0].wh.size),self.nets[0].wh.size)
                for _ in range(k_2):
                    point = self.get_random_point('wh')
                    nn.wh[point] += random.uniform(-0.5, 0.5)
                    
                k_3 = random.randint(int(0.5*self.nets[0].bh.size),self.nets[0].bh.size)
                for _ in range(k_3):
                    point = self.get_random_point('bh')
                    nn.bh[point] += random.uniform(-0.5, 0.5)
                    
                k_4 = random.randint(int(0.5*self.nets[0].wy.size),self.nets[0].wy.size)
                for _ in range(k_4):
                    point = self.get_random_point('wy')
                    nn.wy[point] += random.uniform(-0.5, 0.5)
                    
                k_5 = random.randint(int(0.5*self.nets[0].by.size),self.nets[0].by.size)
                for _ in range(k_5):
                    point = self.get_random_point('by')
                    nn.by[point] += random.uniform(-0.5, 0.5)
                self.nets.append(copy.deepcopy(nn))
        
    def selection(self,Xc,yc):
        nets_new=[]
        for i in range(self.n_pops):
            list_k = random.sample(range(len(self.nets)),5)
            list_k.sort(key=lambda x: self.nets[x].score(Xc,yc))
            nets_new.append(self.nets[list_k[0]])
        self.nets = copy.deepcopy(nets_new)
    
    def sort_nets(self,Xc,yc):
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))
        score_list.sort(key=lambda x: x[1])
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        start_time = time.time()
        for t in range(25):
            self.accuracy_train.append(self.best.accuracy(self.X,self.y))
            self.accuracy_test.append(self.best.accuracy(self.X_test,self.y_test))
            for i in range(20):
                j1=i*40
                j2=(1+i)*40
                Xc=self.X[j1:j2,:,:]
                yc=self.y[j1:j2,:]
                for k in range(25): 
                    self.crossover()
                    self.mutation()
                    self.selection(Xc,yc)
                    self.sort_nets(Xc,yc)
                print("Current iteration : {}, batch : {}".format(t+1,i+1))
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.best.score(self.X,self.y))
                print("Current top member's network accuracy: %.2f%%\n" % self.best.accuracy(self.X,self.y))

# %%
df = pd.read_csv("../../Data/data_(8-8).csv")
sc = StandardScaler()

# %%
X = df.iloc[:800, :8].values
y = df.iloc[:800, 8:16].values
X = sc.fit_transform(X)
X_test = df.iloc[800:1000, :8].values
y_test = df.iloc[800:1000, 8:16].values
X_test = sc.fit_transform(X_test)

# %%
X1= np.reshape(X, (X.shape[0], X.shape[1], 1))
y1= np.reshape(y, (y.shape[0], y.shape[1]))

# %%
X2= np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y2= np.reshape(y_test, (y_test.shape[0], y_test.shape[1]))

# %%
N_POPS = 50
steps = X.shape[1]
NET_SIZE = [1,24,8]
MUTATION_RATE = 0.1
CROSSOVER_RATE = 0.8
simple_rnn_ga = Simple_RNN_GA(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, X1, y1, X2, y2, steps)
simple_rnn_ga.evolve()
# Out:
# Current iteration : 1, batch : 1
# Time taken by far : 21.0 seconds
# Current top member's network score: 1.79529
# Current top member's network accuracy: 16.25%
#
# Current iteration : 1, batch : 2
# Time taken by far : 42.2 seconds
# Current top member's network score: 1.75687
# Current top member's network accuracy: 16.38%
#
# Current iteration : 1, batch : 3
# Time taken by far : 64.2 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 4
# Time taken by far : 85.2 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 5
# Time taken by far : 106.4 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 6
# Time taken by far : 128.1 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 7
# Time taken by far : 149.2 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 8
# Time taken by far : 170.3 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 9
# Time taken by far : 192.6 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 10
# Time taken by far : 213.5 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 11
# Time taken by far : 234.7 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 12
# Time taken by far : 256.8 seconds
# Current top member's network score: 1.73313
# Current top member's network accuracy: 16.50%
#
# Current iteration : 1, batch : 13
# Time taken by far : 277.8 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 1, batch : 14
# Time taken by far : 298.6 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 1, batch : 15
# Time taken by far : 320.3 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 1, batch : 16
# Time taken by far : 341.3 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 1, batch : 17
# Time taken by far : 362.4 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 1, batch : 18
# Time taken by far : 384.1 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 1, batch : 19
# Time taken by far : 405.1 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 1, batch : 20
# Time taken by far : 426.1 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 1
# Time taken by far : 447.8 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 2
# Time taken by far : 469.1 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 3
# Time taken by far : 490.0 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 4
# Time taken by far : 512.2 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 5
# Time taken by far : 533.3 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 6
# Time taken by far : 554.3 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 7
# Time taken by far : 575.6 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 8
# Time taken by far : 597.0 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 9
# Time taken by far : 617.6 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 10
# Time taken by far : 638.7 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 11
# Time taken by far : 660.5 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 12
# Time taken by far : 681.5 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 13
# Time taken by far : 702.6 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 14
# Time taken by far : 724.2 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 15
# Time taken by far : 745.2 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 16
# Time taken by far : 766.3 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 17
# Time taken by far : 788.4 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 18
# Time taken by far : 809.3 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 19
# Time taken by far : 830.2 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 2, batch : 20
# Time taken by far : 852.2 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 1
# Time taken by far : 873.2 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 2
# Time taken by far : 894.2 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 3
# Time taken by far : 915.9 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 4
# Time taken by far : 937.1 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 5
# Time taken by far : 958.1 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 6
# Time taken by far : 979.8 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 7
# Time taken by far : 1000.8 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 8
# Time taken by far : 1021.6 seconds
# Current top member's network score: 1.73060
# Current top member's network accuracy: 18.62%
#
# Current iteration : 3, batch : 9
# Time taken by far : 1043.2 seconds
# Current top member's network score: 1.56807
# Current top member's network accuracy: 18.75%
#
# Current iteration : 3, batch : 10
# Time taken by far : 1064.2 seconds
# Current top member's network score: 1.56807
# Current top member's network accuracy: 18.75%
#
# Current iteration : 3, batch : 11
# Time taken by far : 1085.1 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 3, batch : 12
# Time taken by far : 1106.9 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
# Current iteration : 3, batch : 13
# Time taken by far : 1127.9 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 3, batch : 14
# Time taken by far : 1149.5 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 3, batch : 15
# Time taken by far : 1171.4 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 3, batch : 16
# Time taken by far : 1192.5 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 3, batch : 17
# Time taken by far : 1213.6 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 3, batch : 18
# Time taken by far : 1235.0 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 3, batch : 19
# Time taken by far : 1256.6 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 3, batch : 20
# Time taken by far : 1278.3 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 4, batch : 1
# Time taken by far : 1299.4 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 4, batch : 2
# Time taken by far : 1321.1 seconds
# Current top member's network score: 1.70715
# Current top member's network accuracy: 26.00%
#
# Current iteration : 4, batch : 3
# Time taken by far : 1341.9 seconds
# Current top member's network score: 1.67361
# Current top member's network accuracy: 28.00%
#
# Current iteration : 4, batch : 4
# Time taken by far : 1363.1 seconds
# Current top member's network score: 1.67361
# Current top member's network accuracy: 28.00%
#
# Current iteration : 4, batch : 5
# Time taken by far : 1384.9 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 6
# Time taken by far : 1406.0 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 7
# Time taken by far : 1427.1 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 8
# Time taken by far : 1448.7 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 9
# Time taken by far : 1469.7 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 10
# Time taken by far : 1490.7 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 11
# Time taken by far : 1512.5 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 12
# Time taken by far : 1533.8 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 13
# Time taken by far : 1555.1 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 14
# Time taken by far : 1576.9 seconds
# Current top member's network score: 1.42698
# Current top member's network accuracy: 37.25%
#
# Current iteration : 4, batch : 15
# Time taken by far : 1598.3 seconds
# Current top member's network score: 1.41971
# Current top member's network accuracy: 37.38%
#
# Current iteration : 4, batch : 16
# Time taken by far : 1619.5 seconds
# Current top member's network score: 1.37154
# Current top member's network accuracy: 38.00%
#
# Current iteration : 4, batch : 17
# Time taken by far : 1641.3 seconds
# Current top member's network score: 1.37154
# Current top member's network accuracy: 38.00%
#
# Current iteration : 4, batch : 18
# Time taken by far : 1662.3 seconds
# Current top member's network score: 1.37154
# Current top member's network accuracy: 38.00%
#
# Current iteration : 4, batch : 19
# Time taken by far : 1683.5 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 4, batch : 20
# Time taken by far : 1705.5 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 1
# Time taken by far : 1726.6 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 2
# Time taken by far : 1747.8 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 3
# Time taken by far : 1769.7 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 4
# Time taken by far : 1790.9 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 5
# Time taken by far : 1811.7 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 6
# Time taken by far : 1833.5 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 7
# Time taken by far : 1854.8 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 8
# Time taken by far : 1875.8 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 9
# Time taken by far : 1897.5 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 10
# Time taken by far : 1918.5 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 11
# Time taken by far : 1939.5 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 12
# Time taken by far : 1961.1 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 13
# Time taken by far : 1982.8 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 14
# Time taken by far : 2003.8 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch : 15
# Time taken by far : 2024.8 seconds
# Current top member's network score: 1.28261
# Current top member's network accuracy: 42.12%
#
# Current iteration : 5, batch :
1 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 1
# Time taken by far : 6029.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 2
# Time taken by far : 6051.7 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 3
# Time taken by far : 6073.1 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 4
# Time taken by far : 6094.4 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 5
# Time taken by far : 6116.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 6
# Time taken by far : 6137.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 7
# Time taken by far : 6159.4 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 8
# Time taken by far : 6181.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 9
# Time taken by far : 6203.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 10
# Time taken by far : 6225.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 11
# Time taken by far : 6247.4 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 12
# Time taken by far : 6268.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 13
# Time taken by far : 6290.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 14
# Time taken by far : 6312.1 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 15
# Time taken by far : 6333.7 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 16
# Time taken by far : 6355.1 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 17
# Time taken by far : 6376.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 18
# Time taken by far : 6398.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 19
# Time taken by far : 6420.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 15, batch : 20
# Time taken by far : 6442.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 1
# Time taken by far : 6464.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 2
# Time taken by far : 6485.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 3
# Time taken by far : 6507.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 4
# Time taken by far : 6529.1 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 5
# Time taken by far : 6550.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 6
# Time taken by far : 6571.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 7
# Time taken by far : 6593.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 8
# Time taken by far : 6615.0 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 9
# Time taken by far : 6636.4 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
# Current iteration : 16, batch : 10
# Time taken by far : 6658.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 11
# Time taken by far : 6679.8 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 12
# Time taken by far : 6701.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 13
# Time taken by far : 6723.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 14
# Time taken by far : 6744.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 15
# Time taken by far : 6766.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 16
# Time taken by far : 6788.4 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 17
# Time taken by far : 6809.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 18
# Time taken by far : 6831.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 19
# Time taken by far : 6853.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 16, batch : 20
# Time taken by far : 6874.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 1
# Time taken by far : 6895.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 2
# Time taken by far : 6917.8 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 3
# Time taken by far : 6939.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 4
# Time taken by far : 6960.7 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 5
# Time taken by far : 6982.8 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 6
# Time taken by far : 7004.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 7
# Time taken by far : 7025.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 8
# Time taken by far : 7047.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 9
# Time taken by far : 7068.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 10
# Time taken by far : 7090.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 11
# Time taken by far : 7112.4 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 12
# Time taken by far : 7134.0 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 13
# Time taken by far : 7155.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 14
# Time taken by far : 7177.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 15
# Time taken by far : 7199.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 16
# Time taken by far : 7220.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 17
# Time taken by far : 7242.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 18
# Time taken by far : 7264.0 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 19
# Time taken by far : 7285.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 17, batch : 20
# Time taken by far : 7307.4 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 1
# Time taken by far : 7328.8 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 2
# Time taken by far : 7350.1 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 3
# Time taken by far : 7372.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 4
# Time taken by far : 7394.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 5
# Time taken by far : 7415.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 6
# Time taken by far : 7437.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 7
# Time taken by far : 7458.9 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 8
# Time taken by far : 7480.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 9
# Time taken by far : 7502.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 10
# Time taken by far : 7523.8 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 11
# Time taken by far : 7545.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 12
# Time taken by far : 7567.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 13
# Time taken by far : 7588.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 14
# Time taken by far : 7609.7 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 15
# Time taken by far : 7631.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 16
# Time taken by far : 7653.0 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 17
# Time taken by far : 7674.3 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 18
# Time taken by far : 7695.8 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 19
# Time taken by far : 7717.5 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 18, batch : 20
# Time taken by far : 7738.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
# Current iteration : 19, batch : 1
# Time taken by far : 7760.2 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%
#
# Current iteration : 19, batch : 2
# Time taken by far : 7782.6 seconds
# Current top member's network score: 1.38491
# Current top member's network accuracy: 44.00%

# %%
simple_rnn_ga.best.accuracy(X1,y1)

# %%
simple_rnn_ga.best.accuracy(X2,y2)

# %%
accuracy_train = np.array(simple_rnn_ga.accuracy_train)
accuracy_test = np.array(simple_rnn_ga.accuracy_test)

# %%
plt.plot(accuracy_train)
plt.plot(accuracy_test )
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
