# %%
import random
import numpy as np
import pandas as pd
import copy
import time
from sklearn.preprocessing import StandardScaler

# %%
class Network(object):

    def __init__(self, sizes):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.biases = [np.random.randn(y, 1) for y in sizes[1:]]
        self.weights = [np.random.randn(y, x) for x, y in zip(sizes[:-1], sizes[1:])]
        
        # helper variables
        self.bias_nitem = sum(sizes[1:])
        self.weight_nitem = sum([self.weights[i].size for i in range(self.num_layers-2)])

    def feedforward(self, a):
        for b, w in zip(self.biases, self.weights):
            a = self.sigmoid(np.dot(w,a)+b)
        return a

    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i].reshape(-1,1))
            actual = y[i].reshape(-1,1)
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = (self.feedforward(X[i].reshape(-1,1))).reshape(-1)
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

    def __str__(self):
        s = "\nBias:\n\n" + str(self.biases)
        s += "\nWeights:\n\n" + str(self.weights)
        s += "\n\n"
        return s

# %%
class NNGeneticAlgo:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, X, y, X_test, y_test):
        self.n_pops = n_pops
        self.net_size = net_size
        self.nets = [Network(self.net_size) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.X = X[:]
        self.y = y[:]
        self.X_test = X_test[:]
        self.y_test = y_test[:]
        self.accuracy_train = []
        self.accuracy_test = []
        self.best = Network(self.net_size)
    
    def get_random_point(self, type):
        nn = self.nets[0]
        layer_index, point_index = random.randint(0, nn.num_layers-2), 0
        if type == 'weight':
            row = random.randint(0,nn.weights[layer_index].shape[0]-1)
            col = random.randint(0,nn.weights[layer_index].shape[1]-1)
            point_index = (row, col)
        elif type == 'bias':
            point_index = random.randint(0,nn.biases[layer_index].size-1)
        return (layer_index, point_index)

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc,yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc,yc) for net in self.nets]

    def crossover(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.crossover_rate:
                father = random.randint(0,self.n_pops-1)
                mother = random.randint(0,self.n_pops-1)
                # make a copy of father 'genetic' weights & biases information
                nn_1 = copy.deepcopy(self.nets[father])
                nn_2 = copy.deepcopy(self.nets[mother])
                # cross-over bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # replace genetic (bias) with mother's value
                    nn_1.biases[layer][point] = self.nets[mother].biases[layer][point]
                    nn_2.biases[layer][point] = self.nets[father].biases[layer][point]

                # cross-over weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # replace genetic (weight) with mother's value
                    nn_1.weights[layer][point] = self.nets[mother].weights[layer][point]
                    nn_2.weights[layer][point] = self.nets[father].weights[layer][point]
                self.nets.append(copy.deepcopy(nn_1))
                self.nets.append(copy.deepcopy(nn_2))
        
    def mutation(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.mutation_rate:
                origin = random.randint(0,self.n_pops-1)
                nn = copy.deepcopy(self.nets[origin])

                # mutate bias
                k_1 = random.randint(int(0.5*self.nets[0].bias_nitem),self.nets[0].bias_nitem)
                for _ in range(k_1):
                    # get some random points
                    layer, point = self.get_random_point('bias')
                    # add some random value between -0.5 and 0.5
                    nn.biases[layer][point] += random.uniform(-0.5, 0.5)

                # mutate weight
                k_2 = random.randint(int(0.5*self.nets[0].weight_nitem),self.nets[0].weight_nitem)
                for _ in range(k_2):
                    # get some random points
                    layer, point = self.get_random_point('weight')
                    # add some random value between -0.5 and 0.5
                    nn.weights[layer][point[0], point[1]] += random.uniform(-0.5, 0.5)
                self.nets.append(copy.deepcopy(nn))
        
    def selection(self,Xc,yc):
        nets_new=[]
        for i in range(self.n_pops):
            k_1 = random.randint(0,len(self.nets)-1)
            k_2 = random.randint(0,len(self.nets)-1)
            if(self.nets[k_1].score(Xc,yc)<self.nets[k_2].score(Xc,yc)):
                nets_new.append(self.nets[k_1])
            else:
                nets_new.append(self.nets[k_2])
        self.nets = copy.deepcopy(nets_new)
    
    def sort_nets(self,Xc,yc):
        # calculate score for each population of neural-net
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))

        # sort the network using its score
        score_list.sort(key=lambda x: x[1])

        # exclude score as it is not needed anymore
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        start_time = time.time()
        for t in range(25):
            self.accuracy_train.append(self.best.accuracy(self.X,self.y))
            self.accuracy_test.append(self.best.accuracy(self.X_test,self.y_test))
            for i in range(40):
                j1=i*40
                j2=(1+i)*40
                Xc=self.X[j1:j2,:]
                yc=self.y[j1:j2,:]
                for k in range(25): 
                    self.crossover()
                    self.mutation()
                    self.selection(Xc,yc)
                    self.sort_nets(Xc,yc)
                print("Current iteration : {}, batch : {}".format(t+1,i+1))
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.best.score(self.X,self.y))
                print("Current top member's network accuracy: %.2f%%\n" % self.best.accuracy(self.X,self.y))

# %%
df = pd.read_csv("../Data/data_(12-12).csv")

# %%
X = df.iloc[:1600, :12].values
y = df.iloc[:1600, 12:24].values
sc = StandardScaler()
X = sc.fit_transform(X)
X_test = df.iloc[1600:2000, :12].values
y_test = df.iloc[1600:2000, 12:24].values
sc = StandardScaler()
X_test = sc.fit_transform(X_test)

# %%
N_POPS = 100
NET_SIZE = [12,12,12]
MUTATION_RATE = 0.1
CROSSOVER_RATE = 0.8
nnga = NNGeneticAlgo(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, X, y, X_test, y_test)
nnga.evolve()
# Out:
# Current iteration : 1, batch : 1
# Time taken by far : 15.5 seconds
# Current top member's network score: 1.75891
# Current top member's network accuracy: 29.12%
#
# Current iteration : 1, batch : 2
# Time taken by far : 30.5 seconds
# Current top member's network score: 1.68536
# Current top member's network accuracy: 38.19%
#
# Current iteration : 1, batch : 3
# Time taken by far : 45.0 seconds
# Current top member's network score: 1.39387
# Current top member's network accuracy: 41.88%
#
# Current iteration : 1, batch : 4
# Time taken by far : 61.9 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 5
# Time taken by far : 76.3 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 6
# Time taken by far : 90.5 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 7
# Time taken by far : 104.4 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 8
# Time taken by far : 121.0 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 9
# Time taken by far : 135.8 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 10
# Time taken by far : 150.1 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 11
# Time taken by far : 164.4 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 12
# Time taken by far : 179.7 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 13
# Time taken by far : 194.9 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 14
# Time taken by far : 209.1 seconds
# Current top member's network score: 1.43155
# Current top member's network accuracy: 48.38%
#
# Current iteration : 1, batch : 15
# Time taken by far : 224.4 seconds
# Current top member's network score: 1.05721
# Current top member's network accuracy: 48.50%
#
# Current iteration : 1, batch : 16
# Time taken by far : 238.6 seconds
# Current top member's network score: 1.05721
# Current top member's network accuracy: 48.50%
#
# Current iteration : 1, batch : 17
# Time taken by far : 253.4 seconds
# Current top member's network score: 1.01812
# Current top member's network accuracy: 49.62%
#
# Current iteration : 1, batch : 18
# Time taken by far : 268.4 seconds
# Current top member's network score: 1.01812
# Current top member's network accuracy: 49.62%
#
# Current iteration : 1, batch : 19
# Time taken by far : 282.8 seconds
# Current top member's network score: 1.03078
# Current top member's network accuracy: 50.12%
#
# Current iteration : 1, batch : 20
# Time taken by far : 297.7 seconds
# Current top member's network score: 1.00955
# Current top member's network accuracy: 50.44%
#
# Current iteration : 1, batch : 21
# Time taken by far : 312.9 seconds
# Current top member's network score: 0.97277
# Current top member's network accuracy: 51.38%
#
# Current iteration : 1, batch : 22
# Time taken by far : 326.7 seconds
# Current top member's network score: 0.93876
# Current top member's network accuracy: 52.88%
#
# Current iteration : 1, batch : 23
# Time taken by far : 341.1 seconds
# Current top member's network score: 0.94179
# Current top member's network accuracy: 54.75%
#
# Current iteration : 1, batch : 24
# Time taken by far : 355.7 seconds
# Current top member's network score: 0.94179
# Current top member's network accuracy: 54.75%
#
# Current iteration : 1, batch : 25
# Time taken by far : 370.3 seconds
# Current top member's network score: 0.94179
# Current top member's network accuracy: 54.75%
#
# Current iteration : 1, batch : 26
# Time taken by far : 385.1 seconds
# Current top member's network score: 0.94179
# Current top member's network accuracy: 54.75%
#
# Current iteration : 1, batch : 27
# Time taken by far : 399.9 seconds
# Current top member's network score: 0.89275
# Current top member's network accuracy: 55.00%
#
# Current iteration : 1, batch : 28
# Time taken by far : 414.8 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 29
# Time taken by far : 429.4 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 30
# Time taken by far : 444.0 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 31
# Time taken by far : 457.6 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 32
# Time taken by far : 472.0 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 33
# Time taken by far : 486.0 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 34
# Time taken by far : 499.7 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 35
# Time taken by far : 513.8 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 36
# Time taken by far : 527.8 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 37
# Time taken by far : 542.0 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 38
# Time taken by far : 556.3 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 39
# Time taken by far : 570.2 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 1, batch : 40
# Time taken by far : 584.4 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 2, batch : 1
# Time taken by far : 597.9 seconds
# Current top member's network score: 0.88698
# Current top member's network accuracy: 56.06%
#
# Current iteration : 2, batch : 2
# Time taken by far : 611.9 seconds
# Current top member's network score: 0.82958
# Current top member's network accuracy: 56.12%
#
# Current iteration : 2, batch : 3
# Time taken by far : 628.9 seconds
# Current top member's network score: 0.82958
# Current top member's network accuracy: 56.12%
#
# Current iteration : 2, batch : 4
# Time taken by far : 643.6 seconds
# Current top member's network score: 0.84421
# Current top member's network accuracy: 58.38%
#
# Current iteration : 2, batch : 5
# Time taken by far : 657.8 seconds
# Current top member's network score: 0.84421
# Current top member's network accuracy: 58.38%
#
# Current iteration : 2, batch : 6
# Time taken by far : 672.4 seconds
# Current top member's network score: 0.84421
# Current top member's network accuracy: 58.38%
#
# Current iteration : 2, batch : 7
# Time taken by far : 686.9 seconds
# Current top member's network score: 0.85299
# Current top member's network accuracy: 58.56%
#
# Current iteration : 2, batch : 8
# Time taken by far : 701.1 seconds
# Current top member's network score: 0.85299
# Current top member's network accuracy: 58.56%
#
# Current iteration : 2, batch : 9
# Time taken by far : 715.6 seconds
# Current top member's network score: 0.85299
# Current top member's network accuracy: 58.56%
#
# Current iteration : 2, batch : 10
# Time taken by far : 729.4 seconds
# Current top member's network score: 0.81224
# Current top member's network accuracy: 59.13%
#
# Current iteration : 2, batch : 11
# Time taken by far : 743.4 seconds
# Current top member's network score: 0.81224
# Current top member's network accuracy: 59.13%
#
# Current iteration : 2, batch : 12
# Time taken by far : 758.5 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
# Current iteration : 2, batch : 13
# Time taken by far : 773.4 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 14
# Time taken by far : 788.5 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 15
# Time taken by far : 802.9 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 16
# Time taken by far : 817.6 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 17
# Time taken by far : 834.0 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 18
# Time taken by far : 848.9 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 19
# Time taken by far : 863.3 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 20
# Time taken by far : 878.5 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 21
# Time taken by far : 893.2 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 22
# Time taken by far : 908.7 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 23
# Time taken by far : 924.2 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 24
# Time taken by far : 938.8 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 25
# Time taken by far : 953.6 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 26
# Time taken by far : 968.2 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 27
# Time taken by far : 983.6 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 28
# Time taken by far : 998.4 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 29
# Time taken by far : 1012.7 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 30
# Time taken by far : 1027.3 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 31
# Time taken by far : 1042.2 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 32
# Time taken by far : 1056.1 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 33
# Time taken by far : 1070.3 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 34
# Time taken by far : 1089.1 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 35
# Time taken by far : 1109.8 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 36
# Time taken by far : 1132.1 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 37
# Time taken by far : 1159.3 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 38
# Time taken by far : 1186.9 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 39
# Time taken by far : 1213.7 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 2, batch : 40
# Time taken by far : 1242.8 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch : 1
# Time taken by far : 1269.5 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch : 2
# Time taken by far : 1296.2 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch : 3
# Time taken by far : 1321.2 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch : 4
# Time taken by far : 1345.7 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch : 5
# Time taken by far : 1373.2 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch : 6
# Time taken by far : 1399.6 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch : 7
# Time taken by far : 1425.6 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch : 8
# Time taken by far : 1452.8 seconds
# Current top member's network score: 0.78417
# Current top member's network accuracy: 60.19%
#
# Current iteration : 3, batch :
seconds
# Current top member's network score: 0.64725
# Current top member's network accuracy: 62.94%
#
# Current iteration : 6, batch : 31
# Time taken by far : 5253.1 seconds
# Current top member's network score: 0.64725
# Current top member's network accuracy: 62.94%
#
# Current iteration : 6, batch : 32
# Time taken by far : 5278.7 seconds
# Current top member's network score: 0.62215
# Current top member's network accuracy: 63.25%
#
# Current iteration : 6, batch : 33
# Time taken by far : 5303.6 seconds
# Current top member's network score: 0.62215
# Current top member's network accuracy: 63.25%
#
# Current iteration : 6, batch : 34
# Time taken by far : 5328.8 seconds
# Current top member's network score: 0.65179
# Current top member's network accuracy: 63.44%
#
# Current iteration : 6, batch : 35
# Time taken by far : 5353.9 seconds
# Current top member's network score: 0.65179
# Current top member's network accuracy: 63.44%
#
# Current iteration : 6, batch : 36
# Time taken by far : 5379.0 seconds
# Current top member's network score: 0.65179
# Current top member's network accuracy: 63.44%
#
# Current iteration : 6, batch : 37
# Time taken by far : 5404.5 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 6, batch : 38
# Time taken by far : 5429.3 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 6, batch : 39
# Time taken by far : 5454.3 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 6, batch : 40
# Time taken by far : 5479.7 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 1
# Time taken by far : 5505.3 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 2
# Time taken by far : 5530.5 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 3
# Time taken by far : 5555.5 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 4
# Time taken by far : 5580.4 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 5
# Time taken by far : 5605.6 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 6
# Time taken by far : 5630.8 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 7
# Time taken by far : 5656.0 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 8
# Time taken by far : 5681.6 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 9
# Time taken by far : 5706.3 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 10
# Time taken by far : 5731.6 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 11
# Time taken by far : 5756.5 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 12
# Time taken by far : 5781.5 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 13
# Time taken by far : 5806.9 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 14
# Time taken by far : 5832.2 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 15
# Time taken by far : 5857.0 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 16
# Time taken by far : 5882.6 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 17
# Time taken by far : 5907.5 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 18
# Time taken by far : 5933.1 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 19
# Time taken by far : 5957.7 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 20
# Time taken by far : 5982.6 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 21
# Time taken by far : 6007.9 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 22
# Time taken by far : 6033.0 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 23
# Time taken by far : 6057.9 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 24
# Time taken by far : 6083.2 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 25
# Time taken by far : 6108.3 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 26
# Time taken by far : 6133.3 seconds
# Current top member's network score: 0.62265
# Current top member's network accuracy: 63.50%
#
# Current iteration : 7, batch : 27
# Time taken by far : 6158.4 seconds
# Current top member's network score: 0.63530
# Current top member's network accuracy: 64.19%
#
# Current iteration : 7, batch : 28
# Time taken by far : 6183.4 seconds
# Current top member's network score: 0.63530
# Current top member's network accuracy: 64.19%
#
# Current iteration : 7, batch : 29
# Time taken by far : 6208.6 seconds
# Current top member's network score: 0.63530
# Current top member's network accuracy: 64.19%
#
# Current iteration : 7, batch : 30
# Time taken by far : 6233.4 seconds
# Current top member's network score: 0.63530
# Current top member's network accuracy: 64.19%
#
# Current iteration : 7, batch : 31
# Time taken by far : 6258.8 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 32
# Time taken by far : 6283.3 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 33
# Time taken by far : 6308.2 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 34
# Time taken by far : 6333.7 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 35
# Time taken by far : 6358.6 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 36
# Time taken by far : 6383.5 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 37
# Time taken by far : 6408.5 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 38
# Time taken by far : 6432.9 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 39
# Time taken by far : 6458.3 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 7, batch : 40
# Time taken by far : 6482.9 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 8, batch : 1
# Time taken by far : 6507.8 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 8, batch : 2
# Time taken by far : 6533.1 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 8, batch : 3
# Time taken by far : 6558.2 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 8, batch : 4
# Time taken by far : 6583.3 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 8, batch : 5
# Time taken by far : 6608.8 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 8, batch : 6
# Time taken by far : 6633.4 seconds
# Current top member's network score: 0.60657
# Current top member's network accuracy: 64.62%
#
# Current iteration : 8, batch :
seconds
# Current top member's network score: 0.47486
# Current top member's network accuracy: 75.69%
#
# Current iteration : 24, batch : 30
# Time taken by far : 20378.1 seconds
# Current top member's network score: 0.47486
# Current top member's network accuracy: 75.69%
#
# Current iteration : 24, batch : 31
# Time taken by far : 20396.4 seconds
# Current top member's network score: 0.48040
# Current top member's network accuracy: 76.19%
#
# Current iteration : 24, batch : 32
# Time taken by far : 20414.1 seconds
# Current top member's network score: 0.45871
# Current top member's network accuracy: 76.56%
#
# Current iteration : 24, batch : 33
# Time taken by far : 20431.0 seconds
# Current top member's network score: 0.45871
# Current top member's network accuracy: 76.56%
#
# Current iteration : 24, batch : 34
# Time taken by far : 20447.6 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 24, batch : 35
# Time taken by far : 20465.4 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 24, batch : 36
# Time taken by far : 20483.0 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 24, batch : 37
# Time taken by far : 20499.9 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 24, batch : 38
# Time taken by far : 20517.8 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 24, batch : 39
# Time taken by far : 20535.6 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 24, batch : 40
# Time taken by far : 20553.1 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 1
# Time taken by far : 20571.0 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 2
# Time taken by far : 20589.0 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 3
# Time taken by far : 20606.2 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 4
# Time taken by far : 20623.5 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 5
# Time taken by far : 20641.6 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 6
# Time taken by far : 20659.2 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 7
# Time taken by far : 20676.6 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 8
# Time taken by far : 20693.7 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 9
# Time taken by far : 20712.3 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 10
# Time taken by far : 20730.2 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 11
# Time taken by far : 20747.4 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
# Current iteration : 25, batch : 12
# Time taken by far : 20764.9 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 13
# Time taken by far : 20783.7 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 14
# Time taken by far : 20800.7 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 15
# Time taken by far : 20818.2 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 16
# Time taken by far : 20836.4 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 17
# Time taken by far : 20853.4 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 18
# Time taken by far : 20871.1 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 19
# Time taken by far : 20888.6 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 20
# Time taken by far : 20906.8 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 21
# Time taken by far : 20924.0 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 22
# Time taken by far : 20941.4 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 23
# Time taken by far : 20958.6 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 24
# Time taken by far : 20976.6 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 25
# Time taken by far : 20993.8 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 26
# Time taken by far : 21011.5 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 27
# Time taken by far : 21029.4 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 28
# Time taken by far : 21047.5 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 29
# Time taken by far : 21064.8 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 30
# Time taken by far : 21081.6 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 31
# Time taken by far : 21098.3 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 32
# Time taken by far : 21115.7 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 33
# Time taken by far : 21133.7 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 34
# Time taken by far : 21151.2 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 35
# Time taken by far : 21169.5 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 36
# Time taken by far : 21187.5 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 37
# Time taken by far : 21207.0 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 38
# Time taken by far : 21225.2 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 39
# Time taken by far : 21243.5 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%
#
# Current iteration : 25, batch : 40
# Time taken by far : 21261.4 seconds
# Current top member's network score: 0.45620
# Current top member's network accuracy: 77.69%

# %%
nnga.best.accuracy(X,y)
# Out:
# 77.6875

# %%
nnga.best.accuracy(X_test,y_test)
# Out:
# 74.75

# %%
accuracy_train = np.array(nnga.accuracy_train)
accuracy_test = np.array(nnga.accuracy_test)

# %%
from matplotlib import pyplot as plt
plt.plot(accuracy_train)
plt.plot(accuracy_test )
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#Dependencies
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout
# Neural network
model = Sequential()
model.add(Dense(12, input_dim=12, activation="sigmoid"))
model.add(Dense(12, activation="sigmoid"))

# %%
for i in range(len(model.layers)):
    model.layers[i].set_weights([nnga.best.weights[i].T,nnga.best.biases[i].reshape(-1)])

# %%
from keras.models import load_model
model.save('model_NN_GA_12_12_12.h5')  # creates a HDF5 file 'my_model.h5'
del model
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
