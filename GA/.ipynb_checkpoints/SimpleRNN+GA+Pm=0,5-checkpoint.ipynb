# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
import copy
import time
from sklearn.preprocessing import StandardScaler
import random

# %%
class Simple_RNN(object):

    def __init__(self, sizes, steps):
        self.num_layers = len(sizes)
        self.sizes = sizes
        self.wx = np.random.randn(sizes[0], sizes[1])
        self.wh = np.random.randn(sizes[1], sizes[1])
        self.bh = np.random.randn(sizes[1], 1)
        self.wy = np.random.randn(sizes[1], sizes[2])
        self.by = np.random.randn(sizes[2], 1)
        self.h0 = np.zeros(sizes[1])
        self.steps = steps

    def feedforward(self, x):
        h_temp=np.tanh(np.dot(self.wx.T,x[0]) + self.h0 + self.bh.reshape(-1))
        for i in range(self.steps-1):
            h_temp = np.tanh(np.dot( self.wx.T,x[i+1]) + np.dot(self.wh.T,h_temp) + self.bh.reshape(-1))
        result = self.sigmoid(np.dot(self.wy.T,h_temp) + self.by.reshape(-1))
        return result 
    
    def sigmoid(self, z):
        return 1.0/(1.0+np.exp(-z))

    def score(self, X, y):
        total_score=0
        for i in range(X.shape[0]):
            predicted = self.feedforward(X[i])
            actual = y[i]
            total_score += np.sum(np.power(predicted-actual,2))  # mean-squared error
        return total_score/X.shape[0]

    def accuracy(self, X, y):
        accuracy = 0
        for i in range(X.shape[0]):
            output = self.feedforward(X[i])
            condition = True
            for j in range(len(output)):
                output[j] = round(output[j])
            for j in range(len(output)):
                if(output[j]!=y[i][j]):
                    condition = False
                    break
            if condition:
                accuracy += 1
        return accuracy / X.shape[0] * 100

# %%
class Simple_RNN_GA:

    def __init__(self, n_pops, net_size, mutation_rate, crossover_rate, X, y, X_test, y_test, steps):
        self.n_pops = n_pops
        self.steps = steps
        self.net_size = net_size
        self.nets = [Simple_RNN(self.net_size,self.steps) for i in range(self.n_pops)]
        self.mutation_rate = mutation_rate
        self.crossover_rate = crossover_rate
        self.X = X[:]
        self.y = y[:]
        self.X_test = X_test[:]
        self.y_test = y_test[:]
        self.accuracy_train = []
        self.accuracy_test = []
        self.best = Simple_RNN(self.net_size,self.steps)
    
    def get_random_point(self, type):
        nn = self.nets[0]
        point_index = 0
        if type == 'wx':
            row = random.randint(0,nn.wx.shape[0]-1)
            col = random.randint(0,nn.wx.shape[1]-1)
            point_index = (row, col)
        elif type == 'wh':
            row = random.randint(0,nn.wh.shape[0]-1)
            col = random.randint(0,nn.wh.shape[1]-1)
            point_index = (row, col)
        elif type == 'bh':
            row = random.randint(0,nn.bh.shape[0]-1)
            col = random.randint(0,nn.bh.shape[1]-1)
            point_index = (row, col)
        elif type == 'wy':
            row = random.randint(0,nn.wy.shape[0]-1)
            col = random.randint(0,nn.wy.shape[1]-1)
            point_index = (row, col)
        elif type == 'by':
            row = random.randint(0,nn.by.shape[0]-1)
            col = random.randint(0,nn.by.shape[1]-1)
            point_index = (row, col)
        return point_index

    def get_all_scores(self,Xc,yc):
        return [net.score(Xc,yc) for net in self.nets]

    def get_all_accuracy(self,Xc,yc):
        return [net.accuracy(Xc,yc) for net in self.nets]

    def crossover(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.crossover_rate:
                father = random.randint(0,self.n_pops-1)
                mother = random.randint(0,self.n_pops-1)
                nn_1 = copy.deepcopy(self.nets[father])
                nn_2 = copy.deepcopy(self.nets[mother])
                
                k_1 = random.randint(int(0.5*self.nets[0].wx.size),self.nets[0].wx.size)
                for _ in range(k_1):
                    point = self.get_random_point('wx')
                    nn_1.wx[point] = self.nets[mother].wx[point]
                    nn_2.wx[point] = self.nets[father].wx[point]
                    
                k_2 = random.randint(int(0.5*self.nets[0].wh.size),self.nets[0].wh.size)
                for _ in range(k_2):
                    point = self.get_random_point('wh')
                    nn_1.wh[point] = self.nets[mother].wh[point]
                    nn_2.wh[point] = self.nets[father].wh[point]
                    
                k_3 = random.randint(int(0.5*self.nets[0].bh.size),self.nets[0].bh.size)
                for _ in range(k_3):
                    point = self.get_random_point('bh')
                    nn_1.bh[point] = self.nets[mother].bh[point]
                    nn_2.bh[point] = self.nets[father].bh[point]
                    
                k_4 = random.randint(int(0.5*self.nets[0].wy.size),self.nets[0].wy.size)
                for _ in range(k_4):
                    point = self.get_random_point('wy')
                    nn_1.wy[point] = self.nets[mother].wy[point]
                    nn_2.wy[point] = self.nets[father].wy[point]
                    
                k_5 = random.randint(int(0.5*self.nets[0].by.size),self.nets[0].by.size)
                for _ in range(k_5):
                    point = self.get_random_point('by')
                    nn_1.by[point] = self.nets[mother].by[point]
                    nn_2.by[point] = self.nets[father].by[point]
                    
                self.nets.append(copy.deepcopy(nn_1))
                self.nets.append(copy.deepcopy(nn_2))
        
    def mutation(self):
        for i in range(self.n_pops):
            if random.uniform(0,1) < self.mutation_rate:
                origin = random.randint(0,self.n_pops-1)
                nn = copy.deepcopy(self.nets[origin])

                k_1 = random.randint(int(0.5*self.nets[0].wx.size),self.nets[0].wx.size)
                for _ in range(k_1):
                    point = self.get_random_point('wx')
                    nn.wx[point] += random.uniform(-0.5, 0.5)

                k_2 = random.randint(int(0.5*self.nets[0].wh.size),self.nets[0].wh.size)
                for _ in range(k_2):
                    point = self.get_random_point('wh')
                    nn.wh[point] += random.uniform(-0.5, 0.5)
                    
                k_3 = random.randint(int(0.5*self.nets[0].bh.size),self.nets[0].bh.size)
                for _ in range(k_3):
                    point = self.get_random_point('bh')
                    nn.bh[point] += random.uniform(-0.5, 0.5)
                    
                k_4 = random.randint(int(0.5*self.nets[0].wy.size),self.nets[0].wy.size)
                for _ in range(k_4):
                    point = self.get_random_point('wy')
                    nn.wy[point] += random.uniform(-0.5, 0.5)
                    
                k_5 = random.randint(int(0.5*self.nets[0].by.size),self.nets[0].by.size)
                for _ in range(k_5):
                    point = self.get_random_point('by')
                    nn.by[point] += random.uniform(-0.5, 0.5)
                self.nets.append(copy.deepcopy(nn))
        
    def selection(self,Xc,yc):
        nets_new=[]
        for i in range(self.n_pops):
            k_1 = random.randint(0,len(self.nets)-1)
            k_2 = random.randint(0,len(self.nets)-1)
            if(self.nets[k_1].score(Xc,yc)<self.nets[k_2].score(Xc,yc)):
                nets_new.append(self.nets[k_1])
            else:
                nets_new.append(self.nets[k_2])
        self.nets = copy.deepcopy(nets_new)
    
    def sort_nets(self,Xc,yc):
        score_list = list(zip(self.nets, self.get_all_scores(Xc,yc)))
        score_list.sort(key=lambda x: x[1])
        score_list = [obj[0] for obj in score_list]
        self.nets = copy.deepcopy(score_list)
        if(self.best.accuracy(self.X,self.y)<self.nets[0].accuracy(self.X,self.y)):
            self.best = copy.deepcopy(self.nets[0])

    def evolve(self):
        start_time = time.time()
        for t in range(25):
            self.accuracy_train.append(self.best.accuracy(self.X,self.y))
            self.accuracy_test.append(self.best.accuracy(self.X_test,self.y_test))
            for i in range(20):
                j1=i*40
                j2=(1+i)*40
                Xc=self.X[j1:j2,:,:]
                yc=self.y[j1:j2,:]
                for k in range(25): 
                    self.crossover()
                    self.mutation()
                    self.selection(Xc,yc)
                    self.sort_nets(Xc,yc)
                print("Current iteration : {}, batch : {}".format(t+1,i+1))
                print("Time taken by far : %.1f seconds" % (time.time() - start_time))
                print("Current top member's network score: %.5f " % self.best.score(self.X,self.y))
                print("Current top member's network accuracy: %.2f%%\n" % self.best.accuracy(self.X,self.y))

# %%
df = pd.read_csv("../Data/data_(8-8).csv")
sc = StandardScaler()

# %%
X = df.iloc[:800, :8].values
y = df.iloc[:800, 8:16].values
X = sc.fit_transform(X)
X_test = df.iloc[800:1000, :8].values
y_test = df.iloc[800:1000, 8:16].values
X_test = sc.fit_transform(X_test)

# %%
X1= np.reshape(X, (X.shape[0], X.shape[1], 1))
y1= np.reshape(y, (y.shape[0], y.shape[1]))

# %%
X2= np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y2= np.reshape(y_test, (y_test.shape[0], y_test.shape[1]))

# %%
N_POPS = 100
steps = X.shape[1]
NET_SIZE = [1,24,8]
MUTATION_RATE = 0.5
CROSSOVER_RATE = 0.8
simple_rnn_ga = Simple_RNN_GA(N_POPS, NET_SIZE, MUTATION_RATE, CROSSOVER_RATE, X1, y1, X2, y2, steps)
simple_rnn_ga.evolve()
# Out:
# Current iteration : 1, batch : 1
# Time taken by far : 26.8 seconds
# Current top member's network score: 1.97991
# Current top member's network accuracy: 6.50%
#
# Current iteration : 1, batch : 2
# Time taken by far : 52.3 seconds
# Current top member's network score: 2.15989
# Current top member's network accuracy: 8.25%
#
# Current iteration : 1, batch : 3
# Time taken by far : 75.6 seconds
# Current top member's network score: 1.80630
# Current top member's network accuracy: 17.38%
#
# Current iteration : 1, batch : 4
# Time taken by far : 100.4 seconds
# Current top member's network score: 1.80630
# Current top member's network accuracy: 17.38%
#
# Current iteration : 1, batch : 5
# Time taken by far : 126.6 seconds
# Current top member's network score: 1.80630
# Current top member's network accuracy: 17.38%
#
# Current iteration : 1, batch : 6
# Time taken by far : 149.3 seconds
# Current top member's network score: 1.53743
# Current top member's network accuracy: 22.12%
#
# Current iteration : 1, batch : 7
# Time taken by far : 172.3 seconds
# Current top member's network score: 1.53743
# Current top member's network accuracy: 22.12%
#
# Current iteration : 1, batch : 8
# Time taken by far : 196.1 seconds
# Current top member's network score: 1.30579
# Current top member's network accuracy: 28.38%
#
# Current iteration : 1, batch : 9
# Time taken by far : 223.7 seconds
# Current top member's network score: 1.19252
# Current top member's network accuracy: 31.25%
#
# Current iteration : 1, batch : 10
# Time taken by far : 257.3 seconds
# Current top member's network score: 1.06945
# Current top member's network accuracy: 42.75%
#
# Current iteration : 1, batch : 11
# Time taken by far : 283.4 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 12
# Time taken by far : 309.0 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 13
# Time taken by far : 341.2 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 14
# Time taken by far : 366.9 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 15
# Time taken by far : 394.2 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 16
# Time taken by far : 424.9 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 17
# Time taken by far : 452.7 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 18
# Time taken by far : 481.0 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 19
# Time taken by far : 506.3 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 1, batch : 20
# Time taken by far : 529.8 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 1
# Time taken by far : 552.5 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 2
# Time taken by far : 574.7 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 3
# Time taken by far : 597.5 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 4
# Time taken by far : 619.4 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 5
# Time taken by far : 641.6 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 6
# Time taken by far : 664.7 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 7
# Time taken by far : 688.4 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 8
# Time taken by far : 715.4 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 9
# Time taken by far : 741.6 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 10
# Time taken by far : 772.4 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 11
# Time taken by far : 801.6 seconds
# Current top member's network score: 1.04796
# Current top member's network accuracy: 50.00%
#
# Current iteration : 2, batch : 12
# Time taken by far : 832.0 seconds
# Current top member's network score: 0.94159
# Current top member's network accuracy: 50.12%
#
# Current iteration : 2, batch : 13
# Time taken by far : 862.9 seconds
# Current top member's network score: 0.94159
# Current top member's network accuracy: 50.12%
#
# Current iteration : 2, batch : 14
# Time taken by far : 899.1 seconds
# Current top member's network score: 0.90467
# Current top member's network accuracy: 51.50%
#
# Current iteration : 2, batch : 15
# Time taken by far : 935.5 seconds
# Current top member's network score: 0.90467
# Current top member's network accuracy: 51.50%
#
# Current iteration : 2, batch : 16
# Time taken by far : 963.5 seconds
# Current top member's network score: 0.90467
# Current top member's network accuracy: 51.50%
#
# Current iteration : 2, batch : 17
# Time taken by far : 993.0 seconds
# Current top member's network score: 0.89048
# Current top member's network accuracy: 52.00%
#
# Current iteration : 2, batch : 18
# Time taken by far : 1027.8 seconds
# Current top member's network score: 0.89048
# Current top member's network accuracy: 52.00%
#
# Current iteration : 2, batch : 19
# Time taken by far : 1061.2 seconds
# Current top member's network score: 0.89048
# Current top member's network accuracy: 52.00%
#
# Current iteration : 2, batch : 20
# Time taken by far : 1087.4 seconds
# Current top member's network score: 0.89048
# Current top member's network accuracy: 52.00%
#
# Current iteration : 3, batch : 1
# Time taken by far : 1113.9 seconds
# Current top member's network score: 0.89048
# Current top member's network accuracy: 52.00%
#
# Current iteration : 3, batch : 2
# Time taken by far : 1139.4 seconds
# Current top member's network score: 0.89048
# Current top member's network accuracy: 52.00%
#
# Current iteration : 3, batch : 3
# Time taken by far : 1164.9 seconds
# Current top member's network score: 0.89048
# Current top member's network accuracy: 52.00%
#
# Current iteration : 3, batch : 4
# Time taken by far : 1191.2 seconds
# Current top member's network score: 0.89048
# Current top member's network accuracy: 52.00%
#
# Current iteration : 3, batch : 5
# Time taken by far : 1216.5 seconds
# Current top member's network score: 0.89616
# Current top member's network accuracy: 53.12%
#
# Current iteration : 3, batch : 6
# Time taken by far : 1242.7 seconds
# Current top member's network score: 0.89616
# Current top member's network accuracy: 53.12%
#
# Current iteration : 3, batch : 7
# Time taken by far : 1268.3 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 8
# Time taken by far : 1293.7 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 9
# Time taken by far : 1320.2 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 10
# Time taken by far : 1345.3 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 11
# Time taken by far : 1371.2 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 12
# Time taken by far : 1396.4 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
# Current iteration : 3, batch : 13
# Time taken by far : 1421.5 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 14
# Time taken by far : 1447.5 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 15
# Time taken by far : 1472.7 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 16
# Time taken by far : 1497.9 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 17
# Time taken by far : 1524.1 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 18
# Time taken by far : 1549.6 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 19
# Time taken by far : 1575.9 seconds
# Current top member's network score: 0.85966
# Current top member's network accuracy: 55.38%
#
# Current iteration : 3, batch : 20
# Time taken by far : 1601.0 seconds
# Current top member's network score: 0.87111
# Current top member's network accuracy: 56.50%
#
# Current iteration : 4, batch : 1
# Time taken by far : 1626.1 seconds
# Current top member's network score: 0.87111
# Current top member's network accuracy: 56.50%
#
# Current iteration : 4, batch : 2
# Time taken by far : 1652.1 seconds
# Current top member's network score: 0.87111
# Current top member's network accuracy: 56.50%
#
# Current iteration : 4, batch : 3
# Time taken by far : 1677.2 seconds
# Current top member's network score: 0.87111
# Current top member's network accuracy: 56.50%
#
# Current iteration : 4, batch : 4
# Time taken by far : 1703.3 seconds
# Current top member's network score: 0.87111
# Current top member's network accuracy: 56.50%
#
# Current iteration : 4, batch : 5
# Time taken by far : 1728.7 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 6
# Time taken by far : 1753.7 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 7
# Time taken by far : 1779.6 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 8
# Time taken by far : 1804.8 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 9
# Time taken by far : 1830.3 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 10
# Time taken by far : 1855.5 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 11
# Time taken by far : 1880.7 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 12
# Time taken by far : 1906.7 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 13
# Time taken by far : 1931.9 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 14
# Time taken by far : 1957.3 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 15
# Time taken by far : 1983.5 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 16
# Time taken by far : 2008.9 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 17
# Time taken by far : 2037.3 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 18
# Time taken by far : 2062.7 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 19
# Time taken by far : 2088.5 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 4, batch : 20
# Time taken by far : 2114.7 seconds
# Current top member's network score: 0.91840
# Current top member's network accuracy: 59.50%
#
# Current iteration : 5, batch :
7 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 8
# Time taken by far : 6398.9 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 9
# Time taken by far : 6423.1 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 10
# Time taken by far : 6448.5 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 11
# Time taken by far : 6472.9 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 12
# Time taken by far : 6497.3 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 13
# Time taken by far : 6522.8 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 14
# Time taken by far : 6547.4 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 15
# Time taken by far : 6571.9 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 16
# Time taken by far : 6597.3 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 17
# Time taken by far : 6622.0 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 18
# Time taken by far : 6647.2 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
# Current iteration : 13, batch : 19
# Time taken by far : 6671.7 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 13, batch : 20
# Time taken by far : 6696.3 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 1
# Time taken by far : 6721.6 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 2
# Time taken by far : 6746.0 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 3
# Time taken by far : 6770.2 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 4
# Time taken by far : 6795.1 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 5
# Time taken by far : 6819.5 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 6
# Time taken by far : 6844.5 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 7
# Time taken by far : 6868.9 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 8
# Time taken by far : 6893.1 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 9
# Time taken by far : 6918.2 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 10
# Time taken by far : 6942.6 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 11
# Time taken by far : 6967.1 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 12
# Time taken by far : 6992.2 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 13
# Time taken by far : 7016.8 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 14
# Time taken by far : 7041.9 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 15
# Time taken by far : 7066.0 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 16
# Time taken by far : 7090.7 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 17
# Time taken by far : 7116.0 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 18
# Time taken by far : 7140.5 seconds
# Current top member's network score: 0.76906
# Current top member's network accuracy: 63.62%
#
# Current iteration : 14, batch : 19
# Time taken by far : 7165.2 seconds
# Current top member's network score: 0.82438
# Current top member's network accuracy: 64.62%
#
# Current iteration : 14, batch : 20
# Time taken by far : 7190.2 seconds
# Current top member's network score: 0.81917
# Current top member's network accuracy: 66.12%
#
# Current iteration : 15, batch : 1
# Time taken by far : 7214.7 seconds
# Current top member's network score: 0.76809
# Current top member's network accuracy: 66.25%
#
# Current iteration : 15, batch : 2
# Time taken by far : 7239.8 seconds
# Current top member's network score: 0.76809
# Current top member's network accuracy: 66.25%
#
# Current iteration : 15, batch : 3
# Time taken by far : 7264.3 seconds
# Current top member's network score: 0.84149
# Current top member's network accuracy: 66.50%
#
# Current iteration : 15, batch : 4
# Time taken by far : 7288.6 seconds
# Current top member's network score: 0.84149
# Current top member's network accuracy: 66.50%
#
# Current iteration : 15, batch : 5
# Time taken by far : 7313.8 seconds
# Current top member's network score: 0.73898
# Current top member's network accuracy: 67.50%
#
# Current iteration : 15, batch : 6
# Time taken by far : 7338.3 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 7
# Time taken by far : 7362.7 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 8
# Time taken by far : 7387.6 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 9
# Time taken by far : 7411.8 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 10
# Time taken by far : 7436.5 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 11
# Time taken by far : 7460.8 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 12
# Time taken by far : 7485.1 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 13
# Time taken by far : 7510.1 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 14
# Time taken by far : 7534.5 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 15
# Time taken by far : 7558.9 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 16
# Time taken by far : 7583.9 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 17
# Time taken by far : 7608.1 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 18
# Time taken by far : 7632.8 seconds
# Current top member's network score: 0.72998
# Current top member's network accuracy: 68.00%
#
# Current iteration : 15, batch : 19
# Time taken by far : 7657.5 seconds
# ...
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 3
# Time taken by far : 10103.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 4
# Time taken by far : 10125.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 5
# Time taken by far : 10148.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 6
# Time taken by far : 10170.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 7
# Time taken by far : 10192.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 8
# Time taken by far : 10215.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 9
# Time taken by far : 10237.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 10
# Time taken by far : 10259.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 11
# Time taken by far : 10282.5 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
# Current iteration : 21, batch : 12
# Time taken by far : 10304.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 13
# Time taken by far : 10326.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 14
# Time taken by far : 10349.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 15
# Time taken by far : 10372.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 16
# Time taken by far : 10394.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 17
# Time taken by far : 10417.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 18
# Time taken by far : 10439.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 19
# Time taken by far : 10461.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 21, batch : 20
# Time taken by far : 10484.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 1
# Time taken by far : 10506.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 2
# Time taken by far : 10528.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 3
# Time taken by far : 10551.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 4
# Time taken by far : 10573.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 5
# Time taken by far : 10595.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 6
# Time taken by far : 10618.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 7
# Time taken by far : 10640.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 8
# Time taken by far : 10662.5 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 9
# Time taken by far : 10685.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 10
# Time taken by far : 10707.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 11
# Time taken by far : 10730.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 12
# Time taken by far : 10752.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 13
# Time taken by far : 10775.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 14
# Time taken by far : 10797.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 15
# Time taken by far : 10820.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 16
# Time taken by far : 10842.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 17
# Time taken by far : 10864.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 18
# Time taken by far : 10886.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 19
# Time taken by far : 10908.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 22, batch : 20
# Time taken by far : 10932.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 1
# Time taken by far : 10955.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 2
# Time taken by far : 10977.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 3
# Time taken by far : 11001.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 4
# Time taken by far : 11028.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 5
# Time taken by far : 11052.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 6
# Time taken by far : 11079.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 7
# Time taken by far : 11102.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 8
# Time taken by far : 11128.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 9
# Time taken by far : 11152.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 10
# Time taken by far : 11176.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 11
# Time taken by far : 11201.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 12
# Time taken by far : 11226.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 13
# Time taken by far : 11250.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 14
# Time taken by far : 11274.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 15
# Time taken by far : 11298.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 16
# Time taken by far : 11322.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 17
# Time taken by far : 11346.5 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 18
# Time taken by far : 11369.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 19
# Time taken by far : 11394.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 23, batch : 20
# Time taken by far : 11417.5 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 1
# Time taken by far : 11440.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 2
# Time taken by far : 11465.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
# Current iteration : 24, batch : 3
# Time taken by far : 11488.4 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 4
# Time taken by far : 11511.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 5
# Time taken by far : 11536.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 6
# Time taken by far : 11559.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 7
# Time taken by far : 11583.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 8
# Time taken by far : 11607.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 9
# Time taken by far : 11631.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 10
# Time taken by far : 11656.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 11
# Time taken by far : 11679.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 12
# Time taken by far : 11703.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 13
# Time taken by far : 11727.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 14
# Time taken by far : 11751.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 15
# Time taken by far : 11774.5 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 16
# Time taken by far : 11798.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 17
# Time taken by far : 11822.1 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 18
# Time taken by far : 11845.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 19
# Time taken by far : 11870.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 24, batch : 20
# Time taken by far : 11893.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 1
# Time taken by far : 11917.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 2
# Time taken by far : 11941.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 3
# Time taken by far : 11964.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 4
# Time taken by far : 11989.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 5
# Time taken by far : 12012.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 6
# Time taken by far : 12035.6 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 7
# Time taken by far : 12059.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 8
# Time taken by far : 12083.2 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 9
# Time taken by far : 12106.5 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 10
# Time taken by far : 12130.7 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 11
# Time taken by far : 12153.9 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 12
# Time taken by far : 12177.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 13
# Time taken by far : 12201.5 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 14
# Time taken by far : 12224.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 15
# Time taken by far : 12248.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 16
# Time taken by far : 12272.3 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 17
# Time taken by far : 12295.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 18
# Time taken by far : 12320.0 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 19
# Time taken by far : 12343.5 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%
#
# Current iteration : 25, batch : 20
# Time taken by far : 12366.8 seconds
# Current top member's network score: 0.71293
# Current top member's network accuracy: 68.12%

# %%
simple_rnn_ga.best.accuracy(X1,y1)
# Out:
# 68.125

# %%
simple_rnn_ga.best.accuracy(X2,y2)
# Out:
# 64.5

# %%
accuracy_train = np.array(simple_rnn_ga.accuracy_train)
accuracy_test = np.array(simple_rnn_ga.accuracy_test)

# %%
plt.plot(accuracy_train)
plt.plot(accuracy_test )
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
